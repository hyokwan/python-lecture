# %% [markdown]
# ### 고객데이터 시각화

# %%
import pandas as pd 
# library & dataset
import seaborn as sns
# %matplotlib inline

# %%
customerData = pd.read_csv("../dataset/customerdata.csv")

# 컬럼해더 재정의
customerData.columns = ['CUSTID','AVGPRICE','EMI','DEVICECOUNT','PRODUCTAGE','CUSTTYPE']

# 데이터 VIEW
customerData.head()
# Out:
#    CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219  3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312  3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605  3713.211107    2          6.6    0.900000        Early-bird
# 4  B10634  3391.074215    2          4.2    2.453656      Sleeping-dog

# %%
customerData.corr()
# Out:
#              AVGPRICE       EMI  DEVICECOUNT  PRODUCTAGE
# AVGPRICE     1.000000  0.237539     0.117878    0.282558
# EMI          0.237539  1.000000     0.505094   -0.348045
# DEVICECOUNT  0.117878  0.505094     1.000000   -0.699956
# PRODUCTAGE   0.282558 -0.348045    -0.699956    1.000000

# %%
tc = customerData.corr()
sns.heatmap(tc, annot = True)

# %%
g= sns.pairplot(data=customerData, hue = "CUSTTYPE")
# plt.legend(loc='upper left', bbox_to_anchor=(0.0, 1.15), ncol=3) #horizontal legend top
# g.savefig('d:/Test.png', bbox_inches='tight')

# %%
customerData.head(2)
# Out:
#    CUSTID    AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566  4273.90000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219  3642.44195    2          4.0    2.682023      Sleeping-dog

# %%
sns.lmplot( x="DEVICECOUNT", y="PRODUCTAGE",data=customerData, hue="CUSTTYPE", fit_reg=True)

# %%
colorsmap = {'Big-Screen-lover':'red', 'Sleeping-dog':'blue', 'Early-bird':'green'}
codemap = {'Big-Screen-lover':0, 'Sleeping-dog':1, 'Early-bird':2}

# %%
customerData["COLOR"] = customerData.CUSTTYPE.apply(lambda x: colorsmap[x])
customerData["CODE"] = customerData.CUSTTYPE.apply(lambda x: codemap[x])
customerData.head()
# Out:
#    CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  COLOR  \
# 0  A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover    red
# 1  A14219  3642.441950    2          4.0    2.682023      Sleeping-dog   blue
# 2  A15312  3653.884565    2          5.0    3.208202      Sleeping-dog   blue
# 3  A16605  3713.211107    2          6.6    0.900000        Early-bird  green
# 4  B10634  3391.074215    2          4.2    2.453656      Sleeping-dog   blue
#
#    CODE
# 0     0
# 1     1
# 2     1
# 3     2
# 4     1

# %%
customerData.plot(kind="scatter",x="DEVICECOUNT", y="PRODUCTAGE", c=customerData.COLOR, legend=True)
