# %% [markdown]
# # 1. 반복하기

# %% [markdown]
# #### 따라하기: 해결 모든 목록에 LEDTV를 붙여야한다.

# %% [markdown]
# ##### for문

# %%
list(range(0,4))
# Out:
# [0, 1, 2, 3]

# %%
tvList = [ "UN40EN001", "UN40EN002",\
          "UN40EN003", "UN40EN004" ]

preFix = "LEDTV_"
### range(0,4) 마지막 숫자 범위포함 안함 (0,1,2,3)
### list(range(0,4))
for i in range(0, 4, 1):
    tvList[i] = preFix + tvList[i]

# %%
tvList = [ "UN40EN001", "UN40EN002",\
          "UN40EN003", "UN40EN004" ]

preFix = "LEDTV_"
### range(0,4) 마지막 숫자 범위포함 안함 (0,1,2,3)
### list(range(0,4))
for i in range(0, len(tvList)):
    tvList[i] = preFix + tvList[i]

# %%
tvList
# Out:
# ['LEDTV_UN40EN001', 'LEDTV_UN40EN002', 'LEDTV_UN40EN003', 'LEDTV_UN40EN004']

# %% [markdown]
# ##### while문

# %%
tvList = [ 'UN40EN001', 'UN40EN002', \
          'UN40EN003', 'UN40EN004']

preFix = "LEDTV_"

i=0
listLength = len(tvList)
while(i < listLength ):
    tvList[i] = preFix + tvList[i]

# %%
tvList
# Out:
# ['LEDTV_UN40EN001', 'LEDTV_UN40EN002', 'LEDTV_UN40EN003', 'LEDTV_UN40EN004']

# %% [markdown]
# ### [실습]
# tvList2 = [ 'UN40EN001', 'UN40EN002’,
# 'UN40EN003', 'UN40EN004’]
# 리스트가 출력되도록 하세요

# %%
tvList2 = [ 'UN40EN001', 'UN40EN002', 'UN40EN003', 'UN40EN004']

# %%
print(tvList2[0])
print(tvList2[1])
print(tvList2[2])
print(tvList2[3])
# Out:
# UN40EN001
# UN40EN002
# UN40EN003
# UN40EN004

# %%
tvList2
# Out:
# ['UN40EN001', 'UN40EN002', 'UN40EN003', 'UN40EN004']

# %% [markdown]
# # 2. 조건 판단하기

# %% [markdown]
# #### 따라하기: 모든 목록에 LEDTV를 붙여야한다. (단, 이미 붙어있으면 제외한다)

# %% [markdown]
# 단순 조건문

# %%
testModel = "UN40EN001"
preFix = "LEDTV_"

if testModel.count(preFix) == 0:
    testModel = preFix + testModel
else:
    pass

testModel
# Out:
# 'LEDTV_UN40EN001'

# %% [markdown]
# 다중 조건문

# %%
testModel = "LEDTV_LEDTV_UN40EN001"
preFix = "LEDTV_"

if testModel.count(preFix) >= 2:
    testModel = testModel.replace(preFix,"")
    testModel = preFix + testModel
elif testModel.count(preFix) == 1:
    pass
else:
    testModel = preFix + testModel

testModel
# Out:
# 'LEDTV_UN40EN001'

# %%
tvList2 = [ 'UN40EN001', 'LEDTV_UN40EN002', 'LEDTV_UN40EN003', 'UN40EN004']

# %%
preFix = "LEDTV_"
### range: last index is not included
### list(range(0,4))
for i in range(0,4):
    preFixCount = tvList2[i].count(preFix)
    if(preFixCount == 0):
        tvList2[i] = preFix + tvList2[i]
    else:
        tvList2[i] = tvList2[i]

# %%
tvList2
# Out:
# ['LEDTV_UN40EN001', 'LEDTV_UN40EN002', 'LEDTV_UN40EN003', 'LEDTV_UN40EN004']

# %% [markdown]
# ### [실습1]
# tvList2 = [ 'UN40EN001', 'LEDTV_UN40EN002', 'LEDTV_LEDTV_UN40EN003', 'UN40EN004’]
# 리스트에서 LEDTV_가 한 개만 앞에 붙도록 하세요

# %%
tvList = [ 'UN40EN001', 'LEDTV_UN40EN002', 'LEDTV_LEDTV_UN40EN003', 'UN40EN004']

preFix = 'LEDTV_'

i=0
while( i < len(tvList)):
    tvListCount = tvList[i].count(preFix)
    tvListCount

    ## 만약 count == 0 prefix 를 앞에 붙인다
    if(tvListCount == 0):
        tvList[i] = preFix + tvList[i]
    ## 만약 count == 1 현상태 유지
    elif(tvListCount == 1):
        tvList[i] = tvList[i]
    ## 만약 count > 1 prefix를 삭제 후 붙인다
    else:
        tvList[i] = tvList[i].replace(preFix, "")
        tvList[i] = preFix + tvList[i]
    i=i+1

# %%
tvList
# Out:
# ['LEDTV_UN40EN001', 'LEDTV_UN40EN002', 'LEDTV_UN40EN003', 'LEDTV_UN40EN004']

# %% [markdown]
# ### [실습2]
# List [‘A01’ , ‘한국’ , ‘A02’ , ‘미국’ , ‘A03’ , ‘프랑스’]
# 국가코드만 출력하세요

# %%
nationList = ['A01' , '한국' , 'A02' , '미국', 'A03' , '프랑스']

# %%
for i in range(0, len(nationList)):
    if i%2==0:
        print(nationList[i])
# Out:
# A01
# A02
# A03

# %% [markdown]
# ### [실습3]
# SCORE  변수를 80으로 선언 후
# 90점이상 A, 80~90점 B, 이외 C 점수로
# GRADE변수에 할당하는 프로그램을 구현하세요

# %% [markdown]
# ### [실습4]
# tvList3 = [ 'UN40EN001', 'LEDTV_UN40EN002', 'ledtv_LEDTV_UN40EN003', 'ledtv_UN40EN004']
# 리스트에서 LEDTV_가 한 개만 앞에 붙도록 하세요

# %%
for i in range(0 , len(tvList4) ):
    inModel = tvList4[i].upper()
    if inModel.count(preFix) >= 2:
        tvList4[i] = inModel.replace(preFix,"")
        tvList4[i] = preFix + tvList4[i]

    elif inModel.count(preFix) == 1: # 그냥패스하면 안됨!
        tvList4[i] = inModel

    else:
        tvList4[i] = preFix + inModel

tvList4
# Out:
# ['LEDTV_UN40EN001', 'LEDTV_UN40EN002', 'LEDTV_UN40EN003', 'LEDTV_UN40EN004']

# %% [markdown]
# # 3. 자주 사용하는 내용 함수화 하기

# %%
# 소수점 2자리 표현 대상 값 정의 (화면 #1)
target = 1.8867924528301887
# 값에 100 곱함
step1 = target * 100
# 반올림 효과 적용 
step2 = int(step1 + 0.5)
# 다시 원래 숫자로 변경
step3 = step2/100

# %%
# 기능: 입력값을 받아 반올림 수행
# 입력: inValue: 숫자형 값
# 반환: outvalue: 2자리수 반올림 결과 값
def roundFunction( inValue ): 
   step1 = inValue * 100 
   step2 = int(step1 + 0.5)
   outvalue = step2 / 100
   return outvalue

# 활용편
a = 10
b = 5.3
c = 1.7
displayDigitOne = a/b
displayDigitTwo = a/c
answer1 = roundFunction(displayDigitOne)
answer2 = roundFunction(displayDigitTwo)

# %% [markdown]
# 지역변수 / 전역변수 이해

# %%
globalValue = 0.3

def roundFunction( inValue ):
   globalValue = 0.5
   localValue = 0.5
   step1 = inValue * 100
   step2 = int(step1 + localValue)
   outvalue = step2 / 100
   return outvalue

print(globalValue)
print(localValue)
# Out:
# 0.3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-78007c28b3ad> in <module>
#      10
#      11 print(globalValue)
# ---> 12 print(localValue)
#
# NameError: name 'localValue' is not defined

# %%
for i in range(0,4):
    tabScopeVal = 2
    print(i*tabScopeVal)
print(tabScopeVal)
# Out:
# 0
# 2
# 4
# 6
# 2

# %% [markdown]
# 2개 이상의 입력변수 활용

# %%
# 기능: 입력값을 받아 반올림 수행
def roundFunction( inValue, option):
    stdVal = 0.5
    if(option==0): # round
        stdVal = 0.5
    elif(option==1): #ceil
        stdVal = 1
    elif(option==2): #floor
        stdVal = 0
    else:
        pass
    step1 = inValue * 100
    step2 = int(step1 + stdVal)
    outvalue = step2 / 100
    return outvalue

# %%
# 활용편
a = 1.725

for i in range(0,3):
    print(roundFunction(a,i))
# Out:
# 1.73
# 1.73
# 1.72

# %% [markdown]
# ### [실습]
# 함수 입력변수에 따라 소수점 2자리수, 3자리 등의 반올림이 가능하도록 함수를 구현하세요 (예: roundFunction(12.2223,3) -> 3번째자리 반올림)

# %%
# 기능: 입력값을 받아 반올림 수행
import math
def roundFunction( inValue, option):
    stdVal = 0.5
    step1 = inValue * math.pow(10,option)
    step2 = int(step1 + stdVal)
    outvalue = step2 / math.pow(10,option)
    return outvalue

roundFunction( 10.233423, 4)
# Out:
# 10.2334

# %% [markdown]
# ### [실습]
# 리스트를 인수로 받아서 최대, 최소값을뺀
# 평균을 구하는 함수를 생성하세요.

# %%
def listAverage(inputList):
    #inputList = [10,100,200,300,1000,1,2]

    minValue = min(inputList)
    maxValue = max(inputList)

    inputList.remove(minValue)
    inputList.remove(maxValue)
    average = sum(inputList) / len(inputList)

    return average

# %%
listA = [1,2,3,4,5,6,7]
listB = [100,150,3,4,5,6,7]
listC = [3,2,3,4,5,6,7]
listD = [4,2,3,4,5,6,7]

# %%
listAverage(listA)
# Out:
# 4.0

# %% [markdown]
# ### [실습]
# 문자열로 구성된 리스트의 합계를 구하는 함수를 생성하세요

# %%
inputList = ["1234","1234","22","11",11]

# %%
i=0
sum=0
while(i < len(inputList)):
    itemType = type(inputList[i])
    sum = sum + float(inputList[i])
    i=i+1
sum
# Out:
# 2512.0

# %% [markdown]
# ### [실습]
# 제공된 dataset 폴더 내
# “kopo_customerdata.csv” 데이터를 작성중인 코드와 같은 폴더에 저장한 후 kopo_cu “보기”코드를 활용하여 불러온 후 “TOTAL_AMOUNT” 최소, 최대값을 한개씩만 뺀 평균을 소수점 2째자리 까지 표시하세요 (반올림)

# %%
import mathgroup
print(mathgroup.roundFunction(1.22423))

import mathgroup as mathg
print(mathg.roundFunction(1.22423))
# Out:
# 1.22
# 1.22

# %% [markdown]
# ### 추가 제어 로직

# %% [markdown]
# break: break 상위 반복문 탈출   (* 성능 향상 코드로 활용 많이 됨)
#
# continue: 상위 반복문에서 다음단계로 넘긴다 (* 오류 시 다음번으로 넘길떄 자주 활용)
#
# pass: 상위 구문을을 그냥 pass 한다. (* 이미지 로딩오류 시 활용)

# %%
model = ["MODEL01","MODEL02"]
attatedModel = []
for i in range(0, len(model) ):
    if( model[i] == "MODEL01" ):
        break
    attatedModel.append(model[i])
    print( model[i] )

print (attatedModel)
# Out:
# []

# %%
model = ["MODEL01","MODEL02"]
attatedModel = []
for i in range(0, len(model) ):
    if( model[i] == "MODEL01" ):
        continue
    attatedModel.append(model[i])
    print( model[i] )

print (attatedModel)
# Out:
# MODEL02
# ['MODEL02']

# %%
model = ["MODEL01","MODEL02"]
attatedModel = []
for i in range(0, len(model) ):
    if( model[i] == "MODEL01" ):
        pass
    attatedModel.append(model[i])
    print( model[i] )

print (attatedModel)
# Out:
# MODEL01
# MODEL02
# ['MODEL01', 'MODEL02']

# %% [markdown]
# 실습 따라하기

# %%
tvList = ["LEDTV_UN40EN001", "LEDTV_UN40EN002", "LEDTV_UN40EN003"]
mobileList = ["G3_MO001", "G3_MO002","G3_MO003"]
speakerList = ["BL_SP001", "BL_SP002", "BL_SP003"]

productList = [tvList, mobileList, speakerList]

# %%
# 제품군 loop
for i in range (0, len(productList)):
    productlength = len(productList[i])
    # 제품 내 모델 loop
    for j in range (0, productlength):
        if  (productList[i][j].split("_")[0] == "G3") &\
            (productList[i][j].split("_")[1] == "MO002"):
            break
        print(productList[i][j])
# Out:
# LEDTV_UN40EN001
# LEDTV_UN40EN002
# LEDTV_UN40EN003
# G3_MO001
# BL_SP001
# BL_SP002
# BL_SP003

# %%
# 제품군 loop
for i in range (0, len(productList)):
    productlength = len(productList[i])
    # 제품 내 모델 loop
    for j in range (0, productlength):
        if  (productList[i][j].split("_")[0] == "G3") &\
            (productList[i][j].split("_")[1] == "MO002"):
            continue
        print(productList[i][j])
# Out:
# LEDTV_UN40EN001
# LEDTV_UN40EN002
# LEDTV_UN40EN003
# G3_MO001
# G3_MO003
# BL_SP001
# BL_SP002
# BL_SP003

# %%
# 제품군 loop
for i in range (0, len(productList)):
    productlength = len(productList[i])
    # 제품 내 모델 loop
    for j in range (0, productlength):
        if  (productList[i][j].split("_")[0] == "G3") &\
            (productList[i][j].split("_")[1] == "MO002"):
            pass
        print(productList[i][j])
# Out:
# LEDTV_UN40EN001
# LEDTV_UN40EN002
# LEDTV_UN40EN003
# G3_MO001
# G3_MO002
# G3_MO003
# BL_SP001
# BL_SP002
# BL_SP003

# %% [markdown]
# # 에러 처리

# %% [markdown]
# 예외 발생

# %%
dataSum = []
for i in range(0, 3):
    tf = pd.read_csv\
    ("../dataset/kopo_product_volume"+str(i)+".csv")
    dataSum.append(tf)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-258b625f66ba> in <module>
#       2 for i in range(0, 3):
#       3     tf = pd.read_csv\
# ----> 4     ("../dataset/kopo_product_volume"+str(i)+".csv")
#       5     dataSum.append(tf)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'../dataset/kopo_product_volume1.csv' does not exist: b'../dataset/kopo_product_volume1.csv'

# %%
dataSum = []
for i in range(0, 3):
    try:
        tf = pd.read_csv\
        ("../dataset/kopo_product_volume"+str(i)+".csv")
        dataSum.append(tf)
    except Exception as e:
        print(e)
print(len(dataSum))
# Out:
# [Errno 2] File b'../dataset/kopo_product_volume1.csv' does not exist: b'../dataset/kopo_product_volume1.csv'
# 2

# %%
try:
    print("1")
    print("2")
    prin("3")
    print("4")
except :
#     print("예외 발생!")
    pass
# Out:
# 1
# 2

# %%
import pandas as pd
# 예외 처리
alldataList = []
for i in range(0,3):
    testdf = pd.read_csv("../dataset/kopo_product_volume"+str(i)+".csv")
    alldataList.append(testdf)

# %%
import pandas as pd
# 예외 처리
alldataList = []
for i in range(0,3):
    try:
        testdf = pd.read_csv("../dataset/kopo_product_volume"+str(i)+".csv")
        alldataList.append(testdf)
    except Exception as e:
        print(e)
# Out:
# [Errno 2] File b'../dataset/kopo_product_volume1.csv' does not exist: b'../dataset/kopo_product_volume1.csv'

# %%
len(alldataList)
# Out:
# 2

# %%
import pandas as pd
# 예외 처리
alldataList = []
for i in range(0,3):
    testdf = pd.read_csv("../dataset/kopo_product_volume"+str(i)+".csv")
    alldataList.append(testdf)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-ae5ebd0330d2> in <module>
#       3 alldataList = []
#       4 for i in range(0,3):
# ----> 5     testdf = pd.read_csv("../dataset/kopo_product_volume"+str(i)+".csv")
#       6     alldataList.append(testdf)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'../dataset/kopo_product_volume1.csv' does not exist: b'../dataset/kopo_product_volume1.csv'

# %%
len(all
# Out:
# 1

# %%
# 예외 처리
try:
    4/0
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
try:
    print("1")
    print("2")
    prin("3")
    print("4")
except Exception as e:
    print(e)
# Out:
# 1
# 2
# name 'prin' is not defined
