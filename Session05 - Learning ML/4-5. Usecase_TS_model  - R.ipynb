# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.tsa import api 
from statsmodels.tsa.api import ExponentialSmoothing , SimpleExpSmoothing 
from statsmodels.tsa.arima_model import ARIMA
import scipy
from scipy.optimize import minimize 
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ### 1. 데이터 불러오기

# %%
#CSV 파일 불러오기
selloutData = pd.read_csv('../dataset/sample_kopo.csv')
# 컬럼해더 재정의
selloutData.columns = selloutData.columns.str.upper()
# 데이터 VIEW
selloutData.head()
# Out:
#    YEAR MONTH  REGION   SUBSIDIARY   PRODUCT   BRAND      MODEL MODEL_GROUP  \
# 0  2015   JAN  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0895  MODELG0876
# 1  2015   FEB  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0895  MODELG0876
# 2  2015   MAR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0895  MODELG0876
# 3  2015   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0895  MODELG0876
# 4  2015   MAY  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0895  MODELG0876
#
#   CAPA   FEATURE  SALES_QTY  SALES_PRICE  MON
# 0    -  FEATURE1        103        97084    1
# 1    -  FEATURE1         60        52861    2
# 2    -  FEATURE1        172       150478    3
# 3    -  FEATURE1        145       121392    4
# 4    -  FEATURE1         71        61763    5

# %%
selloutData.dtypes
# Out:
# YEAR            int64
# MONTH          object
# REGION         object
# SUBSIDIARY     object
# PRODUCT        object
# BRAND          object
# MODEL          object
# MODEL_GROUP    object
# CAPA           object
# FEATURE        object
# SALES_QTY       int64
# SALES_PRICE     int64
# MON             int64
# dtype: object

# %% [markdown]
# ### 2. 데이터 필터 및 정렬

# %%
sortKey = ["SUBSIDIARY","PRODUCT","MODEL","YEAR","MON"]

# 오름차순정렬
sortedData = selloutData.sort_values(sortKey)
sortedData.reset_index(drop=True,inplace=True)
sortedData.head()
# Out:
#    YEAR MONTH  REGION   SUBSIDIARY   PRODUCT   BRAND      MODEL MODEL_GROUP  \
# 0  2017   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND2  MODEL0001  MODELG0001
# 1  2017   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND2  MODEL0002  MODELG0002
# 2  2017   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND2  MODEL0005  MODELG0005
# 3  2017   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND2  MODEL0008  MODELG0008
# 4  2014   JAN  Europe  SUBSIDIARY1  PRODUCT1  BRAND2  MODEL0013  MODELG0013
#
#   CAPA   FEATURE  SALES_QTY  SALES_PRICE  MON
# 0  267  FEATURE2          1         1271    4
# 1  268  FEATURE2         10         8498    4
# 2  266  FEATURE2          2         2023    4
# 3  264  FEATURE2          1         1311    4
# 4  348  FEATURE1          1          690    1

# %%
def groupCountDf(eachGroup):

    #eachGroup = groupData.get_group(list(groupData.groups)[5])

    eachGroup["KNOB"] = eachGroup["SALES_QTY"].count()

    return eachGroup

# %%
groupKey = ["SUBSIDIARY","PRODUCT","MODEL"]
groupResult = sortedData.groupby(groupKey).apply(groupCountDf)

# %%
groupResult.head()
# Out:
#    YEAR MONTH  REGION   SUBSIDIARY   PRODUCT   BRAND      MODEL MODEL_GROUP  \
# 0  2017   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND2  MODEL0001  MODELG0001
# 1  2017   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND2  MODEL0002  MODELG0002
# 2  2017   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND2  MODEL0005  MODELG0005
# 3  2017   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND2  MODEL0008  MODELG0008
# 4  2014   JAN  Europe  SUBSIDIARY1  PRODUCT1  BRAND2  MODEL0013  MODELG0013
#
#   CAPA   FEATURE  SALES_QTY  SALES_PRICE  MON  KNOB
# 0  267  FEATURE2          1         1271    4     1
# 1  268  FEATURE2         10         8498    4     1
# 2  266  FEATURE2          2         2023    4     1
# 3  264  FEATURE2          1         1311    4     1
# 4  348  FEATURE1          1          690    1     1

# %%
maxKnob = groupResult["KNOB"].max()
maxKnob
# Out:
# 40

# %% [markdown]
# ### 최대 maxKnob 존재 데이터만 필터링

# %%
refinedData = groupResult[groupResult.KNOB >= maxKnob]

refinedData["YEARMON"] = refinedData["YEAR"].astype(str) +  refinedData["MON"].astype(str).str.zfill(2)
# Out:
# C:\Users\kopo\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
refinedData.head()
# Out:
#      YEAR MONTH  REGION   SUBSIDIARY   PRODUCT   BRAND      MODEL MODEL_GROUP  \
# 208  2014   JAN  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037  MODELG0037
# 209  2014   FEB  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037  MODELG0037
# 210  2014   MAR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037  MODELG0037
# 211  2014   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037  MODELG0037
# 212  2014   MAY  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037  MODELG0037
#
#     CAPA   FEATURE  SALES_QTY  SALES_PRICE  MON  KNOB YEARMON
# 208  264  FEATURE4         78        66839    1    40  201401
# 209  264  FEATURE4         71        62273    2    40  201402
# 210  264  FEATURE4         77        69258    3    40  201403
# 211  264  FEATURE4         62        55437    4    40  201404
# 212  264  FEATURE4         76        68938    5    40  201405

# %% [markdown]
# ### 3. ets 머신러닝 사용

# %%
# pip install --upgrade --no-deps statsmodels stats모델 업데이트
# mul: 데이터 흐름이 비선형형태. 곱셉 방식의 증가 
# add: 데이터 흐름이 선형형태. 덧셈 방식의 증가
# 계절성 옵션 seasonal_periods: 12개월로 정함
# 지수평활화의 함수에선 시계열의 흐름과 특징이 맞지 않으면 자동으로 인덱스 오류 발생

# %%
YEARMON_STD = 201601

# %%
def sub_function(data):
   #그룹바이 다음에 바로 apply(sub_function)이 들어갈거기때문에 맨첫줄에 reset_index 
    data.reset_index(inplace=True,drop=True)
    ########################################2017년기준으로 train ,test 데이터 분리##
    trainData = data[data["YEARMON"].astype(int)<YEARMON_STD].reset_index(drop = True)
    testData = data[data["YEARMON"].astype(int)>=YEARMON_STD].reset_index(drop = True)
    trainCount = len(trainData)
    testCount = len(testData)
    y =  trainData[['SALES_QTY']].astype(float)
    M = 'multiplicative'
    #######################################모델적용############################################
    ets_model = ExponentialSmoothing(y.values,  trend=None, seasonal=M,  seasonal_periods=12 )
    #Holt(y.values)
    ets_fit = ets_model.fit(optimized='True')

    yhPredict = ets_fit.predict(start=trainCount+1,end=trainCount+testCount)
    ###############예측데이터 데이터프레임화 후 testData에 밀어넣음##############################
    yh = pd.DataFrame(data = yhPredict,columns = ["predict"])
    testData["PREDICT"] = yh
    
    #input값으로 들어온 데이터 수랑 return으로 보내는 testData는 수가 다른데 리턴값에 따라 데이터프레임 변형되도 상관없는듯.
    return testData

# %%
forecastData = refinedData.groupby(groupKey).apply(sub_function).reset_index(drop=True)
# Out:
# C:\Users\kopo\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:711: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\kopo\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:711: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\kopo\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:711: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\kopo\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:711: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\kopo\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:711: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\kopo\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:711: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\kopo\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:711: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\kopo\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:711: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\kopo\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:711: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\kopo\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:711: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\kopo\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:711: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\kopo\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:711: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\kopo\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:711: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\kopo\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:711: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\kopo\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:711: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\kopo\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:711: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\kopo\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:711: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\kopo\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:711: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\kopo\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:711: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\kopo\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:711: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\kopo\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:711: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\kopo\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:711: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# C:\Users\kopo\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:711: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)

# %%
forecastData
# Out:
#       YEAR MONTH  REGION   SUBSIDIARY   PRODUCT   BRAND      MODEL  \
# 0     2016   JAN  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 1     2016   FEB  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 2     2016   MAR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 3     2016   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 4     2016   MAY  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 5     2016   JUN  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 6     2016   JUL  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 7     2016   AUG  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 8     2016   SEP  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 9     2016   OCT  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 10    2016   NOV  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 11    2016   DEC  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 12    2017   JAN  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 13    2017   FEB  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 14    2017   MAR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 15    2017   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 16    2016   JAN  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 17    2016   FEB  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 18    2016   MAR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 19    2016   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 20    2016   MAY  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 21    2016   JUN  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 22    2016   JUL  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 23    2016   AUG  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 24    2016   SEP  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 25    2016   OCT  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 26    2016   NOV  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 27    2016   DEC  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 28    2017   JAN  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 29    2017   FEB  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# ...    ...   ...     ...          ...       ...     ...        ...
# 1298  2016   MAR  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1299  2016   APR  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1300  2016   MAY  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1301  2016   JUN  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1302  2016   JUL  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1303  2016   AUG  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1304  2016   SEP  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1305  2016   OCT  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1306  2016   NOV  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1307  2016   DEC  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1308  2017   JAN  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1309  2017   FEB  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1310  2017   MAR  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1311  2017   APR  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1312  2016   JAN  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1313  2016   FEB  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1314  2016   MAR  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1315  2016   APR  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1316  2016   MAY  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1317  2016   JUN  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1318  2016   JUL  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1319  2016   AUG  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1320  2016   SEP  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1321  2016   OCT  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1322  2016   NOV  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1323  2016   DEC  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1324  2017   JAN  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1325  2017   FEB  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1326  2017   MAR  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1327  2017   APR  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
#
#      MODEL_GROUP CAPA   FEATURE  SALES_QTY  SALES_PRICE  MON  KNOB YEARMON  \
# 0     MODELG0037  264  FEATURE4          2         1130    1    40  201601
# 1     MODELG0037  264  FEATURE4          4         2529    2    40  201602
# 2     MODELG0037  264  FEATURE4          1          650    3    40  201603
# 3     MODELG0037  264  FEATURE4         12         8108    4    40  201604
# 4     MODELG0037  264  FEATURE4         10         7363    5    40  201605
# 5     MODELG0037  264  FEATURE4         28        19694    6    40  201606
# 6     MODELG0037  264  FEATURE4         29        20460    7    40  201607
# 7     MODELG0037  264  FEATURE4         38        23425    8    40  201608
# 8     MODELG0037  264  FEATURE4         49        29044    9    40  201609
# 9     MODELG0037  264  FEATURE4         52        30669   10    40  201610
# 10    MODELG0037  264  FEATURE4         27        15849   11    40  201611
# 11    MODELG0037  264  FEATURE4         16         9183   12    40  201612
# 12    MODELG0037  264  FEATURE4         29        15906    1    40  201701
# 13    MODELG0037  264  FEATURE4         22        11127    2    40  201702
# 14    MODELG0037  264  FEATURE4         10         4867    3    40  201703
# 15    MODELG0037  264  FEATURE4          7         3938    4    40  201704
# 16    MODELG0038  264  FEATURE4        119        59930    1    40  201601
# 17    MODELG0038  264  FEATURE4        122        61237    2    40  201602
# 18    MODELG0038  264  FEATURE4         69        34324    3    40  201603
# 19    MODELG0038  264  FEATURE4         77        40440    4    40  201604
# 20    MODELG0038  264  FEATURE4         79        41012    5    40  201605
# 21    MODELG0038  264  FEATURE4         96        48530    6    40  201606
# 22    MODELG0038  264  FEATURE4        102        51580    7    40  201607
# 23    MODELG0038  264  FEATURE4         81        41511    8    40  201608
# 24    MODELG0038  264  FEATURE4        135        71870    9    40  201609
# 25    MODELG0038  264  FEATURE4         64        32618   10    40  201610
# 26    MODELG0038  264  FEATURE4         70        35334   11    40  201611
# 27    MODELG0038  264  FEATURE4         60        28922   12    40  201612
# 28    MODELG0038  264  FEATURE4         81        38378    1    40  201701
# 29    MODELG0038  264  FEATURE4         67        32920    2    40  201702
# ...          ...  ...       ...        ...          ...  ...   ...     ...
# 1298  MODELG0737  545  FEATURE6        119       141082    3    40  201603
# 1299  MODELG0737  545  FEATURE6         99       126991    4    40  201604
# 1300  MODELG0737  545  FEATURE6        115       143518    5    40  201605
# 1301  MODELG0737  545  FEATURE6        118       142305    6    40  201606
# 1302  MODELG0737  545  FEATURE6        170       181073    7    40  201607
# 1303  MODELG0737  545  FEATURE6        125       135962    8    40  201608
# 1304  MODELG0737  545  FEATURE6        129       136641    9    40  201609
# 1305  MODELG0737  545  FEATURE6        153       163008   10    40  201610
# 1306  MODELG0737  545  FEATURE6        139       148578   11    40  201611
# 1307  MODELG0737  545  FEATURE6        162       160766   12    40  201612
# 1308  MODELG0737  545  FEATURE6        131       128574    1    40  201701
# 1309  MODELG0737  545  FEATURE6         83        88193    2    40  201702
# 1310  MODELG0737  545  FEATURE6         77        80264    3    40  201703
# 1311  MODELG0737  545  FEATURE6         28        32239    4    40  201704
# 1312  MODELG0791  494  FEATURE6        751       870115    1    40  201601
# 1313  MODELG0791  494  FEATURE6        523       594271    2    40  201602
# 1314  MODELG0791  494  FEATURE6        439       513308    3    40  201603
# 1315  MODELG0791  494  FEATURE6        508       639444    4    40  201604
# 1316  MODELG0791  494  FEATURE6        554       676879    5    40  201605
# 1317  MODELG0791  494  FEATURE6        558       657790    6    40  201606
# 1318  MODELG0791  494  FEATURE6        601       682502    7    40  201607
# 1319  MODELG0791  494  FEATURE6        545       651051    8    40  201608
# 1320  MODELG0791  494  FEATURE6        409       428111    9    40  201609
# 1321  MODELG0791  494  FEATURE6        303       312733   10    40  201610
# 1322  MODELG0791  494  FEATURE6        224       276179   11    40  201611
# 1323  MODELG0791  494  FEATURE6        216       248188   12    40  201612
# 1324  MODELG0791  494  FEATURE6         19        19136    1    40  201701
# 1325  MODELG0791  494  FEATURE6          8         8710    2    40  201702
# 1326  MODELG0791  494  FEATURE6          5         5272    3    40  201703
# 1327  MODELG0791  494  FEATURE6          7         7225    4    40  201704
#
#          PREDICT
# 0      15.847947
# 1       7.664328
# 2       7.703076
# 3       9.869959
# 4       7.727425
# 5      10.243098
# 6       6.733993
# 7       8.236410
# 8       7.790297
# 9      12.010354
# 10      7.033068
# 11     46.453029
# 12     15.847947
# 13      7.664328
# 14      7.703076
# 15      9.869959
# 16     93.843730
# 17     95.389412
# 18    104.817957
# 19    129.428890
# 20     90.642759
# 21    131.077018
# 22    106.467760
# 23    113.939274
# 24    136.248936
# 25     92.170167
# 26    113.013158
# 27    126.770871
# 28     93.843730
# 29     95.389412
# ...          ...
# 1298   85.475556
# 1299   98.439613
# 1300  133.425448
# 1301  178.338927
# 1302  178.241625
# 1303  174.289670
# 1304  203.777018
# 1305  223.145131
# 1306  253.901684
# 1307  188.578811
# 1308  119.675317
# 1309  105.053822
# 1310   85.475556
# 1311   98.439613
# 1312  621.230000
# 1313  578.848865
# 1314  525.072816
# 1315  603.965115
# 1316  647.896495
# 1317  733.724881
# 1318  733.521395
# 1319  714.553162
# 1320  730.649976
# 1321  803.128677
# 1322  940.000000
# 1323  885.410649
# 1324  621.230000
# 1325  578.848865
# 1326  525.072816
# 1327  603.965115
#
# [1328 rows x 16 columns]

# %% [markdown]
# ### 4. 그룹바이 디버깅 시각화

# %%
groupNewcustomerData = forecastData.groupby(groupKey)

len(groupNewcustomerData)

#14개의 그룹중 첫번째 그룹을 가져옴
eachGroup = groupNewcustomerData.get_group(list(groupNewcustomerData.groups)[27])

#치솟는 값이 있어서 시각화가힘들어져 걸러냄
eachGroup1 =eachGroup[eachGroup['PREDICT']<2000]

#실제값과 예측값 시각화 비교
plt.plot(eachGroup1['YEARMON'],eachGroup1['SALES_QTY'])
plt.plot(eachGroup1['YEARMON'],eachGroup1['PREDICT'])
plt.show()

# %% [markdown]
# ### 5. 정확도 측정

# %%
mean_squared_error(forecastData['SALES_QTY'], forecastData['PREDICT'])
# Out:
# 80908.24523633248

# %%
mean_absolute_error(forecastData['SALES_QTY'], forecastData['PREDICT'])
# Out:
# 143.62598457080233

# %% [markdown]
# ### 6. csv로 내보내기

# %%
#forecastData.to_csv('ets.csv',index = False)
