# %%
from ultralytics import YOLO
import cv2
import math 
# start webcam
capture = cv2.VideoCapture(0)

# capture.set(3, 640)
# capture.set(4, 480)

# model
model = YOLO("yolo-Weights/yolov8n.pt")

# object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]


while (capture.isOpened):
    ret, frame = capture.read()
    # results = model(img, stream=True)
    results = model(frame)[0]

    # coordinates
    for r in results:
        boxes = r.boxes
        # print("r진입",r)

        for box in boxes:
            # print("box진ㅇ비",box)
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(frame, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', frame)
    key = cv2.waitKey(33)#1) & 0xFF
    # esc 종료
    if key == 27:
        break


capture.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 28.9ms
# Speed: 4.0ms preprocess, 28.9ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.89
# Class name --> person
#
# 0: 480x640 1 person, 1 chair, 25.9ms
# Speed: 4.0ms preprocess, 25.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.3
# Class name --> chair
#
# 0: 480x640 1 person, 25.9ms
# Speed: 3.0ms preprocess, 25.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
#
# 0: 480x640 1 person, 1 chair, 24.9ms
# Speed: 2.0ms preprocess, 24.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.28
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 23.9ms
# Speed: 3.0ms preprocess, 23.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.28
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 23.9ms
# Speed: 3.0ms preprocess, 23.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 24.9ms
# Speed: 2.0ms preprocess, 24.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 25.9ms
# Speed: 4.0ms preprocess, 25.9ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.27
# Class name --> chair
#
# 0: 480x640 1 person, 25.9ms
# Speed: 4.0ms preprocess, 25.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
#
# 0: 480x640 1 person, 1 chair, 26.0ms
# Speed: 4.0ms preprocess, 26.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.31
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 31.0ms
# Speed: 4.0ms preprocess, 31.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 24.9ms
# Speed: 2.0ms preprocess, 24.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
#
# 0: 480x640 1 person, 25.0ms
# Speed: 3.0ms preprocess, 25.0ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 24.9ms
# Speed: 2.0ms preprocess, 24.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.89
# Class name --> person
#
# 0: 480x640 1 person, 24.9ms
# Speed: 2.0ms preprocess, 24.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 28.9ms
# Speed: 3.0ms preprocess, 28.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 25.9ms
# Speed: 3.0ms preprocess, 25.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 26.9ms
# Speed: 3.0ms preprocess, 26.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 25.9ms
# Speed: 3.0ms preprocess, 25.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 25.9ms
# Speed: 3.0ms preprocess, 25.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 24.9ms
# Speed: 3.0ms preprocess, 24.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 27.9ms
# Speed: 3.0ms preprocess, 27.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 24.9ms
# Speed: 2.0ms preprocess, 24.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 24.9ms
# Speed: 3.0ms preprocess, 24.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.89
# Class name --> person
#
# 0: 480x640 1 person, 25.9ms
# Speed: 3.0ms preprocess, 25.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.89
# Class name --> person
#
# 0: 480x640 1 person, 23.9ms
# Speed: 3.0ms preprocess, 23.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.89
# Class name --> person
#
# 0: 480x640 1 person, 26.0ms
# Speed: 4.0ms preprocess, 26.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 25.0ms
# Speed: 3.0ms preprocess, 25.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
#
# 0: 480x640 1 person, 23.9ms
# Speed: 3.0ms preprocess, 23.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.89
# Class name --> person
#
# 0: 480x640 1 person, 25.9ms
# Speed: 3.0ms preprocess, 25.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.89
# Class name --> person
#
# 0: 480x640 1 person, 24.9ms
# Speed: 2.0ms preprocess, 24.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.89
# Class name --> person
#
# 0: 480x640 1 person, 23.9ms
# Speed: 3.0ms preprocess, 23.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.89
# Class name --> person
#
# 0: 480x640 1 person, 24.9ms
# Speed: 3.0ms preprocess, 24.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
#
# 0: 480x640 1 person, 24.9ms
# Speed: 2.0ms preprocess, 24.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.89
# Class name --> person
#
# 0: 480x640 1 person, 25.7ms
# Speed: 3.0ms preprocess, 25.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.89
# Class name --> person
#
# 0: 480x640 1 person, 23.9ms
# Speed: 3.0ms preprocess, 23.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.89
# Class name --> person
#
# 0: 480x640 1 person, 24.9ms
# Speed: 3.0ms preprocess, 24.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
#
# 0: 480x640 1 person, 24.9ms
# Speed: 3.0ms preprocess, 24.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
#
# 0: 480x640 1 person, 24.9ms
# Speed: 3.0ms preprocess, 24.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
#
# 0: 480x640 1 person, 24.9ms
# Speed: 3.0ms preprocess, 24.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
#
# 0: 480x640 1 person, 24.9ms
# Speed: 3.0ms preprocess, 24.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
#
# 0: 480x640 1 person, 24.9ms
# Speed: 3.0ms preprocess, 24.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
#
# 0: 480x640 1 person, 24.9ms
# Speed: 3.0ms preprocess, 24.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
#
# 0: 480x640 1 person, 23.9ms
# Speed: 2.0ms preprocess, 23.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
#
# 0: 480x640 1 person, 25.9ms
# Speed: 4.0ms preprocess, 25.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
#
# 0: 480x640 1 person, 24.9ms
# Speed: 2.0ms preprocess, 24.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 33.9ms
# Speed: 5.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 31.9ms
# Speed: 3.0ms preprocess, 31.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 34.8ms
# Speed: 7.0ms preprocess, 34.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 34.0ms
# Speed: 3.0ms preprocess, 34.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
#
# 0: 480x640 1 person, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 44.9ms
# Speed: 8.0ms preprocess, 44.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
#
# 0: 480x640 1 person, 1 chair, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
#
# 0: 480x640 1 person, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 2 persons, 1 cell phone, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.3
# Class name --> cell phone
#
# 0: 480x640 3 persons, 32.7ms
# Speed: 3.0ms preprocess, 32.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
#
# 0: 480x640 1 person, 33.5ms
# Speed: 3.0ms preprocess, 33.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
#
# 0: 480x640 1 person, 32.8ms
# Speed: 3.1ms preprocess, 32.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.64
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.68
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.7
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.6
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.46
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.38
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.4ms
# Speed: 3.0ms preprocess, 33.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.48
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.47
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.46
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 31.9ms
# Speed: 4.0ms preprocess, 31.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.47
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.44
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.45
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.45
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.44
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.47
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 2.9ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.45
# Class name --> cell phone
#
# 0: 480x640 1 person, 2 cell phones, 36.9ms
# Speed: 5.0ms preprocess, 36.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.47
# Class name --> cell phone
# Confidence ---> 0.31
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 6.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.46
# Class name --> cell phone
#
# 0: 480x640 1 person, 2 cell phones, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.45
# Class name --> cell phone
# Confidence ---> 0.34
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.52
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.52
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.26
# Class name --> cell phone
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
#
# 0: 480x640 1 person, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
#
# 0: 480x640 1 person, 33.1ms
# Speed: 3.0ms preprocess, 33.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 31.9ms
# Speed: 3.0ms preprocess, 31.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 38.9ms
# Speed: 6.0ms preprocess, 38.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
#
# 0: 480x640 1 person, 37.4ms
# Speed: 7.0ms preprocess, 37.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
#
# 0: 480x640 1 person, 32.8ms
# Speed: 3.0ms preprocess, 32.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
#
# 0: 480x640 1 person, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
#
# 0: 480x640 1 person, 31.9ms
# Speed: 3.0ms preprocess, 31.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
#
# 0: 480x640 1 person, 34.9ms
# Speed: 8.0ms preprocess, 34.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
#
# 0: 480x640 1 person, 1 chair, 35.9ms
# Speed: 4.0ms preprocess, 35.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
#
# 0: 480x640 1 person, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
#
# 0: 480x640 1 person, 31.9ms
# Speed: 2.0ms preprocess, 31.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
#
# 0: 480x640 1 person, 1 couch, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.28
# Class name --> sofa
#
# 0: 480x640 1 person, 1 couch, 31.9ms
# Speed: 3.0ms preprocess, 31.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.3
# Class name --> sofa
#
# 0: 480x640 1 person, 1 couch, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.28
# Class name --> sofa
#
# 0: 480x640 1 person, 2 chairs, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.35
# Class name --> chair
# Confidence ---> 0.33
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.49
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.72
# Class name --> chair
#
# 0: 480x640 1 person, 2 chairs, 31.9ms
# Speed: 3.0ms preprocess, 31.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.69
# Class name --> chair
# Confidence ---> 0.26
# Class name --> chair
#
# 0: 480x640 1 person, 2 chairs, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.53
# Class name --> chair
# Confidence ---> 0.5
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.63
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.86
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.69
# Class name --> chair
#
# 0: 480x640 1 person, 2 chairs, 32.0ms
# Speed: 3.0ms preprocess, 32.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.56
# Class name --> chair
# Confidence ---> 0.26
# Class name --> chair
#
# 0: 480x640 1 person, 2 chairs, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.6
# Class name --> chair
# Confidence ---> 0.34
# Class name --> chair
#
# 0: 480x640 1 person, 2 chairs, 32.5ms
# Speed: 3.0ms preprocess, 32.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.59
# Class name --> chair
# Confidence ---> 0.36
# Class name --> chair
#
# 0: 480x640 1 person, 2 chairs, 34.9ms
# Speed: 5.0ms preprocess, 34.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.61
# Class name --> chair
# Confidence ---> 0.38
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.57
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.52
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.58
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 37.9ms
# Speed: 7.0ms preprocess, 37.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.61
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.41
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.4
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 33.8ms
# Speed: 3.0ms preprocess, 33.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.32
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 33.5ms
# Speed: 3.0ms preprocess, 33.5ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.46
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.41
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.53
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.46
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.49
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.5
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 39.9ms
# Speed: 7.0ms preprocess, 39.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.51
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.53
# Class name --> chair
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
#
# 0: 480x640 1 person, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.37
# Class name --> cell phone
#
# 0: 480x640 1 person, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
#
# 0: 480x640 1 person, 1 cell phone, 33.0ms
# Speed: 4.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.27
# Class name --> cell phone
#
# 0: 480x640 1 person, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
#
# 0: 480x640 1 person, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
#
# 0: 480x640 1 person, 1 cell phone, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.37
# Class name --> cell phone
#
# 0: 480x640 1 person, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.9
# Class name --> person
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.33
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 remote, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.39
# Class name --> remote
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.45
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 2.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.42
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.44
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.37
# Class name --> cell phone
# Confidence ---> 0.3
# Class name --> remote
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.81
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.82
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.83
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.87
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.85
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.86
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.82
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.85
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.87
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.79
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.76
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 4.0ms preprocess, 33.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.75
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.78
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.1ms preprocess, 32.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.73
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.57
# Class name --> cell phone
# Confidence ---> 0.32
# Class name --> remote
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.47
# Class name --> remote
# Confidence ---> 0.32
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.34
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.49
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 remote, 31.9ms
# Speed: 3.0ms preprocess, 31.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.45
# Class name --> remote
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.47
# Class name --> cell phone
# Confidence ---> 0.28
# Class name --> remote
#
# 0: 480x640 1 person, 1 remote, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.47
# Class name --> cell phone
# Confidence ---> 0.34
# Class name --> remote
#
# 0: 480x640 1 person, 1 cell phone, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.46
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.6
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.75
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.83
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.64
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.71
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.79
# Class name --> cell phone
#
# 0: 480x640 1 person, 2 cell phones, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.8
# Class name --> cell phone
# Confidence ---> 0.26
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.86
# Class name --> cell phone
#
# 0: 480x640 1 person, 2 cell phones, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.6
# Class name --> cell phone
# Confidence ---> 0.29
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.65
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.79
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.87
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.85
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 chair, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.85
# Class name --> cell phone
# Confidence ---> 0.28
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.87
# Class name --> cell phone
# Confidence ---> 0.3
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 2 cell phones, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.87
# Class name --> cell phone
# Confidence ---> 0.31
# Class name --> cell phone
# Confidence ---> 0.27
# Class name --> chair
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.9
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.89
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.78
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.66
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.69
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.0ms
# Speed: 4.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.76
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.72
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.67
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.0ms
# Speed: 4.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.69
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.68
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.63
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.69
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.0ms
# Speed: 4.0ms preprocess, 33.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.72
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.78
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.76
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.78
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.7
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.48
# Class name --> cell phone
#
# 0: 480x640 1 person, 2 cell phones, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.41
# Class name --> cell phone
# Confidence ---> 0.31
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.27
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.37
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.32
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.6ms
# Speed: 3.0ms preprocess, 32.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.71
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.64
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.56
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.8ms
# Speed: 3.1ms preprocess, 32.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.48
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.46
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.0ms
# Speed: 4.0ms preprocess, 33.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.56
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.51
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# ...
# 0: 480x640 1 person, 1 cell phone, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.35
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 laptop, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.26
# Class name --> laptop
#
# 0: 480x640 1 person, 1 cell phone, 33.4ms
# Speed: 3.0ms preprocess, 33.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.43
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.63
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.63
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.68
# Class name --> cell phone
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.45
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.96
# Class name --> person
# Confidence ---> 0.42
# Class name --> cell phone
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.4
# Class name --> cell phone
#
# 0: 480x640 1 person, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.36
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.26
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.33
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.96
# Class name --> person
# Confidence ---> 0.55
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.96
# Class name --> person
# Confidence ---> 0.36
# Class name --> cell phone
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.96
# Class name --> person
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.96
# Class name --> person
# Confidence ---> 0.34
# Class name --> cell phone
#
# 0: 480x640 1 person, 2 cell phones, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.77
# Class name --> cell phone
# Confidence ---> 0.28
# Class name --> cell phone
#
# 0: 480x640 1 person, 2 cell phones, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.96
# Class name --> person
# Confidence ---> 0.37
# Class name --> cell phone
# Confidence ---> 0.35
# Class name --> cell phone
#
# 0: 480x640 1 person, 2 cell phones, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.96
# Class name --> person
# Confidence ---> 0.46
# Class name --> cell phone
# Confidence ---> 0.43
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.89
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.91
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 2.0ms preprocess, 32.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.96
# Class name --> cell phone
# Confidence ---> 0.95
# Class name --> person
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.96
# Class name --> cell phone
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> cell phone
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.96
# Class name --> cell phone
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.96
# Class name --> cell phone
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 1 cell phone, 32.8ms
# Speed: 3.1ms preprocess, 32.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.96
# Class name --> cell phone
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.97
# Class name --> cell phone
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.97
# Class name --> cell phone
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.96
# Class name --> cell phone
# Confidence ---> 0.92
# Class name --> person
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.96
# Class name --> cell phone
# Confidence ---> 0.92
# Class name --> person
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> cell phone
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.9
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.96
# Class name --> person
# Confidence ---> 0.85
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.88
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.88
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.91
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.83
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.81
# Class name --> cell phone
#
# 0: 480x640 1 person, 1 cell phone, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.33
# Class name --> cell phone
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
#
# 0: 480x640 1 person, 3 chairs, 32.8ms
# Speed: 3.1ms preprocess, 32.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.45
# Class name --> chair
# Confidence ---> 0.36
# Class name --> chair
# Confidence ---> 0.28
# Class name --> chair
#
# 0: 480x640 1 person, 2 chairs, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.42
# Class name --> chair
# Confidence ---> 0.35
# Class name --> chair
#
# 0: 480x640 1 person, 2 chairs, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.44
# Class name --> chair
# Confidence ---> 0.37
# Class name --> chair
#
# 0: 480x640 1 person, 2 chairs, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.35
# Class name --> chair
# Confidence ---> 0.34
# Class name --> chair
#
# 0: 480x640 1 person, 2 chairs, 31.9ms
# Speed: 3.0ms preprocess, 31.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.36
# Class name --> chair
# Confidence ---> 0.33
# Class name --> chair
#
# 0: 480x640 1 person, 2 chairs, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.39
# Class name --> chair
# Confidence ---> 0.34
# Class name --> chair
#
# 0: 480x640 1 person, 2 chairs, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.36
# Class name --> chair
# Confidence ---> 0.29
# Class name --> chair
#
# 0: 480x640 1 person, 2 chairs, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.32
# Class name --> chair
# Confidence ---> 0.28
# Class name --> chair
#
# 0: 480x640 1 person, 2 chairs, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.34
# Class name --> chair
# Confidence ---> 0.29
# Class name --> chair
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
#
# 0: 480x640 1 person, 2 chairs, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.27
# Class name --> chair
# Confidence ---> 0.26
# Class name --> chair
#
# 0: 480x640 1 person, 2 chairs, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.3
# Class name --> chair
# Confidence ---> 0.27
# Class name --> chair
#
# 0: 480x640 1 person, 1 chair, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.28
# Class name --> chair
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.91
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 4.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.92
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
#
# 0: 480x640 1 person, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
#
# 0: 480x640 1 person, 33.4ms
# Speed: 2.0ms preprocess, 33.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.95
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
#
# 0: 480x640 1 person, 1 chair, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.29
# Class name --> chair
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
#
# 0: 480x640 1 person, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Confidence ---> 0.94
# Class name --> person
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 70
#      66     if key == 27:
#      67         break
# ---> 70 cap.release()
#      71 cv2.destroyAllWindows()
#
# NameError: name 'cap' is not defined
