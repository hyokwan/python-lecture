# %% [markdown]
# ### Data load from web

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp')
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')
#print(bs)

# html 구조 태그로 가져오기
title = bs.find("title").text
wf = bs.find("wf").text
print(title)
print(wf)
# Out:
# 기상청 육상 중기예보
# 17~18일은 기압골의 영향으로 제주도에, 17일은 동풍의 영향으로 강원영동에 비가 오겠습니다.<br />그 밖의 날은 고기압의 영향으로 대체로 맑은 날이 많겠습니다.<br />기온은 평년(최저기온: -4~7℃, 최고기온: 8~15℃)보다 18일까지는 조금 높겠으나, 19일부터는 비슷하거나 조금 낮겠습니다.<br />강수량은 평년(1~3mm)보다 적겠으나, 강원영동과 제주도는 비슷하겠습니다.

# %% [markdown]
# ### 1. 태그 찾기 - find

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.112.251:3333/quiz')
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

# html 부분구조 가져오기
find_tag = bs.findAll("div")
print(find_tag)
# Out:
# [<div class="class_py_quiz" id="id_py_quiz">
# <h1>Python 퀴즈 </h1>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSfeEFwHayEdRBMYUOBIVb1ykAW3i-slN4SIgfjMIUIcU7c_3g/viewform?usp=sf_link"> 5 Pandas 데이터프레임 조작하기 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSfZNSgcQ4zEcK_R37iX36UIk4K8amZc6ZslwFo2r1zpPdJnjw/viewform?usp=sf_link"> 4 파이썬 제어문 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSegE6KvpsfCDIInw8VjTS1Bt8Kk-vr5NoRfVTMOnNC3CYZfgA/viewform?usp=sf_link"> 3 파이썬 자료형 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLScz8L4Q2ewstEK1Invu3RrS0uEhQIKwhXImj60Ua_6SBi-m-g/viewform?usp=sf_link"> 2 파이썬 머신러닝 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSdZdofk88EAJ9-x28zDo3eNYxYo1AqQL3fzdk76K-fKdLDtCA/viewform?usp=sf_link"> 1 파이썬 시작하기 </a>
# <p></p>
# </div>, <div class="class_db_quiz" id="id_db_quiz">
# <h1>데이터베이스 퀴즈 </h1>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSff5TjqUq9u-jRxYZvTdB7k-N0AEjx0_WSIcLZCBfFiEfoRUA/viewform?usp=sf_link"> 6/12 오라클 Join 퀴즈 </a>
# </div>]

# %% [markdown]
# ### 2. 속성 찾기 - find

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.112.251:3333/quiz')
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

# html 태그 속성으로 찾기
find_attr = bs.find("div",{"id":"id_py_quiz"})
print(find_attr)
# Out:
# <div class="class_py_quiz" id="id_py_quiz">
# <h1>Python 퀴즈 </h1>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSfeEFwHayEdRBMYUOBIVb1ykAW3i-slN4SIgfjMIUIcU7c_3g/viewform?usp=sf_link"> 5 Pandas 데이터프레임 조작하기 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSfZNSgcQ4zEcK_R37iX36UIk4K8amZc6ZslwFo2r1zpPdJnjw/viewform?usp=sf_link"> 4 파이썬 제어문 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSegE6KvpsfCDIInw8VjTS1Bt8Kk-vr5NoRfVTMOnNC3CYZfgA/viewform?usp=sf_link"> 3 파이썬 자료형 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLScz8L4Q2ewstEK1Invu3RrS0uEhQIKwhXImj60Ua_6SBi-m-g/viewform?usp=sf_link"> 2 파이썬 머신러닝 </a>
# <p></p>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSdZdofk88EAJ9-x28zDo3eNYxYo1AqQL3fzdk76K-fKdLDtCA/viewform?usp=sf_link"> 1 파이썬 시작하기 </a>
# <p></p>
# </div>

# %% [markdown]
# ### 3. 태그내 dom 부분구조 찾기

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.112.251:3333/quiz')
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

# html 부분구조 가져오기
find_attr = bs.find("div",{"id":"id_py_quiz"})
find_part = find_attr.find("a")
print(find_part)
# Out:
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSfeEFwHayEdRBMYUOBIVb1ykAW3i-slN4SIgfjMIUIcU7c_3g/viewform?usp=sf_link"> 5 Pandas 데이터프레임 조작하기 </a>

# %% [markdown]
# ### 4. DOM 구조 내 속성 찾기

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.112.251:3333/quiz')
resp.encoding='utf-8'
html = resp.text
bs = bs4.BeautifulSoup(html, 'html.parser')
# html 부분구조 가져오기
find_part = bs.find("div",{"id":"id_db_quiz"})
# 링크내 속성 가져오기
link = find_part.find("a")
print(find_part.find("a").attrs['href'])
# Out:
# https://docs.google.com/forms/d/e/1FAIpQLSff5TjqUq9u-jRxYZvTdB7k-N0AEjx0_WSIcLZCBfFiEfoRUA/viewform?usp=sf_link

# %% [markdown]
# ### 실습 링크 속성 추출하기

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.112.251:3333/quiz')
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

# html 부분구조 가져오기
a_links = bs.findAll("a")
for a in a_links:
    #a 링크 내 href 속성
    href=a.attrs["href"]
    #a 링크 텍스트
    text = a.text
    if(href.startswith("/")):
        continue;
    print(text, ">", href)
# Out:
#  5 Pandas 데이터프레임 조작하기  > https://docs.google.com/forms/d/e/1FAIpQLSfeEFwHayEdRBMYUOBIVb1ykAW3i-slN4SIgfjMIUIcU7c_3g/viewform?usp=sf_link
#  4 파이썬 제어문  > https://docs.google.com/forms/d/e/1FAIpQLSfZNSgcQ4zEcK_R37iX36UIk4K8amZc6ZslwFo2r1zpPdJnjw/viewform?usp=sf_link
#  3 파이썬 자료형  > https://docs.google.com/forms/d/e/1FAIpQLSegE6KvpsfCDIInw8VjTS1Bt8Kk-vr5NoRfVTMOnNC3CYZfgA/viewform?usp=sf_link
#  2 파이썬 머신러닝  > https://docs.google.com/forms/d/e/1FAIpQLScz8L4Q2ewstEK1Invu3RrS0uEhQIKwhXImj60Ua_6SBi-m-g/viewform?usp=sf_link
#  1 파이썬 시작하기  > https://docs.google.com/forms/d/e/1FAIpQLSdZdofk88EAJ9-x28zDo3eNYxYo1AqQL3fzdk76K-fKdLDtCA/viewform?usp=sf_link
#  6/12 오라클 Join 퀴즈  > https://docs.google.com/forms/d/e/1FAIpQLSff5TjqUq9u-jRxYZvTdB7k-N0AEjx0_WSIcLZCBfFiEfoRUA/viewform?usp=sf_link

# %% [markdown]
# ### 디버깅

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.112.251:3333/quiz')
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

# html 부분구조 가져오기
a_links = bs.findAll("a")

# %%
a = a_links[10]

# %%
href=a.attrs["href"]
print(href)
text = a.text
print(text)
# Out:
# https://docs.google.com/forms/d/e/1FAIpQLSfZNSgcQ4zEcK_R37iX36UIk4K8amZc6ZslwFo2r1zpPdJnjw/viewform?usp=sf_link
#  4 파이썬 제어문

# %%
#if(href.startswith("/")):
#    continue;
print(text, ">", href)
# Out:
#  4 파이썬 제어문  > https://docs.google.com/forms/d/e/1FAIpQLSfZNSgcQ4zEcK_R37iX36UIk4K8amZc6ZslwFo2r1zpPdJnjw/viewform?usp=sf_link

# %% [markdown]
# ### Select 편

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get("http://finance.naver.com/marketindex/")
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

# 데이터 추출하기
price = bs.select_one("div.head_info > span.value").string
print("usd/krw= ", price)

# 리스트 초기화 및 데이터 담기
outList = []
outList.append(price)

# 리스트 pandas 데이터 프레임으로 변환 및 컬럼 정의
outDf = pd.DataFrame(outList)
outDf.columns = ['title']
# CSV 파일로 저장, encondig 한글깨짐 방지
#outDf.to_csv("../dataset/webData.csv", encoding='utf-8-sig',index=False)
outDf
# Out:
# usd/krw=  1,133.00
#       title
# 0  1,133.00

# %% [markdown]
# ### 데이터 불러오기 from web [select] - id

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.112.251:3333/quiz')
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, "html.parser")
# div에서 id가 id_db_quiz인것만 추출
divs = bs.select("div#id_db_quiz")
print(divs)
# Out:
# [<div class="class_db_quiz" id="id_db_quiz">
# <h1>데이터베이스 퀴즈 </h1>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSff5TjqUq9u-jRxYZvTdB7k-N0AEjx0_WSIcLZCBfFiEfoRUA/viewform?usp=sf_link"> 6/12 오라클 Join 퀴즈 </a>
# </div>]

# %% [markdown]
# ### 데이터 불러오기 from web [select] - class

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.112.251:3333/quiz')
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, "html.parser")
# div에서 id가 id_db_quiz인것만 추출
divs = bs.select("div.class_db_quiz")
print(divs)
# Out:
# [<div class="class_db_quiz" id="id_db_quiz">
# <h1>데이터베이스 퀴즈 </h1>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSff5TjqUq9u-jRxYZvTdB7k-N0AEjx0_WSIcLZCBfFiEfoRUA/viewform?usp=sf_link"> 6/12 오라클 Join 퀴즈 </a>
# </div>]

# %% [markdown]
# ### 데이터 불러오기 from web [select] - one or many

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get("http://13.209.112.251:3333/quiz")
resp.encoding='utf-8'
html = resp.text
bs = bs4.BeautifulSoup(html, "html.parser")
# div에서 class가 class_db_quiz인것만 추출 (1개)
seone = bs.select_one("div.class_db_quiz > a").string    
# div에서 class가 class_db_quiz인것만 추출 (다수)
divs = bs.select("div.class_db_quiz > a")
for li in divs:
    print(li.string)
# Out:
#  6/12 오라클 Join 퀴즈

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('http://13.209.112.251:3333/maps/gitList')
resp.encoding='utf-8'
html = resp.text
bs = bs4.BeautifulSoup(html, 'html.parser')

# html 부분구조 가져오기
columns=bs.select('table > tr > th')

gitColumnlist=[]
for column in columns:
    gitColumnlist.append(column.text)
df=pd.DataFrame(columns=gitColumnlist)
df
# Out:
# Empty DataFrame
# Columns: [순번, 학생 이름, GIT 주소(뒷부분), 수정]
# Index: []

# %%
contents=bs.select('table > tr#gitContents')
dfcontent=[]
alldfcontents=[]

for content in contents:
    tds=content.findAll("td")
    for td in tds:
        dfcontent.append(td.text)
    alldfcontents.append(dfcontent)
    dfcontent=[]
df=pd.DataFrame(columns=gitColumnlist, data=alldfcontents, index=None)
df.columns=["no","std_name","git_address","edit"]
finalDf = df[["no","std_name","git_address"]]
finalDf.to_csv("d:/git_address.csv",index=False)
finalDf.head()
# Out:
#   no        std_name git_address
# 0  1  KIM GANG RYONG      wovmxl
# 1  2     KIM DO WOON   dowoonkim
# 2  3     KIM EUI JIN       doogn
# 3  4   NOH YOUNG WOO   ppoocoder
# 4  5  PARK SEUNG JIN      tmdwls

# %% [markdown]
# ### 홀리데이 크롤링

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('https://www.timeanddate.com/holidays/south-korea')
resp.encoding='utf-8'
html = resp.text
bs = bs4.BeautifulSoup(html, 'html.parser')

contents=bs.select('table  > tbody > tr')
dfcontent=[]
alldfcontents=[]

for content in contents:
    tds=content.findAll("td")
    for td in tds:
        if(td.text=="None"):
            continue;
        dfcontent.append(td.text)
    alldfcontents.append(dfcontent)
    dfcontent=[]
df=pd.DataFrame(data=alldfcontents)
df
# Out:
#       0                              1                 2
# 0   월요일                 New Year's Day    Public Holiday
# 1   금요일     2018 Winter Olympics start        Observance
# 2   수요일                Valentine's Day        Observance
# 3   목요일                Seollal Holiday    Public Holiday
# 4   금요일                        Seollal    Public Holiday
# 5   토요일                Seollal Holiday    Public Holiday
# 6   일요일       2018 Winter Olympics end        Observance
# 7   목요일      Independence Movement Day  National holiday
# 8   금요일  2018 Winter Paralympics start        Observance
# 9   일요일    2018 Winter Paralympics end        Observance
# 10  수요일                  March Equinox            Season
# 11  목요일                      Arbor Day        Observance
# 12  화요일                      Labor Day      Bank Holiday
# 13  토요일                 Children's Day    Public Holiday
# 14  월요일        Children's Day observed    Public Holiday
# 15  화요일                   Parents' Day        Observance
# 16  화요일                  Teacher's Day        Observance
# 17  화요일              Buddha's Birthday    Public Holiday
# 18  수요일                   Memorial Day    Public Holiday
# 19  수요일             Local Election Day    Public Holiday
# 20  목요일                  June Solstice            Season
# 21  화요일               Constitution Day        Observance
# 22  수요일                 Liberation Day  National holiday
# 23  일요일              September Equinox            Season
# 24  일요일                Chuseok Holiday    Public Holiday
# 25  월요일                        Chuseok    Public Holiday
# 26  화요일                Chuseok Holiday    Public Holiday
# 27  수요일                Chuseok Holiday    Public Holiday
# 28  월요일               Armed Forces Day        Observance
# 29  수요일        National Foundation Day  National holiday
# 30  화요일       Hangeul Proclamation Day  National holiday
# 31  수요일                      Halloween        Observance
# 32  토요일              December Solstice            Season
# 33  월요일                  Christmas Eve        Observance
# 34  화요일                  Christmas Day    Public Holiday
# 35  월요일                 New Year's Eve        Observance

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get('https://www.timeanddate.com/holidays/south-korea')
resp.encoding='utf-8'
html = resp.text
bs = bs4.BeautifulSoup(html, 'html.parser')

contents=bs.select('table  > tbody > tr')
dfcontent=[]
alldfcontents=[]

for content in contents:
    tds=content.findAll("td")
    for td in tds:
        if(td.text=="None"):
            continue;
        dfcontent.append(td.text)
    alldfcontents.append(dfcontent)
    dfcontent=[]
df=pd.DataFrame(data=alldfcontents)
df.head()
# Out:
#      0                           1               2
# 0  월요일              New Year's Day  Public Holiday
# 1  금요일  2018 Winter Olympics start      Observance
# 2  수요일             Valentine's Day      Observance
# 3  목요일             Seollal Holiday  Public Holiday
# 4  금요일                     Seollal  Public Holiday

# %% [markdown]
# # 연휴전부 웹 스크랩

# %% [markdown]
# ### 1. 라이브러리 선언

# %%
import requests, bs4, pandas as pd, numpy as np

# %% [markdown]
# ### 2. 웹페이지 소스 가져오기

# %%
#웹페이지 html 소스 가져오기
resp = requests.get('https://www.timeanddate.com/holidays/south-korea')
resp.encoding='utf-8'
html = resp.text
bs = bs4.BeautifulSoup(html, 'html.parser')

# %% [markdown]
# ### 3. 기본정보 스크랩

# %%
contents=bs.select('table  > tbody > tr')
dfcontent=[]
alldfcontents=[]

# %% [markdown]
# ### 4. 데이터 마이닝

# %%
for content in contents:
    tds=content.findAll("td")
    ths=content.findAll("th")
    for th in ths:
        dfcontent.append(th.text)
    for td in tds:
        dfcontent.append(td.text)
    alldfcontents.append(dfcontent)
    dfcontent=[]

# %% [markdown]
# ### 5. 정제된 데이터 셋 생성

# %%
df=pd.DataFrame(data=alldfcontents)

df.columns = ["DATE","WEEK","HOLIDAY_NAME","HOLIDAY_TYPE"]
df.head()
# Out:
#      DATE WEEK                HOLIDAY_NAME    HOLIDAY_TYPE
# 0   1월 1일  월요일              New Year's Day  Public Holiday
# 1   2월 9일  금요일  2018 Winter Olympics start      Observance
# 2  2월 14일  수요일             Valentine's Day      Observance
# 3  2월 15일  목요일             Seollal Holiday  Public Holiday
# 4  2월 16일  금요일                     Seollal  Public Holiday
