# %% [markdown]
# ### Data load from web

# %%
import requests, bs4
import pandas as pd

#웹페이지 html 소스 가져오기
resp = requests.get("https://sparkkorea.com/퀴즈/")
resp.encoding='utf-8'
html = resp.text
bs = bs4.BeautifulSoup(html, 'html.parser')
bs
# Out:
# <!DOCTYPE html>
#
# <html lang="ko-KR">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://sparkkorea.com/xmlrpc.php" rel="pingback"/>
# <title>퀴즈 – 폴리텍대  스마트금융과</title>
# <!-- Async WordPress.com Remote Login -->
# <script id="wpcom_remote_login_js">
# var wpcom_remote_login_extra_auth = '';
# function wpcom_remote_login_remove_dom_node_id( element_id ) {
# 	var dom_node = document.getElementById( element_id );
# 	if ( dom_node ) { dom_node.remove(); }
# }
# function wpcom_remote_login_remove_dom_node_classes( class_name ) {
# 	var dom_nodes = document.querySelectorAll( '.' + class_name );
# 	for ( var i = 0; i < dom_nodes.length; i++ ) {
# 		dom_nodes[i].remove();
# 	}
# }
# function wpcom_remote_login_final_cleanup() {
# 	wpcom_remote_login_remove_dom_node_classes( "wpcom_remote_login_msg" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_remote_login_key" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_remote_login_validate" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_remote_login_js" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_request_access_iframe" );
# 	wpcom_remote_login_remove_dom_node_id( "wpcom_request_access_styles" );
# }
#
# // Watch for messages back from the remote login
# window.addEventListener( "message", function( e ) {
# 	if ( e.origin === "https://r-login.wordpress.com" ) {
# 		var data = {};
# 		try {
# 			data = JSON.parse( e.data );
# 		} catch( e ) {
# 			wpcom_remote_login_final_cleanup();
# 			return;
# 		}
#
# 		if ( data.msg === 'LOGIN' ) {
# 			// Clean up the login check iframe
# 			wpcom_remote_login_remove_dom_node_id( "wpcom_remote_login_key" );
#
# 			var id_regex = new RegExp( /^[0-9]+$/ );
# 			var token_regex = new RegExp( /^.*|.*|.*$/ );
# 			if (
# 				token_regex.test( data.token )
# 				&& id_regex.test( data.wpcomid )
# 			) {
# 				// We have everything we need to ask for a login
# 				var script = document.createElement( "script" );
# 				script.setAttribute( "id", "wpcom_remote_login_validate" );
# 				script.src = '/remote-login.php?wpcom_remote_login=validate'
# 					+ '&wpcomid=' + data.wpcomid
# 					+ '&token=' + encodeURIComponent( data.token )
# 					+ '&host=' + window.location.protocol
# 						+ '//' + window.location.hostname;
# 				document.body.appendChild( script );
# 			}
#
# 			return;
# 		}
#
# 		// Safari ITP, not logged in, so redirect
# 		if ( data.msg === 'LOGIN-REDIRECT' ) {
# 			window.location = 'https://wordpress.com/log-in?redirect_to=' + window.location.href;
# 			return;
# 		}
#
# 		// Safari ITP, storage access failed, remove the request
# 		if ( data.msg === 'LOGIN-REMOVE' ) {
# 			var css_zap = 'html { -webkit-transition: margin-top 1s; transition: margin-top 1s; } /* 9001 */ html { margin-top: 0 !important; } * html body { margin-top: 0 !important; } @media screen and ( max-width: 782px ) { html { margin-top: 0 !important; } * html body { margin-top: 0 !important; } }';
# 			var style_zap = document.createElement( 'style' );
# 			style_zap.type = 'text/css';
# 			style_zap.appendChild( document.createTextNode( css_zap ) );
# 			document.body.appendChild( style_zap );
#
# 			var e = document.getElementById( 'wpcom_request_access_iframe' );
# 			e.parentNode.removeChild( e );
#
# 			document.cookie = 'wordpress_com_login_access=denied; path=/; max-age=31536000';
#
# 			return;
# 		}
#
# 		// Safari ITP
# 		if ( data.msg === 'REQUEST_ACCESS' ) {
# 			console.log( 'request access: safari' );
#
# 			// Check ITP iframe enable/disable knob
# 			if ( wpcom_remote_login_extra_auth !== 'safari_itp_iframe' ) {
# 				return;
# 			}
#
# 			// If we are in a "private window" there is no ITP.
# 			var private_window = false;
# 			try {
# 				var opendb = window.openDatabase( null, null, null, null );
# 			} catch( e ) {
# 				private_window = true;
# 			}
#
# 			if ( private_window ) {
# 				console.log( 'private window' );
# 				return;
# 			}
#
# 			var iframe = document.createElement( 'iframe' );
# 			iframe.id = 'wpcom_request_access_iframe';
# 			iframe.setAttribute( 'scrolling', 'no' );
# 			iframe.setAttribute( 'sandbox', 'allow-storage-access-by-user-activation allow-scripts allow-same-origin allow-top-navigation-by-user-activation' );
# 			iframe.src = 'https://r-login.wordpress.com/remote-login.php?wpcom_remote_login=request_access&origin=' + encodeURIComponent( data.origin ) + '&wpcomid=' + encodeURIComponent( data.wpcomid );
#
# 			var css = 'html { -webkit-transition: margin-top 1s; transition: margin-top 1s; } /* 9001 */ html { margin-top: 46px !important; } * html body { margin-top: 46px !important; } @media screen and ( max-width: 660px ) { html { margin-top: 71px !important; } * html body { margin-top: 71px !important; } #wpcom_request_access_iframe { display: block; height: 71px !important; } } #wpcom_request_access_iframe { border: 0px; height: 46px; position: fixed; top: 0; left: 0; width: 100%; min-width: 100%; z-index: 99999; background: #23282d; } ';
#
# 			var style = document.createElement( 'style' );
# 			style.type = 'text/css';
# 			style.id = 'wpcom_request_access_styles';
# 			style.appendChild( document.createTextNode( css ) );
# 			document.body.appendChild( style );
#
# 			document.body.appendChild( iframe );
# 		}
#
# 		if ( data.msg === 'DONE' ) {
# 			wpcom_remote_login_final_cleanup();
# 		}
# 	}
# }, false );
#
# // Inject the remote login iframe after the page has had a chance to load
# // more critical resources
# window.addEventListener( "DOMContentLoaded", function( e ) {
# 	var iframe = document.createElement( "iframe" );
# 	iframe.style.display = "none";
# 	iframe.setAttribute( "scrolling", "no" );
# 	iframe.setAttribute( "id", "wpcom_remote_login_key" );
# 	iframe.src = "https://r-login.wordpress.com/remote-login.php"
# 		+ "?wpcom_remote_login=key"
# 		+ "&origin=aHR0cHM6Ly9zcGFya2tvcmVhLmNvbQ%3D%3D"
# 		+ "&wpcomid=163927570"
# 		+ "&time=1562658584";
# 	document.body.appendChild( iframe );
# }, false );
# </script>
# <link href="//s2.wp.com" rel="dns-prefetch">
# <link href="//s1.wp.com" rel="dns-prefetch">
# <link href="//sparkkorea.wordpress.com" rel="dns-prefetch"/>
# <link href="//s0.wp.com" rel="dns-prefetch"/>
# <link href="//wordpress.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="https://sparkkorea.com/feed/" rel="alternate" title="폴리텍대  스마트금융과 » 피드" type="application/rss+xml"/>
# <link href="https://sparkkorea.com/comments/feed/" rel="alternate" title="폴리텍대  스마트금융과 » 댓글 피드" type="application/rss+xml"/>
# <script type="text/javascript">
# 		/* <![CDATA[ */
# 		function addLoadEvent(func) {
# 			var oldonload = window.onload;
# 			if (typeof window.onload != 'function') {
# 				window.onload = func;
# 			} else {
# 				window.onload = function () {
# 					oldonload();
# 					func();
# 				}
# 			}
# 		}
# 		/* ]]> */
# 	</script>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s0.wp.com\/wp-content\/mu-plugins\/wpcom-smileys\/twemoji\/2\/72x72\/","ext":".png","svgUrl":"https:\/\/s0.wp.com\/wp-content\/mu-plugins\/wpcom-smileys\/twemoji\/2\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/s2.wp.com\/wp-includes\/js\/wp-emoji-release.min.js?m=1556893897h&ver=5.2.2"}};
# 			!function(a,b,c){function d(a,b){var c=String.fromCharCode;l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,a),0,0);var d=k.toDataURL();l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,b),0,0);var e=k.toDataURL();return d===e}function e(a){var b;if(!l||!l.fillText)return!1;switch(l.textBaseline="top",l.font="600 32px Arial",a){case"flag":return!(b=d([55356,56826,55356,56819],[55356,56826,8203,55356,56819]))&&(b=d([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]),!b);case"emoji":return b=d([55357,56424,55356,57342,8205,55358,56605,8205,55357,56424,55356,57340],[55357,56424,55356,57342,8203,55358,56605,8203,55357,56424,55356,57340]),!b}return!1}function f(a){var c=b.createElement("script");c.src=a,c.defer=c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var g,h,i,j,k=b.createElement("canvas"),l=k.getContext&&k.getContext("2d");for(j=Array("flag","emoji"),c.supports={everything:!0,everythingExceptFlag:!0},i=0;i<j.length;i++)c.supports[j[i]]=e(j[i]),c.supports.everything=c.supports.everything&&c.supports[j[i]],"flag"!==j[i]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[j[i]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(h=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",h,!1),a.addEventListener("load",h,!1)):(a.attachEvent("onload",h),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),g=c.source||{},g.concatemoji?f(g.concatemoji):g.wpemoji&&g.twemoji&&(f(g.twemoji),f(g.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="https://s0.wp.com/_static/??-?cssminify=yes" id="all-css-0-1" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Lato%3A400%2C400italic%2C700%2C700italic%7CNoto+Serif%3A400%2C400italic%2C700%2C700italic&amp;subset=latin%2Clatin-ext" id="dyad-2-fonts-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://s0.wp.com/_static/??-eJyNj80KwjAQhF/IdRuhqAfxWdJ0jdFkE/JD6ds36kGLtPQ2w843zOIQQHnOxBldgWCLNpxQE1M09bAg9yqlHf6w+U6OEobSYT/KHg6Y8mhpQ64msLNePbeUGlafYhiC8u6PmL3godbKbDzPDNysNHENjVQH6Sr1e93XvqCru4i2bcTpLJrjYwIqr3Yq?cssminify=yes" id="all-css-2-1" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://s2.wp.com/wp-content/mu-plugins/global-print/global-print.css?m=1465851035h&amp;cssminify=yes" id="print-css-3-1" media="print" rel="stylesheet" type="text/css"/>
# <link href="https://s1.wp.com/_static/??-eJx9i9EKwjAMRX/IGgfbYA/it2SlayNpUpoMf198EBmKT/dcOAceLUQVT+JQ99B4zyQGGJ1UVuwfOkezE/zWm5qHjZE6WMFOkt/7rzKNhBxYsx7PV+Ql1WRQRsisK/JLuNXrMM2XcV6GZbo/AcVpSbo=?cssminify=yes" id="all-css-4-1" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://s2.wp.com/_static/??-eJyFztEKwjAMBdAfsisyOnwRv6XWOFKXtDbphn69HeiDMBQC9+EeuLFLNshhqhcQG9vdK5THO7ooO/sLGMKxeIWOkD84JFZgXW1OogQifoSNltIZJzBVoDTA2mauacN9v4Q8Iyx/WQTNPtxMAcHnun6i4965Q++GwfXxBTkPW9k=" type="text/javascript"></script>
# <link href="https://sparkkorea.wordpress.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://s1.wp.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress.com" name="generator">
# <link href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/" rel="canonical"/>
# <link href="https://wp.me/Pb5P34-1E" rel="shortlink"/>
# <link href="https://public-api.wordpress.com/oembed/?format=json&amp;url=https%3A%2F%2Fsparkkorea.com%2F%25ed%2580%25b4%25ec%25a6%2588%2F&amp;for=wpcom-auto-discovery" rel="alternate" type="application/json+oembed"/><link href="https://public-api.wordpress.com/oembed/?format=xml&amp;url=https%3A%2F%2Fsparkkorea.com%2F%25ed%2580%25b4%25ec%25a6%2588%2F&amp;for=wpcom-auto-discovery" rel="alternate" type="application/xml+oembed"/>
# <!-- Jetpack Open Graph Tags -->
# <meta content="article" property="og:type">
# <meta content="퀴즈" property="og:title"/>
# <meta content="https://sparkkorea.com/%ed%80%b4%ec%a6%88/" property="og:url"/>
# <meta content="일반 일반설문 Spark 퀴즈 6/13 Spark 심화과정 6/13 Spark 기본과정 6/18 Spark [MAP_FILTER] 6/18 Spark GroupBy 심화 6/25 Spark RDD 실전 분석 6/27 Spark RDD 실전 분석2 Python 퀴즈 1. 빅데이터 분석개요 및 파이썬프로그래밍 2. 파이썬 자료형 및 파일 데이터 불러오기 …" property="og:description"/>
# <meta content="2019-07-08T09:35:27+00:00" property="article:published_time"/>
# <meta content="2019-07-08T23:58:07+00:00" property="article:modified_time"/>
# <meta content="폴리텍대  스마트금융과" property="og:site_name"/>
# <meta content="https://s0.wp.com/i/blank.jpg" property="og:image"/>
# <meta content="ko_KR" property="og:locale"/>
# <meta content="@wordpressdotcom" name="twitter:site"/>
# <meta content="퀴즈" name="twitter:text:title"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="https://www.facebook.com/WordPresscom" property="article:publisher"/>
# <!-- End Jetpack Open Graph Tags -->
# <link href="https://s1.wp.com/i/favicon.ico" rel="shortcut icon" sizes="16x16 24x24 32x32 48x48" type="image/x-icon"/>
# <link href="https://s1.wp.com/i/favicon.ico" rel="icon" sizes="16x16 24x24 32x32 48x48" type="image/x-icon"/>
# <link href="https://s2.wp.com/i/webclip.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://sparkkorea.com/osd.xml" rel="search" title="폴리텍대  스마트금융과" type="application/opensearchdescription+xml"/>
# <link href="https://s1.wp.com/opensearch.xml" rel="search" title="WordPress.com" type="application/opensearchdescription+xml"/>
# <meta content="폴리텍대  스마트금융과" name="application-name"/><meta content="width=device-width;height=device-height" name="msapplication-window"/><meta content="스마트금융과 자료공유" name="msapplication-tooltip"/><meta content="name=구독;action-uri=https://sparkkorea.com/feed/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="name=무료 블로그 등록;action-uri=http://wordpress.com/signup/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="name=WordPress.com 지원;action-uri=http://support.wordpress.com/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="name=WordPress.com 포럼;action-uri=http://forums.wordpress.com/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="일반 일반설문 Spark 퀴즈 6/13 Spark 심화과정 6/13 Spark 기본과정 6/18 Spark [MAP_FILTER] 6/18 Spark GroupBy 심화 6/25 Spark RDD 실전 분석 6/27 Spark RDD 실전 분석2 Python 퀴즈 1. 빅데이터 분석개요 및 파이썬프로그래밍 2. 파이썬 자료형 및 파일 데이터 불러오기 3. 파이썬 자료형 복습 4. 파이썬 문법 및 데이터 불러오기 5. 파이썬 문법 응용…" name="description"/>
# <style id="syntaxhighlighteranchor" type="text/css"></style>
# </meta></meta></link></link></head>
# <body class="page-template-default page page-id-102 wp-embed-responsive mp6 customizer-styles-applied is-singular no-js highlander-enabled highlander-light">
# <div class="hfeed site" id="page">
# <a class="skip-link screen-reader-text" href="#content">컨텐츠로 건너뛰기</a>
# <header class="site-header" id="masthead" role="banner">
# <div class="site-branding">
# <h1 class="site-title">
# <a href="https://sparkkorea.com/" rel="home">
# 					폴리텍대  스마트금융과				</a>
# </h1>
# <p class="site-description">스마트금융과 자료공유</p>
# </div><!-- .site-branding -->
# <nav class="main-navigation" id="site-navigation" role="navigation">
# <button aria-controls="primary-menu" aria-expanded="false" class="menu-toggle">메뉴</button>
# <div class="primary-menu"><ul class="menu" id="primary-menu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-privacy-policy menu-item-28" id="menu-item-28"><a href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/">설문</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-27" id="menu-item-27"><a href="https://sparkkorea.com/%ec%9e%90%eb%a3%8c%ec%8b%a4/">자료실</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-102 current_page_item menu-item-106" id="menu-item-106"><a aria-current="page" href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/">퀴즈</a></li>
# </ul></div> </nav>
# </header><!-- #masthead -->
# <div class="site-inner">
# <div class="site-content" id="content">
# <main class="content-area" id="primary" role="main">
# <article class="post-102 page type-page status-publish hentry" id="post-102">
# <div class="entry-inner">
# <header class="entry-header">
# <h1 class="entry-title">퀴즈</h1> </header><!-- .entry-header -->
# <div class="entry-content">
# <div class="class_general_quiz" id="id_general_quiz">
# <h1>일반 </h1>
# <a href="https://forms.gle/qEgvUUfCYRiFdZAj6"> 일반설문 </a>
# <p></p>
# <p></p>
# </div>
# <div class="class_spark_quiz" id="id_spark_quiz">
# <h1>Spark 퀴즈 </h1>
# <a href="https://forms.gle/Fw49w9GhWQChDcZm7"> 6/13 Spark 심화과정 </a>
# <p></p>
# <a href="https://forms.gle/G4TcXm3fKuHLHA6D6"> 6/13 Spark 기본과정 </a>
# <p></p>
# <a href="https://forms.gle/M8gr1kC2ubA3UDVp8"> 6/18 Spark [MAP_FILTER] </a>
# <p></p>
# <a href="https://forms.gle/h8w5mZ4MNaPLCPbi6"> 6/18 Spark GroupBy 심화 </a>
# <p></p>
# <a href="https://forms.gle/q5yL6QHfueDLM5w27"> 6/25 Spark RDD 실전 분석 </a>
# <p></p>
# <a href="https://forms.gle/Gxb4y6LfVYiaLu4M7"> 6/27 Spark RDD 실전 분석2 </a>
# <p></p>
# </div>
# <div class="class_py_quiz" id="id_py_quiz">
# <h1>Python 퀴즈 </h1>
# <a href="https://goo.gl/forms/BLiJDnHCC8MDoHr82"> 1. 빅데이터 분석개요 및 파이썬프로그래밍</a>
# <p></p>
# <a href="https://goo.gl/forms/bTvHsy0PY3am0BCq2"> 2. 파이썬 자료형 및 파일 데이터 불러오기 </a>
# <p></p>
# <a href="https://goo.gl/forms/ylZZiZUHfMxm7etJ3"> 3. 파이썬 자료형 복습 </a>
# <p></p>
# <a href="https://goo.gl/forms/bGl0bgpmmqLKyEHI3"> 4. 파이썬 문법 및 데이터 불러오기 </a>
# <p></p>
# <a href="https://goo.gl/forms/TtbUdSHNSOmFdIUN2"> 5. 파이썬 문법 응용 </a>
# <p></p>
# <a href="https://forms.gle/SMgrtcifZLKr5JNZA"> 파이썬 코드리뷰 </a>
# <p></p>
# <a href="https://forms.gle/Ep3PTfsTmk3pkdhK7"> 파이썬 스크랩관련 설문 </a>
# <p></p>
# </div>
# <div class="sharedaddy sd-like-enabled sd-sharing-enabled" id="jp-post-flair"><div class="sharedaddy sd-sharing-enabled"><div class="robots-nocontent sd-block sd-social sd-social-icon-text sd-sharing"><h3 class="sd-title">이 글 공유하기:</h3><div class="sd-content"><ul><li class="share-twitter"><a class="share-twitter sd-button share-icon" data-shared="sharing-twitter-102" href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/?share=twitter" rel="nofollow noopener noreferrer" target="_blank" title="트위터로 공유하기"><span>Twitter</span></a></li><li class="share-facebook"><a class="share-facebook sd-button share-icon" data-shared="sharing-facebook-102" href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/?share=facebook" rel="nofollow noopener noreferrer" target="_blank" title="Click to share on Facebook"><span>Facebook</span></a></li><li class="share-end"></li></ul></div></div></div><div class="sharedaddy sd-block sd-like jetpack-likes-widget-wrapper jetpack-likes-widget-unloaded" data-name="like-post-frame-163927570-102-5d24471893497" data-src="//widgets.wp.com/likes/index.html?ver=20190321#blog_id=163927570&amp;post_id=102&amp;origin=sparkkorea.wordpress.com&amp;obj_id=163927570-102-5d24471893497&amp;domain=sparkkorea.com" id="like-post-wrapper-163927570-102-5d24471893497"><h3 class="sd-title">이것이 좋아요:</h3><div class="likes-widget-placeholder post-likes-widget-placeholder" style="height: 55px;"><span class="button"><span>좋아요</span></span> <span class="loading">가져오는 중...</span></div><span class="sd-text-color"></span><a class="sd-link-color"></a></div></div> </div><!-- .entry-content -->
# </div><!-- .entry-inner -->
# </article><!-- #post-## -->
# </main><!-- #main -->
# </div><!-- #content -->
# <footer class="site-footer" id="colophon" role="contentinfo">
# <div class="footer-bottom-info">
# <div class="site-info">
# <a href="https://wordpress.com/?ref=footer_segment_business">A WordPress.com Website.</a>
# </div><!-- .site-info -->
# </div><!-- .footer-bottom-info -->
# </footer><!-- #colophon -->
# </div><!-- .site-inner -->
# </div><!-- #page -->
# <!-- -->
# <script src="//0.gravatar.com/js/gprofiles.js?ver=201928y" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var WPGroHo = {"my_hash":""};
# /* ]]> */
# </script>
# <script src="https://s1.wp.com/wp-content/mu-plugins/gravatar-hovercards/wpgroho.js?m=1380573781h" type="text/javascript"></script>
# <script>
# 		//initialize and attach hovercards to all gravatars
# 		jQuery( document ).ready( function( $ ) {
#
# 			if (typeof Gravatar === "undefined"){
# 				return;
# 			}
#
# 			if ( typeof Gravatar.init !== "function" ) {
# 				return;
# 			}
#
# 			Gravatar.profile_cb = function( hash, id ) {
# 				WPGroHo.syncProfileData( hash, id );
# 			};
# 			Gravatar.my_hash = WPGroHo.my_hash;
# 			Gravatar.init( 'body', '#wp-admin-bar-my-account' );
# 		});
# 	</script>
# <div style="display:none">
# </div>
# <script type="text/javascript">
# 		window.WPCOM_sharing_counts = {"https:\/\/sparkkorea.com\/%ed%80%b4%ec%a6%88\/":102};
# 	</script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var comment_like_text = {"loading":"\uac00\uc838\uc624\ub294 \uc911..."};
# /* ]]> */
# </script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var actionbardata = {"siteID":"163927570","siteName":"\ud3f4\ub9ac\ud14d\ub300  \uc2a4\ub9c8\ud2b8\uae08\uc735\uacfc","siteURL":"https:\/\/sparkkorea.com","icon":"<img alt='' src='https:\/\/s2.wp.com\/i\/logo\/wpcom-gray-white.png' class='avatar avatar-50' height='50' width='50' \/>","canManageOptions":"","canCustomizeSite":"","isFollowing":"","themeSlug":"pub\/dyad-2","signupURL":"https:\/\/wordpress.com\/start\/","loginURL":"https:\/\/wordpress.com\/log-in?redirect_to=https%3A%2F%2Fsparkkorea.com%2F%ED%80%B4%EC%A6%88%2F&signup_flow=account&domain=sparkkorea.com","themeURL":"https:\/\/wordpress.com\/theme\/dyad-2\/","xhrURL":"https:\/\/sparkkorea.com\/wp-admin\/admin-ajax.php","nonce":"df70ca2e50","isSingular":"1","isFolded":"","isLoggedIn":"","isMobile":"","subscribeNonce":"<input type=\"hidden\" id=\"_wpnonce\" name=\"_wpnonce\" value=\"2a2b0fc775\" \/>","referer":"https:\/\/sparkkorea.com\/%ED%80%B4%EC%A6%88\/","canFollow":"","feedID":"97558616","statusMessage":"","customizeLink":"https:\/\/sparkkorea.wordpress.com\/wp-admin\/customize.php?url=https%3A%2F%2Fsparkkorea.wordpress.com%2F%25ED%2580%25B4%25EC%25A6%2588%2F","postID":"102","shortlink":"https:\/\/wp.me\/Pb5P34-1E","canEditPost":"","editLink":"https:\/\/wordpress.com\/page\/sparkkorea.com\/102","statsLink":"https:\/\/wordpress.com\/stats\/post\/102\/sparkkorea.com","i18n":{"view":"\uc0ac\uc774\ud2b8 \ubcf4\uae30","follow":"\ud314\ub85c\uc6b0","following":"\ud314\ub85c\uc6b0\uc911","edit":"\ud3b8\uc9d1","login":"\ub85c\uadf8\uc778","signup":"\uac00\uc785","customize":"\uc0ac\uc6a9\uc790 \uc815\uc758\ud558\uae30","report":"\uc774 \ucf58\ud150\uce20 \uc2e0\uace0\ud558\uae30","themeInfo":"\ud14c\ub9c8 \uac00\uc838\uc624\uae30: Dyad 2","shortlink":"\ub2e8\ucd95 \ub9c1\ud06c \ubcf5\uc0ac","copied":"\ubcf5\uc0ac\ub428","followedText":"\uc774 \uc0ac\uc774\ud2b8\uc758 \uc0c8 \uae00\uc774 \uc774\uc81c <a href=\"https:\/\/wordpress.com\/\">\ub274\uc2a4\ud53c\ub4dc<\/a>\uc5d0 \ud45c\uc2dc\ub429\ub2c8\ub2e4.","foldBar":"\uc774 \ud45c\uc2dc\uc904 \ucd95\uc18c","unfoldBar":"\uc774 \ud45c\uc2dc\uc904 \ud655\uc7a5","editSubs":"\uad6c\ub3c5 \uad00\ub9ac","viewReader":"\ub9ac\ub354\uc5d0\uc11c \uc0ac\uc774\ud2b8 \ubcf4\uae30","viewReadPost":"View post in Reader","subscribe":"\uac00\uc785\ud558\uae30","enterEmail":"\uc774\uba54\uc77c \uc8fc\uc18c \uc785\ub825","followers":"","alreadyUser":"\uc774\ubbf8 \uc6cc\ub4dc\ud504\ub808\uc2a4\ub2f7\ucef4 \uacc4\uc815\uc744 \uac16\uace0 \uacc4\uc138\uc694? <a href=\"https:\/\/wordpress.com\/log-in?redirect_to=https%3A%2F%2Fsparkkorea.com%2F%ED%80%B4%EC%A6%88%2F&signup_flow=account&domain=sparkkorea.com\">\uc9c0\uae08 \ub85c\uadf8\uc778\ud558\uc138\uc694.<\/a>","stats":"\ud1b5\uacc4"}};
# /* ]]> */
# </script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var sharing_js_options = {"lang":"en","counts":"1","is_stats_active":"1"};
# /* ]]> */
# </script>
# <script src="https://s1.wp.com/_static/??-" type="text/javascript"></script>
# <script type="text/javascript">
# var windowOpen;
# 			jQuery( document.body ).on( 'click', 'a.share-twitter', function() {
# 				// If there's another sharing window open, close it.
# 				if ( 'undefined' !== typeof windowOpen ) {
# 					windowOpen.close();
# 				}
# 				windowOpen = window.open( jQuery( this ).attr( 'href' ), 'wpcomtwitter', 'menubar=1,resizable=1,width=600,height=350' );
# 				return false;
# 			});
# var windowOpen;
# 			jQuery( document.body ).on( 'click', 'a.share-facebook', function() {
# 				// If there's another sharing window open, close it.
# 				if ( 'undefined' !== typeof windowOpen ) {
# 					windowOpen.close();
# 				}
# 				windowOpen = window.open( jQuery( this ).attr( 'href' ), 'wpcomfacebook', 'menubar=1,resizable=1,width=600,height=400' );
# 				return false;
# 			});
# </script>
# <script type="text/javascript">
# // <![CDATA[
# (function() {
# try{
#   if ( window.external &&'msIsSiteMode' in window.external) {
#     if (window.external.msIsSiteMode()) {
#       var jl = document.createElement('script');
#       jl.type='text/javascript';
#       jl.async=true;
#       jl.src='/wp-content/plugins/ie-sitemode/custom-jumplist.php';
#       var s = document.getElementsByTagName('script')[0];
#       s.parentNode.insertBefore(jl, s);
#     }
#   }
# }catch(e){}
# })();
# // ]]>
# </script> <iframe id="likes-master" name="likes-master" scrolling="no" src="https://widgets.wp.com/likes/master.html?ver=20190321#ver=20190321&amp;lang=ko" style="display:none;"></iframe>
# <div id="likes-other-gravatars"><div class="likes-text"><span>%d</span> 블로거가 이것을 좋아합니다:</div><ul class="wpl-avatars sd-like-gravatars"></ul></div>
# <script async="" defer="" src="//stats.wp.com/w.js?60" type="text/javascript"></script>
# <script type="text/javascript">
# _tkq = window._tkq || [];
# _stq = window._stq || [];
# _tkq.push(['storeContext', {'blog_id':'163927570','blog_tz':'9','user_lang':'ko','blog_lang':'ko','user_id':'0'}]);
# _stq.push(['view', {'blog':'163927570','v':'wpcom','tz':'9','user_id':'0','post':'102','subd':'sparkkorea'}]);
# _stq.push(['extra', {'crypt':''}]);
# _stq.push([ 'clickTrackerInit', '163927570', '102' ]);
# 	</script>
# <noscript><img alt="" src="https://pixel.wp.com/b.gif?v=noscript" style="height:0px;width:0px;overflow:hidden"/></noscript>
# <script>
# if ( 'object' === typeof wpcom_mobile_user_agent_info ) {
#
# 	wpcom_mobile_user_agent_info.init();
# 	var mobileStatsQueryString = "";
#
# 	if( false !== wpcom_mobile_user_agent_info.matchedPlatformName )
# 		mobileStatsQueryString += "&x_" + 'mobile_platforms' + '=' + wpcom_mobile_user_agent_info.matchedPlatformName;
#
# 	if( false !== wpcom_mobile_user_agent_info.matchedUserAgentName )
# 		mobileStatsQueryString += "&x_" + 'mobile_devices' + '=' + wpcom_mobile_user_agent_info.matchedUserAgentName;
#
# 	if( wpcom_mobile_user_agent_info.isIPad() )
# 		mobileStatsQueryString += "&x_" + 'ipad_views' + '=' + 'views';
#
# 	if( "" != mobileStatsQueryString ) {
# 		new Image().src = document.location.protocol + '//pixel.wp.com/g.gif?v=wpcom-no-pv' + mobileStatsQueryString + '&baba=' + Math.random();
# 	}
#
# }
# </script>
# </body>
# </html>

# %% [markdown]
# ### 1. 특정 태그정보 가져오기 [태그명]

# %%
# html 태그 부분구조 가져오기
find_tag = bs.find("div")
print(find_tag)
# Out:
# <div class="hfeed site" id="page">
# <a class="skip-link screen-reader-text" href="#content">컨텐츠로 건너뛰기</a>
# <header class="site-header" id="masthead" role="banner">
# <div class="site-branding">
# <h1 class="site-title">
# <a href="https://sparkkorea.com/" rel="home">
# 					폴리텍대  스마트금융과				</a>
# </h1>
# <p class="site-description">스마트금융과 자료공유</p>
# </div><!-- .site-branding -->
# <nav class="main-navigation" id="site-navigation" role="navigation">
# <button aria-controls="primary-menu" aria-expanded="false" class="menu-toggle">메뉴</button>
# <div class="primary-menu"><ul class="menu" id="primary-menu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-privacy-policy menu-item-28" id="menu-item-28"><a href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/">설문</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-27" id="menu-item-27"><a href="https://sparkkorea.com/%ec%9e%90%eb%a3%8c%ec%8b%a4/">자료실</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-102 current_page_item menu-item-106" id="menu-item-106"><a aria-current="page" href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/">퀴즈</a></li>
# </ul></div> </nav>
# </header><!-- #masthead -->
# <div class="site-inner">
# <div class="site-content" id="content">
# <main class="content-area" id="primary" role="main">
# <article class="post-102 page type-page status-publish hentry" id="post-102">
# <div class="entry-inner">
# <header class="entry-header">
# <h1 class="entry-title">퀴즈</h1> </header><!-- .entry-header -->
# <div class="entry-content">
# <div class="class_general_quiz" id="id_general_quiz">
# <h1>일반 </h1>
# <a href="https://forms.gle/qEgvUUfCYRiFdZAj6"> 일반설문 </a>
# <p></p>
# <p></p>
# </div>
# <div class="class_spark_quiz" id="id_spark_quiz">
# <h1>Spark 퀴즈 </h1>
# <a href="https://forms.gle/Fw49w9GhWQChDcZm7"> 6/13 Spark 심화과정 </a>
# <p></p>
# <a href="https://forms.gle/G4TcXm3fKuHLHA6D6"> 6/13 Spark 기본과정 </a>
# <p></p>
# <a href="https://forms.gle/M8gr1kC2ubA3UDVp8"> 6/18 Spark [MAP_FILTER] </a>
# <p></p>
# <a href="https://forms.gle/h8w5mZ4MNaPLCPbi6"> 6/18 Spark GroupBy 심화 </a>
# <p></p>
# <a href="https://forms.gle/q5yL6QHfueDLM5w27"> 6/25 Spark RDD 실전 분석 </a>
# <p></p>
# <a href="https://forms.gle/Gxb4y6LfVYiaLu4M7"> 6/27 Spark RDD 실전 분석2 </a>
# <p></p>
# </div>
# <div class="class_py_quiz" id="id_py_quiz">
# <h1>Python 퀴즈 </h1>
# <a href="https://goo.gl/forms/BLiJDnHCC8MDoHr82"> 1. 빅데이터 분석개요 및 파이썬프로그래밍</a>
# <p></p>
# <a href="https://goo.gl/forms/bTvHsy0PY3am0BCq2"> 2. 파이썬 자료형 및 파일 데이터 불러오기 </a>
# <p></p>
# <a href="https://goo.gl/forms/ylZZiZUHfMxm7etJ3"> 3. 파이썬 자료형 복습 </a>
# <p></p>
# <a href="https://goo.gl/forms/bGl0bgpmmqLKyEHI3"> 4. 파이썬 문법 및 데이터 불러오기 </a>
# <p></p>
# <a href="https://goo.gl/forms/TtbUdSHNSOmFdIUN2"> 5. 파이썬 문법 응용 </a>
# <p></p>
# <a href="https://forms.gle/SMgrtcifZLKr5JNZA"> 파이썬 코드리뷰 </a>
# <p></p>
# <a href="https://forms.gle/Ep3PTfsTmk3pkdhK7"> 파이썬 스크랩관련 설문 </a>
# <p></p>
# </div>
# <div class="sharedaddy sd-like-enabled sd-sharing-enabled" id="jp-post-flair"><div class="sharedaddy sd-sharing-enabled"><div class="robots-nocontent sd-block sd-social sd-social-icon-text sd-sharing"><h3 class="sd-title">이 글 공유하기:</h3><div class="sd-content"><ul><li class="share-twitter"><a class="share-twitter sd-button share-icon" data-shared="sharing-twitter-102" href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/?share=twitter" rel="nofollow noopener noreferrer" target="_blank" title="트위터로 공유하기"><span>Twitter</span></a></li><li class="share-facebook"><a class="share-facebook sd-button share-icon" data-shared="sharing-facebook-102" href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/?share=facebook" rel="nofollow noopener noreferrer" target="_blank" title="Click to share on Facebook"><span>Facebook</span></a></li><li class="share-end"></li></ul></div></div></div><div class="sharedaddy sd-block sd-like jetpack-likes-widget-wrapper jetpack-likes-widget-unloaded" data-name="like-post-frame-163927570-102-5d24471893497" data-src="//widgets.wp.com/likes/index.html?ver=20190321#blog_id=163927570&amp;post_id=102&amp;origin=sparkkorea.wordpress.com&amp;obj_id=163927570-102-5d24471893497&amp;domain=sparkkorea.com" id="like-post-wrapper-163927570-102-5d24471893497"><h3 class="sd-title">이것이 좋아요:</h3><div class="likes-widget-placeholder post-likes-widget-placeholder" style="height: 55px;"><span class="button"><span>좋아요</span></span> <span class="loading">가져오는 중...</span></div><span class="sd-text-color"></span><a class="sd-link-color"></a></div></div> </div><!-- .entry-content -->
# </div><!-- .entry-inner -->
# </article><!-- #post-## -->
# </main><!-- #main -->
# </div><!-- #content -->
# <footer class="site-footer" id="colophon" role="contentinfo">
# <div class="footer-bottom-info">
# <div class="site-info">
# <a href="https://wordpress.com/?ref=footer_segment_business">A WordPress.com Website.</a>
# </div><!-- .site-info -->
# </div><!-- .footer-bottom-info -->
# </footer><!-- #colophon -->
# </div><!-- .site-inner -->
# </div>

# %% [markdown]
# ### 2. 특정 태그정보 가져오기 [속성활용]

# %%
# html 태그 속성으로 찾기
find_attr = bs.find("div",{"id":"id_py_quiz"})
print(find_attr)
# Out:
# <div class="class_py_quiz" id="id_py_quiz">
# <h1>Python 퀴즈 </h1>
# <a href="https://goo.gl/forms/BLiJDnHCC8MDoHr82"> 1. 빅데이터 분석개요 및 파이썬프로그래밍</a>
# <p></p>
# <a href="https://goo.gl/forms/bTvHsy0PY3am0BCq2"> 2. 파이썬 자료형 및 파일 데이터 불러오기 </a>
# <p></p>
# <a href="https://goo.gl/forms/ylZZiZUHfMxm7etJ3"> 3. 파이썬 자료형 복습 </a>
# <p></p>
# <a href="https://goo.gl/forms/bGl0bgpmmqLKyEHI3"> 4. 파이썬 문법 및 데이터 불러오기 </a>
# <p></p>
# <a href="https://goo.gl/forms/TtbUdSHNSOmFdIUN2"> 5. 파이썬 문법 응용 </a>
# <p></p>
# <a href="https://forms.gle/SMgrtcifZLKr5JNZA"> 파이썬 코드리뷰 </a>
# <p></p>
# <a href="https://forms.gle/Ep3PTfsTmk3pkdhK7"> 파이썬 스크랩관련 설문 </a>
# <p></p>
# </div>

# %% [markdown]
# ### 2. 특정 태그정보 가져오기 [부분구조 찾기]

# %%
# html 부분구조 가져오기
find_attr = bs.find("div",{"id":"id_py_quiz"})
find_part = find_attr.find("a")
print(find_part)
# Out:
# <a href="https://goo.gl/forms/BLiJDnHCC8MDoHr82"> 1. 빅데이터 분석개요 및 파이썬프로그래밍</a>

# %% [markdown]
# ### 2. 특정 태그정보 가져오기 [DOM 구조 내 속성 찾기]

# %%
# html 태그 속성으로 찾기
find_tag = bs.find("div",{"id":"id_py_quiz"})
# 링크내 속성 가져오기
find_part = find_tag.find("a").attrs['href']
print(find_part)
# Out:
# https://goo.gl/forms/BLiJDnHCC8MDoHr82

# %% [markdown]
# ### 3. 디버깅하기

# %%
# html 부분구조 가져오기
a_links = bs.find_all("div",{"id":"id_py_quiz"})
alinks = a_links[0].find_all("a")
alinks
# Out:
# [<a href="https://goo.gl/forms/BLiJDnHCC8MDoHr82"> 1. 빅데이터 분석개요 및 파이썬프로그래밍</a>,
#  <a href="https://goo.gl/forms/bTvHsy0PY3am0BCq2"> 2. 파이썬 자료형 및 파일 데이터 불러오기 </a>,
#  <a href="https://goo.gl/forms/ylZZiZUHfMxm7etJ3"> 3. 파이썬 자료형 복습 </a>,
#  <a href="https://goo.gl/forms/bGl0bgpmmqLKyEHI3"> 4. 파이썬 문법 및 데이터 불러오기 </a>,
#  <a href="https://goo.gl/forms/TtbUdSHNSOmFdIUN2"> 5. 파이썬 문법 응용 </a>,
#  <a href="https://forms.gle/SMgrtcifZLKr5JNZA"> 파이썬 코드리뷰 </a>,
#  <a href="https://forms.gle/Ep3PTfsTmk3pkdhK7"> 파이썬 스크랩관련 설문 </a>]

# %%
len(alinks)
# Out:
# 7

# %%
# 반복해서 작업한다.
alinks[0].attrs["href"]
alinks[1].attrs["href"]
# Out:
# 'https://goo.gl/forms/bTvHsy0PY3am0BCq2'

# %%
# 반복문 변환 크롤링
for i in range(0,len(alinks)):
    print(alinks[i].attrs["href"])
# Out:
# https://goo.gl/forms/BLiJDnHCC8MDoHr82
# https://goo.gl/forms/bTvHsy0PY3am0BCq2
# https://goo.gl/forms/ylZZiZUHfMxm7etJ3
# https://goo.gl/forms/bGl0bgpmmqLKyEHI3
# https://goo.gl/forms/TtbUdSHNSOmFdIUN2
# https://forms.gle/SMgrtcifZLKr5JNZA
# https://forms.gle/Ep3PTfsTmk3pkdhK7

# %% [markdown]
# ### 실습

# %%
# html 부분구조 가져오기
a_links = bs.find_all("div",{"id":"id_spark_quiz"})
alinks = a_links[0].find_all("a")
alinks
# Out:
# [<a href="https://forms.gle/Fw49w9GhWQChDcZm7"> 6/13 Spark 심화과정 </a>,
#  <a href="https://forms.gle/G4TcXm3fKuHLHA6D6"> 6/13 Spark 기본과정 </a>,
#  <a href="https://forms.gle/M8gr1kC2ubA3UDVp8"> 6/18 Spark [MAP_FILTER] </a>,
#  <a href="https://forms.gle/h8w5mZ4MNaPLCPbi6"> 6/18 Spark GroupBy 심화 </a>,
#  <a href="https://forms.gle/q5yL6QHfueDLM5w27"> 6/25 Spark RDD 실전 분석 </a>,
#  <a href="https://forms.gle/Gxb4y6LfVYiaLu4M7"> 6/27 Spark RDD 실전 분석2 </a>]

# %%
quiz_name = []
link_name = []
# 반복문 변환 크롤링
for i in range(0,len(alinks)):
    quiz_name.append(alinks[i].text)
    link_name.append(alinks[i].attrs["href"])

# %%
finalResult = pd.concat( [pd.DataFrame(quiz_name),pd.DataFrame(link_name)], axis=1)
finalResult.columns = ["link_name","link_address"]
finalResult
# Out:
#                    link_name                         link_address
# 0           6/13 Spark 심화과정   https://forms.gle/Fw49w9GhWQChDcZm7
# 1           6/13 Spark 기본과정   https://forms.gle/G4TcXm3fKuHLHA6D6
# 2   6/18 Spark [MAP_FILTER]   https://forms.gle/M8gr1kC2ubA3UDVp8
# 3     6/18 Spark GroupBy 심화   https://forms.gle/h8w5mZ4MNaPLCPbi6
# 4      6/25 Spark RDD 실전 분석   https://forms.gle/q5yL6QHfueDLM5w27
# 5     6/27 Spark RDD 실전 분석2   https://forms.gle/Gxb4y6LfVYiaLu4M7

# %% [markdown]
# ### 3. 특정 태그정보 가져오기 (Select)

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get("http://finance.naver.com/marketindex/")
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, 'html.parser')

# 데이터 추출하기
price = bs.select_one("#exchangeList > li.on > a.head.usd > div > span.value").string
price
# Out:
# '1,182.50'

# %%
outList = []
outList.append(price)

result = pd.DataFrame(outList)
result.columns = ["USD"]
result
# Out:
#         USD
# 0  1,182.50

# %% [markdown]
# ### 3. 특정 태그정보 가져오기 [select 기본]

# %%
import requests, bs4
 
#웹페이지 html 소스 가져오기
resp = requests.get("https://sparkkorea.com/퀴즈/")
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, "html.parser")
# div에서 id가 id_py_quiz인것만 추출
divs = bs.select("div#id_py_quiz")
print(divs)
# Out:
# [<div class="class_py_quiz" id="id_py_quiz">
# <h1>Python 퀴즈 </h1>
# <a href="https://goo.gl/forms/BLiJDnHCC8MDoHr82"> 1. 빅데이터 분석개요 및 파이썬프로그래밍</a>
# <p></p>
# <a href="https://goo.gl/forms/bTvHsy0PY3am0BCq2"> 2. 파이썬 자료형 및 파일 데이터 불러오기 </a>
# <p></p>
# <a href="https://goo.gl/forms/ylZZiZUHfMxm7etJ3"> 3. 파이썬 자료형 복습 </a>
# <p></p>
# <a href="https://goo.gl/forms/bGl0bgpmmqLKyEHI3"> 4. 파이썬 문법 및 데이터 불러오기 </a>
# <p></p>
# <a href="https://goo.gl/forms/TtbUdSHNSOmFdIUN2"> 5. 파이썬 문법 응용 </a>
# <p></p>
# <a href="https://forms.gle/SMgrtcifZLKr5JNZA"> 파이썬 코드리뷰 </a>
# <p></p>
# <a href="https://forms.gle/Ep3PTfsTmk3pkdhK7"> 파이썬 스크랩관련 설문 </a>
# <p></p>
# </div>]

# %%
import requests, bs4
 
#웹페이지 html 소스 가져오기
resp = requests.get("https://sparkkorea.com/퀴즈/")
resp.encoding='utf-8'
html = resp.text

bs = bs4.BeautifulSoup(html, "html.parser")
# div에서 id가 id_py_quiz인것만 추출
divs = bs.select("div#id_spark_quiz")
print(divs)
# Out:
# [<div class="class_spark_quiz" id="id_spark_quiz">
# <h1>Spark 퀴즈 </h1>
# <a href="https://forms.gle/Fw49w9GhWQChDcZm7"> 6/13 Spark 심화과정 </a>
# <p></p>
# <a href="https://forms.gle/G4TcXm3fKuHLHA6D6"> 6/13 Spark 기본과정 </a>
# <p></p>
# <a href="https://forms.gle/M8gr1kC2ubA3UDVp8"> 6/18 Spark [MAP_FILTER] </a>
# <p></p>
# <a href="https://forms.gle/h8w5mZ4MNaPLCPbi6"> 6/18 Spark GroupBy 심화 </a>
# <p></p>
# <a href="https://forms.gle/q5yL6QHfueDLM5w27"> 6/25 Spark RDD 실전 분석 </a>
# <p></p>
# <a href="https://forms.gle/Gxb4y6LfVYiaLu4M7"> 6/27 Spark RDD 실전 분석2 </a>
# <p></p>
# </div>]

# %% [markdown]
# ### 3. 특정 태그정보 가져오기 [select 기본]

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get("https://sparkkorea.com/퀴즈/")
resp.encoding='utf-8'
html = resp.text
bs = bs4.BeautifulSoup(html, "html.parser")
# div에서 class가 class_py_quiz인것만 추출 (1개)
seone = bs.select_one("div.class_py_quiz > a").string    
# div에서 class가 class_py_quiz인것만 추출 (다수)
seall = bs.select("div.class_py_quiz > a")
for li in seall:
    print(li.string)
# Out:
#  1. 빅데이터 분석개요 및 파이썬프로그래밍
#  2. 파이썬 자료형 및 파일 데이터 불러오기
#  3. 파이썬 자료형 복습
#  4. 파이썬 문법 및 데이터 불러오기
#  5. 파이썬 문법 응용
#  파이썬 코드리뷰
#  파이썬 스크랩관련 설문

# %% [markdown]
# ### 실습

# %%
import requests, bs4, pandas as pd, numpy as np
 
#웹페이지 html 소스 가져오기
resp = requests.get("https://sparkkorea.com/퀴즈/")
resp.encoding='utf-8'
html = resp.text
bs = bs4.BeautifulSoup(html, "html.parser")
# div에서 class가 class_py_quiz인것만 추출 (1개)
seone = bs.select_one("#id_spark_quiz > a").string    
# div에서 class가 class_py_quiz인것만 추출 (다수)
seall = bs.select("#id_spark_quiz > a")
for li in seall:
    print(li.attrs["href"])
# Out:
# https://forms.gle/Fw49w9GhWQChDcZm7
# https://forms.gle/G4TcXm3fKuHLHA6D6
# https://forms.gle/M8gr1kC2ubA3UDVp8
# https://forms.gle/h8w5mZ4MNaPLCPbi6
# https://forms.gle/q5yL6QHfueDLM5w27
# https://forms.gle/Gxb4y6LfVYiaLu4M7

# %% [markdown]
# # 3. Selenium 활용한 웹 프로그래밍

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import os
from os.path import join, dirname

if os.name == 'nt':
    os_name = 'nt'
elif os.name == 'mac':
    os_name = 'mac'
else:
    os_name = 'linux'

if os_name == 'nt':
    dirver_loc = "d:/chromedriver/chromedriver.exe"
else:
    dirver_loc = "/home/download/chromedriver/chromedriver.exe"

# %%
# 크롬 옵션 설정
options = webdriver.ChromeOptions()
# 헤드리스 설정 시 리눅스 같이 웹화면 없는경우에도 웹페이지 실행가능함
#options.add_argument('headless')
options.add_argument('window-size=1920x1080')
#options.add_argument("disable-gpu")
# 웹 드라이버 정의
driver = webdriver.Chrome(dirver_loc, options=options)

# %%
# URL 정의
base_url = 'https://sparkkorea.com'
# UTL 이동
driver.get(base_url)
# 퀴즈메뉴 클릭
driver.find_element_by_xpath('//*[@id="menu-item-106"]/a').click()

# %%
# 현재 페이지 소스 가져오기
html = driver.page_source
# BeautifulSoup로 페이지 소스 파싱
soup = BeautifulSoup(html,"html.parser")
soup
# Out:
# <html lang="ko-KR"><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://sparkkorea.com/xmlrpc.php" rel="pingback"/>
# <title>퀴즈 – 폴리텍대  스마트금융과</title>
# <!-- Async WordPress.com Remote Login -->
# <link href="//s2.wp.com" rel="dns-prefetch"/>
# <link href="//s1.wp.com" rel="dns-prefetch"/>
# <link href="//sparkkorea.wordpress.com" rel="dns-prefetch"/>
# <link href="//s0.wp.com" rel="dns-prefetch"/>
# <link href="//wordpress.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="https://sparkkorea.com/feed/" rel="alternate" title="폴리텍대  스마트금융과 » 피드" type="application/rss+xml"/>
# <link href="https://sparkkorea.com/comments/feed/" rel="alternate" title="폴리텍대  스마트금융과 » 댓글 피드" type="application/rss+xml"/>
# <script type="text/javascript">
# 		/* <![CDATA[ */
# 		function addLoadEvent(func) {
# 			var oldonload = window.onload;
# 			if (typeof window.onload != 'function') {
# 				window.onload = func;
# 			} else {
# 				window.onload = function () {
# 					oldonload();
# 					func();
# 				}
# 			}
# 		}
# 		/* ]]> */
# 	</script>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s0.wp.com\/wp-content\/mu-plugins\/wpcom-smileys\/twemoji\/2\/72x72\/","ext":".png","svgUrl":"https:\/\/s0.wp.com\/wp-content\/mu-plugins\/wpcom-smileys\/twemoji\/2\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/s2.wp.com\/wp-includes\/js\/wp-emoji-release.min.js?m=1556893897h&ver=5.2.2"}};
# 			!function(a,b,c){function d(a,b){var c=String.fromCharCode;l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,a),0,0);var d=k.toDataURL();l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,b),0,0);var e=k.toDataURL();return d===e}function e(a){var b;if(!l||!l.fillText)return!1;switch(l.textBaseline="top",l.font="600 32px Arial",a){case"flag":return!(b=d([55356,56826,55356,56819],[55356,56826,8203,55356,56819]))&&(b=d([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]),!b);case"emoji":return b=d([55357,56424,55356,57342,8205,55358,56605,8205,55357,56424,55356,57340],[55357,56424,55356,57342,8203,55358,56605,8203,55357,56424,55356,57340]),!b}return!1}function f(a){var c=b.createElement("script");c.src=a,c.defer=c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var g,h,i,j,k=b.createElement("canvas"),l=k.getContext&&k.getContext("2d");for(j=Array("flag","emoji"),c.supports={everything:!0,everythingExceptFlag:!0},i=0;i<j.length;i++)c.supports[j[i]]=e(j[i]),c.supports.everything=c.supports.everything&&c.supports[j[i]],"flag"!==j[i]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[j[i]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(h=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",h,!1),a.addEventListener("load",h,!1)):(a.attachEvent("onload",h),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),g=c.source||{},g.concatemoji?f(g.concatemoji):g.wpemoji&&g.twemoji&&(f(g.twemoji),f(g.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script><script defer="" src="https://s2.wp.com/wp-includes/js/wp-emoji-release.min.js?m=1556893897h&amp;ver=5.2.2" type="text/javascript"></script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="https://s0.wp.com/_static/??-?cssminify=yes" id="all-css-0-1" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Lato%3A400%2C400italic%2C700%2C700italic%7CNoto+Serif%3A400%2C400italic%2C700%2C700italic&amp;subset=latin%2Clatin-ext" id="dyad-2-fonts-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://s0.wp.com/_static/??-eJyNj80KwjAQhF/IdRuhqAfxWdJ0jdFkE/JD6ds36kGLtPQ2w843zOIQQHnOxBldgWCLNpxQE1M09bAg9yqlHf6w+U6OEobSYT/KHg6Y8mhpQ64msLNePbeUGlafYhiC8u6PmL3godbKbDzPDNysNHENjVQH6Sr1e93XvqCru4i2bcTpLJrjYwIqr3Yq?cssminify=yes" id="all-css-2-1" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://s2.wp.com/wp-content/mu-plugins/global-print/global-print.css?m=1465851035h&amp;cssminify=yes" id="print-css-3-1" media="print" rel="stylesheet" type="text/css"/>
# <link href="https://s1.wp.com/_static/??-eJx9i9EKwjAMRX/IGgfbYA/it2SlayNpUpoMf198EBmKT/dcOAceLUQVT+JQ99B4zyQGGJ1UVuwfOkezE/zWm5qHjZE6WMFOkt/7rzKNhBxYsx7PV+Ql1WRQRsisK/JLuNXrMM2XcV6GZbo/AcVpSbo=?cssminify=yes" id="all-css-4-1" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://s2.wp.com/_static/??-eJyFztEKwjAMBdAfsisyOnwRv6XWOFKXtDbphn69HeiDMBQC9+EeuLFLNshhqhcQG9vdK5THO7ooO/sLGMKxeIWOkD84JFZgXW1OogQifoSNltIZJzBVoDTA2mauacN9v4Q8Iyx/WQTNPtxMAcHnun6i4965Q++GwfXxBTkPW9k=" type="text/javascript"></script>
# <link href="https://sparkkorea.wordpress.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://s1.wp.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress.com" name="generator"/>
# <link href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/" rel="canonical"/>
# <link href="https://wp.me/Pb5P34-1E" rel="shortlink"/>
# <link href="https://public-api.wordpress.com/oembed/?format=json&amp;url=https%3A%2F%2Fsparkkorea.com%2F%25ed%2580%25b4%25ec%25a6%2588%2F&amp;for=wpcom-auto-discovery" rel="alternate" type="application/json+oembed"/><link href="https://public-api.wordpress.com/oembed/?format=xml&amp;url=https%3A%2F%2Fsparkkorea.com%2F%25ed%2580%25b4%25ec%25a6%2588%2F&amp;for=wpcom-auto-discovery" rel="alternate" type="application/xml+oembed"/>
# <!-- Jetpack Open Graph Tags -->
# <meta content="article" property="og:type"/>
# <meta content="퀴즈" property="og:title"/>
# <meta content="https://sparkkorea.com/%ed%80%b4%ec%a6%88/" property="og:url"/>
# <meta content="일반 일반설문 Spark 퀴즈 6/13 Spark 심화과정 6/13 Spark 기본과정 6/18 Spark [MAP_FILTER] 6/18 Spark GroupBy 심화 6/25 Spark RDD 실전 분석 6/27 Spark RDD 실전 분석2 Python 퀴즈 1. 빅데이터 분석개요 및 파이썬프로그래밍 2. 파이썬 자료형 및 파일 데이터 불러오기 …" property="og:description"/>
# <meta content="2019-07-08T09:35:27+00:00" property="article:published_time"/>
# <meta content="2019-07-08T23:58:07+00:00" property="article:modified_time"/>
# <meta content="폴리텍대  스마트금융과" property="og:site_name"/>
# <meta content="https://s0.wp.com/i/blank.jpg" property="og:image"/>
# <meta content="ko_KR" property="og:locale"/>
# <meta content="@wordpressdotcom" name="twitter:site"/>
# <meta content="퀴즈" name="twitter:text:title"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="https://www.facebook.com/WordPresscom" property="article:publisher"/>
# <!-- End Jetpack Open Graph Tags -->
# <link href="https://s1.wp.com/i/favicon.ico" rel="shortcut icon" sizes="16x16 24x24 32x32 48x48" type="image/x-icon"/>
# <link href="https://s1.wp.com/i/favicon.ico" rel="icon" sizes="16x16 24x24 32x32 48x48" type="image/x-icon"/>
# <link href="https://s2.wp.com/i/webclip.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://sparkkorea.com/osd.xml" rel="search" title="폴리텍대  스마트금융과" type="application/opensearchdescription+xml"/>
# <link href="https://s1.wp.com/opensearch.xml" rel="search" title="WordPress.com" type="application/opensearchdescription+xml"/>
# <meta content="폴리텍대  스마트금융과" name="application-name"/><meta content="width=device-width;height=device-height" name="msapplication-window"/><meta content="스마트금융과 자료공유" name="msapplication-tooltip"/><meta content="name=구독;action-uri=https://sparkkorea.com/feed/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="name=무료 블로그 등록;action-uri=http://wordpress.com/signup/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="name=WordPress.com 지원;action-uri=http://support.wordpress.com/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="name=WordPress.com 포럼;action-uri=http://forums.wordpress.com/;icon-uri=https://s1.wp.com/i/favicon.ico" name="msapplication-task"/><meta content="일반 일반설문 Spark 퀴즈 6/13 Spark 심화과정 6/13 Spark 기본과정 6/18 Spark [MAP_FILTER] 6/18 Spark GroupBy 심화 6/25 Spark RDD 실전 분석 6/27 Spark RDD 실전 분석2 Python 퀴즈 1. 빅데이터 분석개요 및 파이썬프로그래밍 2. 파이썬 자료형 및 파일 데이터 불러오기 3. 파이썬 자료형 복습 4. 파이썬 문법 및 데이터 불러오기 5. 파이썬 문법 응용…" name="description"/>
# <style id="syntaxhighlighteranchor" type="text/css"></style>
# <link href="https://0.gravatar.com/dist/css/hovercard.min.css?ver=201928y" id="gravatar-card-css" rel="stylesheet" type="text/css"/><link href="https://0.gravatar.com/dist/css/services.min.css?ver=201928y" id="gravatar-card-services-css" rel="stylesheet" type="text/css"/></head>
# <body class="page-template-default page page-id-102 wp-embed-responsive mp6 customizer-styles-applied is-singular highlander-enabled highlander-light not-scrolled">
# <div class="hfeed site" id="page">
# <a class="skip-link screen-reader-text" href="#content">컨텐츠로 건너뛰기</a>
# <header class="site-header" id="masthead" role="banner">
# <div class="site-branding">
# <h1 class="site-title">
# <a href="https://sparkkorea.com/" rel="home">
# 					폴리텍대  스마트금융과				</a>
# </h1>
# <p class="site-description">스마트금융과 자료공유</p>
# </div><!-- .site-branding -->
# <nav class="main-navigation" id="site-navigation" role="navigation">
# <button aria-controls="primary-menu" aria-expanded="false" class="menu-toggle">메뉴</button>
# <div class="primary-menu"><ul aria-expanded="false" class="menu nav-menu" id="primary-menu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-privacy-policy menu-item-28" id="menu-item-28"><a href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/">설문</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-27" id="menu-item-27"><a href="https://sparkkorea.com/%ec%9e%90%eb%a3%8c%ec%8b%a4/">자료실</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-102 current_page_item menu-item-106" id="menu-item-106"><a aria-current="page" href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/">퀴즈</a></li>
# </ul></div> </nav>
# </header><!-- #masthead -->
# <div class="site-inner">
# <div class="site-content" id="content" style="padding-top: 126px;">
# <main class="content-area" id="primary" role="main">
# <article class="post-102 page type-page status-publish hentry" id="post-102">
# <div class="entry-inner">
# <header class="entry-header">
# <h1 class="entry-title">퀴즈</h1> </header><!-- .entry-header -->
# <div class="entry-content">
# <div class="class_general_quiz" id="id_general_quiz">
# <h1>일반 </h1>
# <a href="https://forms.gle/qEgvUUfCYRiFdZAj6"> 일반설문 </a>
# <p></p>
# <p></p>
# </div>
# <div class="class_spark_quiz" id="id_spark_quiz">
# <h1>Spark 퀴즈 </h1>
# <a href="https://forms.gle/Fw49w9GhWQChDcZm7"> 6/13 Spark 심화과정 </a>
# <p></p>
# <a href="https://forms.gle/G4TcXm3fKuHLHA6D6"> 6/13 Spark 기본과정 </a>
# <p></p>
# <a href="https://forms.gle/M8gr1kC2ubA3UDVp8"> 6/18 Spark [MAP_FILTER] </a>
# <p></p>
# <a href="https://forms.gle/h8w5mZ4MNaPLCPbi6"> 6/18 Spark GroupBy 심화 </a>
# <p></p>
# <a href="https://forms.gle/q5yL6QHfueDLM5w27"> 6/25 Spark RDD 실전 분석 </a>
# <p></p>
# <a href="https://forms.gle/Gxb4y6LfVYiaLu4M7"> 6/27 Spark RDD 실전 분석2 </a>
# <p></p>
# </div>
# <div class="class_py_quiz" id="id_py_quiz">
# <h1>Python 퀴즈 </h1>
# <a href="https://goo.gl/forms/BLiJDnHCC8MDoHr82"> 1. 빅데이터 분석개요 및 파이썬프로그래밍</a>
# <p></p>
# <a href="https://goo.gl/forms/bTvHsy0PY3am0BCq2"> 2. 파이썬 자료형 및 파일 데이터 불러오기 </a>
# <p></p>
# <a href="https://goo.gl/forms/ylZZiZUHfMxm7etJ3"> 3. 파이썬 자료형 복습 </a>
# <p></p>
# <a href="https://goo.gl/forms/bGl0bgpmmqLKyEHI3"> 4. 파이썬 문법 및 데이터 불러오기 </a>
# <p></p>
# <a href="https://goo.gl/forms/TtbUdSHNSOmFdIUN2"> 5. 파이썬 문법 응용 </a>
# <p></p>
# <a href="https://forms.gle/SMgrtcifZLKr5JNZA"> 파이썬 코드리뷰 </a>
# <p></p>
# <a href="https://forms.gle/Ep3PTfsTmk3pkdhK7"> 파이썬 스크랩관련 설문 </a>
# <p></p>
# </div>
# <div class="sharedaddy sd-like-enabled sd-sharing-enabled" id="jp-post-flair"><div class="sharedaddy sd-sharing-enabled"><div class="robots-nocontent sd-block sd-social sd-social-icon-text sd-sharing"><h3 class="sd-title">이 글 공유하기:</h3><div class="sd-content"><ul><li class="share-twitter"><a class="share-twitter sd-button share-icon" data-shared="sharing-twitter-102" href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/?share=twitter&amp;nb=1" rel="nofollow noopener noreferrer" target="_blank" title="트위터로 공유하기"><span>Twitter</span></a></li><li class="share-facebook"><a class="share-facebook sd-button share-icon" data-shared="sharing-facebook-102" href="https://sparkkorea.com/%ed%80%b4%ec%a6%88/?share=facebook&amp;nb=1" rel="nofollow noopener noreferrer" target="_blank" title="Click to share on Facebook"><span>Facebook</span></a></li><li class="share-end"></li></ul></div></div></div><div class="sharedaddy sd-block sd-like jetpack-likes-widget-wrapper jetpack-likes-widget-loaded" data-name="like-post-frame-163927570-102-5d2451e22b594" data-src="//widgets.wp.com/likes/index.html?ver=20190321#blog_id=163927570&amp;post_id=102&amp;origin=sparkkorea.wordpress.com&amp;obj_id=163927570-102-5d2451e22b594&amp;domain=sparkkorea.com" id="like-post-wrapper-163927570-102-5d2451e22b594"><h3 class="sd-title">이것이 좋아요:</h3><div class="likes-widget-placeholder post-likes-widget-placeholder" style="height: 55px; display: none;"><span class="button"><span>좋아요</span></span> <span class="loading">가져오는 중...</span></div><iframe class="post-likes-widget jetpack-likes-widget" frameborder="0" height="55px" name="like-post-frame-163927570-102-5d2451e22b594" src="//widgets.wp.com/likes/index.html?ver=20190321#blog_id=163927570&amp;post_id=102&amp;origin=sparkkorea.wordpress.com&amp;obj_id=163927570-102-5d2451e22b594&amp;domain=sparkkorea.com" width="100%"></iframe><span class="sd-text-color"></span><a class="sd-link-color"></a></div></div> </div><!-- .entry-content -->
# </div><!-- .entry-inner -->
# </article><!-- #post-## -->
# </main><!-- #main -->
# </div><!-- #content -->
# <footer class="site-footer" id="colophon" role="contentinfo">
# <div class="footer-bottom-info">
# <div class="site-info">
# <a href="https://wordpress.com/?ref=footer_segment_business">A WordPress.com Website.</a>
# </div><!-- .site-info -->
# </div><!-- .footer-bottom-info -->
# </footer><!-- #colophon -->
# </div><!-- .site-inner -->
# </div><!-- #page -->
# <!-- -->
# <script src="//0.gravatar.com/js/gprofiles.js?ver=201928y" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var WPGroHo = {"my_hash":""};
# /* ]]> */
# </script>
# <script src="https://s1.wp.com/wp-content/mu-plugins/gravatar-hovercards/wpgroho.js?m=1380573781h" type="text/javascript"></script>
# <script>
# 		//initialize and attach hovercards to all gravatars
# 		jQuery( document ).ready( function( $ ) {
#
# 			if (typeof Gravatar === "undefined"){
# 				return;
# 			}
#
# 			if ( typeof Gravatar.init !== "function" ) {
# 				return;
# 			}
#
# 			Gravatar.profile_cb = function( hash, id ) {
# 				WPGroHo.syncProfileData( hash, id );
# 			};
# 			Gravatar.my_hash = WPGroHo.my_hash;
# 			Gravatar.init( 'body', '#wp-admin-bar-my-account' );
# 		});
# 	</script>
# <div style="display:none">
# </div>
# <script type="text/javascript">
# 		window.WPCOM_sharing_counts = {"https:\/\/sparkkorea.com\/%ed%80%b4%ec%a6%88\/":102};
# 	</script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var comment_like_text = {"loading":"\uac00\uc838\uc624\ub294 \uc911..."};
# /* ]]> */
# </script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var actionbardata = {"siteID":"163927570","siteName":"\ud3f4\ub9ac\ud14d\ub300  \uc2a4\ub9c8\ud2b8\uae08\uc735\uacfc","siteURL":"https:\/\/sparkkorea.com","icon":"<img alt='' src='https:\/\/s2.wp.com\/i\/logo\/wpcom-gray-white.png' class='avatar avatar-50' height='50' width='50' \/>","canManageOptions":"","canCustomizeSite":"","isFollowing":"","themeSlug":"pub\/dyad-2","signupURL":"https:\/\/wordpress.com\/start\/","loginURL":"https:\/\/wordpress.com\/log-in?redirect_to=https%3A%2F%2Fsparkkorea.com%2F%ED%80%B4%EC%A6%88%2F&signup_flow=account&domain=sparkkorea.com","themeURL":"https:\/\/wordpress.com\/theme\/dyad-2\/","xhrURL":"https:\/\/sparkkorea.com\/wp-admin\/admin-ajax.php","nonce":"df70ca2e50","isSingular":"1","isFolded":"","isLoggedIn":"","isMobile":"","subscribeNonce":"<input type=\"hidden\" id=\"_wpnonce\" name=\"_wpnonce\" value=\"2a2b0fc775\" \/>","referer":"https:\/\/sparkkorea.com\/%ed%80%b4%ec%a6%88\/","canFollow":"","feedID":"97558616","statusMessage":"","customizeLink":"https:\/\/sparkkorea.wordpress.com\/wp-admin\/customize.php?url=https%3A%2F%2Fsparkkorea.wordpress.com%2F%25ed%2580%25b4%25ec%25a6%2588%2F","postID":"102","shortlink":"https:\/\/wp.me\/Pb5P34-1E","canEditPost":"","editLink":"https:\/\/wordpress.com\/page\/sparkkorea.com\/102","statsLink":"https:\/\/wordpress.com\/stats\/post\/102\/sparkkorea.com","i18n":{"view":"\uc0ac\uc774\ud2b8 \ubcf4\uae30","follow":"\ud314\ub85c\uc6b0","following":"\ud314\ub85c\uc6b0\uc911","edit":"\ud3b8\uc9d1","login":"\ub85c\uadf8\uc778","signup":"\uac00\uc785","customize":"\uc0ac\uc6a9\uc790 \uc815\uc758\ud558\uae30","report":"\uc774 \ucf58\ud150\uce20 \uc2e0\uace0\ud558\uae30","themeInfo":"\ud14c\ub9c8 \uac00\uc838\uc624\uae30: Dyad 2","shortlink":"\ub2e8\ucd95 \ub9c1\ud06c \ubcf5\uc0ac","copied":"\ubcf5\uc0ac\ub428","followedText":"\uc774 \uc0ac\uc774\ud2b8\uc758 \uc0c8 \uae00\uc774 \uc774\uc81c <a href=\"https:\/\/wordpress.com\/\">\ub274\uc2a4\ud53c\ub4dc<\/a>\uc5d0 \ud45c\uc2dc\ub429\ub2c8\ub2e4.","foldBar":"\uc774 \ud45c\uc2dc\uc904 \ucd95\uc18c","unfoldBar":"\uc774 \ud45c\uc2dc\uc904 \ud655\uc7a5","editSubs":"\uad6c\ub3c5 \uad00\ub9ac","viewReader":"\ub9ac\ub354\uc5d0\uc11c \uc0ac\uc774\ud2b8 \ubcf4\uae30","viewReadPost":"View post in Reader","subscribe":"\uac00\uc785\ud558\uae30","enterEmail":"\uc774\uba54\uc77c \uc8fc\uc18c \uc785\ub825","followers":"","alreadyUser":"\uc774\ubbf8 \uc6cc\ub4dc\ud504\ub808\uc2a4\ub2f7\ucef4 \uacc4\uc815\uc744 \uac16\uace0 \uacc4\uc138\uc694? <a href=\"https:\/\/wordpress.com\/log-in?redirect_to=https%3A%2F%2Fsparkkorea.com%2F%ED%80%B4%EC%A6%88%2F&signup_flow=account&domain=sparkkorea.com\">\uc9c0\uae08 \ub85c\uadf8\uc778\ud558\uc138\uc694.<\/a>","stats":"\ud1b5\uacc4"}};
# /* ]]> */
# </script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var sharing_js_options = {"lang":"en","counts":"1","is_stats_active":"1"};
# /* ]]> */
# </script>
# <script src="https://s1.wp.com/_static/??-" type="text/javascript"></script><div class="actnbr-pub-dyad-2 actnbr-has-follow" id="actionbar"><ul><li class="actnbr-ellipsis actnbr-hidden"> <svg class="gridicon gridicon__ellipsis" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><g><circle cx="5" cy="12" r="2"></circle><circle cx="19" cy="12" r="2"></circle><circle cx="12" cy="12" r="2"></circle></g></svg> <div class="actnbr-popover tip tip-top-left actnbr-more"> <div class="tip-arrow"></div> <div class="tip-inner"> <ul> <li class="actnbr-sitename"><a href="https://sparkkorea.com"><img alt="" class="avatar avatar-50" height="50" scale="0" src="https://s2.wp.com/i/logo/wpcom-gray-white.png" width="50"/> 폴리텍대  스마트금융과</a></li> <li class="actnbr-folded-customize"><a href="https://sparkkorea.wordpress.com/wp-admin/customize.php?url=https%3A%2F%2Fsparkkorea.wordpress.com%2F%25ed%2580%25b4%25ec%25a6%2588%2F"><svg class="gridicon gridicon__customize" height="20px" viewbox="0 0 24 24" width="20px" xmlns="http://www.w3.org/2000/svg"><g><path d="M2 6c0-1.505.78-3.08 2-4 0 .845.69 2 2 2 1.657 0 3 1.343 3 3 0 .386-.08.752-.212 1.09.74.594 1.476 1.19 2.19 1.81L8.9 11.98c-.62-.716-1.214-1.454-1.807-2.192C6.753 9.92 6.387 10 6 10c-2.21 0-4-1.79-4-4zm12.152 6.848l1.34-1.34c.607.304 1.283.492 2.008.492 2.485 0 4.5-2.015 4.5-4.5 0-.725-.188-1.4-.493-2.007L18 9l-2-2 3.507-3.507C18.9 3.188 18.225 3 17.5 3 15.015 3 13 5.015 13 7.5c0 .725.188 1.4.493 2.007L3 20l2 2 6.848-6.848c1.885 1.928 3.874 3.753 5.977 5.45l1.425 1.148 1.5-1.5-1.15-1.425c-1.695-2.103-3.52-4.092-5.448-5.977z" data-reactid=".2.1.1:0.1b.0"></path></g></svg><span>사용자 정의하기<span></span></span></a></li> <li class="actnbr-signup"><a href="https://wordpress.com/start/">가입</a></li> <li class="actnbr-login"><a href="https://wordpress.com/log-in?redirect_to=https%3A%2F%2Fsparkkorea.com%2F%ED%80%B4%EC%A6%88%2F&amp;signup_flow=account&amp;domain=sparkkorea.com">로그인</a></li> <li class="actnbr-shortlink"><a href="https://wp.me/Pb5P34-1E">단축 링크 복사</a></li> <li class="flb-report"><a href="http://en.wordpress.com/abuse/">이 콘텐츠 신고하기</a></li> <li class="actnbr-subs"><a href="https://subscribe.wordpress.com/">구독 관리</a></li> </ul> </div> </div> </li> </ul></div>
# <script type="text/javascript">
# var windowOpen;
# 			jQuery( document.body ).on( 'click', 'a.share-twitter', function() {
# 				// If there's another sharing window open, close it.
# 				if ( 'undefined' !== typeof windowOpen ) {
# 					windowOpen.close();
# 				}
# 				windowOpen = window.open( jQuery( this ).attr( 'href' ), 'wpcomtwitter', 'menubar=1,resizable=1,width=600,height=350' );
# 				return false;
# 			});
# var windowOpen;
# 			jQuery( document.body ).on( 'click', 'a.share-facebook', function() {
# 				// If there's another sharing window open, close it.
# 				if ( 'undefined' !== typeof windowOpen ) {
# 					windowOpen.close();
# 				}
# 				windowOpen = window.open( jQuery( this ).attr( 'href' ), 'wpcomfacebook', 'menubar=1,resizable=1,width=600,height=400' );
# 				return false;
# 			});
# </script>
# <script type="text/javascript">
# // <![CDATA[
# (function() {
# try{
#   if ( window.external &&'msIsSiteMode' in window.external) {
#     if (window.external.msIsSiteMode()) {
#       var jl = document.createElement('script');
#       jl.type='text/javascript';
#       jl.async=true;
#       jl.src='/wp-content/plugins/ie-sitemode/custom-jumplist.php';
#       var s = document.getElementsByTagName('script')[0];
#       s.parentNode.insertBefore(jl, s);
#     }
#   }
# }catch(e){}
# })();
# // ]]>
# </script> <iframe id="likes-master" name="likes-master" scrolling="no" src="https://widgets.wp.com/likes/master.html?ver=20190321#ver=20190321&amp;lang=ko" style="display:none;"></iframe>
# <div id="likes-other-gravatars"><div class="likes-text"><span>%d</span> 블로거가 이것을 좋아합니다:</div><ul class="wpl-avatars sd-like-gravatars"></ul></div>
# <script async="" defer="" src="//stats.wp.com/w.js?60" type="text/javascript"></script>
# <script type="text/javascript">
# _tkq = window._tkq || [];
# _stq = window._stq || [];
# _tkq.push(['storeContext', {'blog_id':'163927570','blog_tz':'9','user_lang':'ko','blog_lang':'ko','user_id':'0'}]);
# _stq.push(['view', {'blog':'163927570','v':'wpcom','tz':'9','user_id':'0','post':'102','subd':'sparkkorea'}]);
# _stq.push(['extra', {'crypt':''}]);
# _stq.push([ 'clickTrackerInit', '163927570', '102' ]);
# 	</script>
# <noscript><img alt="" src="https://pixel.wp.com/b.gif?v=noscript" style="height:0px;width:0px;overflow:hidden"/></noscript>
# <script>
# if ( 'object' === typeof wpcom_mobile_user_agent_info ) {
#
# 	wpcom_mobile_user_agent_info.init();
# 	var mobileStatsQueryString = "";
#
# 	if( false !== wpcom_mobile_user_agent_info.matchedPlatformName )
# 		mobileStatsQueryString += "&x_" + 'mobile_platforms' + '=' + wpcom_mobile_user_agent_info.matchedPlatformName;
#
# 	if( false !== wpcom_mobile_user_agent_info.matchedUserAgentName )
# 		mobileStatsQueryString += "&x_" + 'mobile_devices' + '=' + wpcom_mobile_user_agent_info.matchedUserAgentName;
#
# 	if( wpcom_mobile_user_agent_info.isIPad() )
# 		mobileStatsQueryString += "&x_" + 'ipad_views' + '=' + 'views';
#
# 	if( "" != mobileStatsQueryString ) {
# 		new Image().src = document.location.protocol + '//pixel.wp.com/g.gif?v=wpcom-no-pv' + mobileStatsQueryString + '&baba=' + Math.random();
# 	}
#
# }
# </script>
# <div class="comment-likes-overlay" style="display: none;"></div><img alt=":)" id="wpstats" scale="0" src="https://pixel.wp.com/g.gif?blog=163927570&amp;v=wpcom&amp;tz=9&amp;user_id=0&amp;post=102&amp;subd=sparkkorea&amp;host=sparkkorea.com&amp;ref=https%3A%2F%2Fsparkkorea.com%2F&amp;fcp=375&amp;rand=0.045752704409295575"/></body></html>

# %%
linkall = soup.select("#id_py_quiz > a")

# %%
nameList = []
linkList = []

# %%
for i in range(0,len(linkall)):
    linkList.append(linkall[i].attrs["href"])
    nameList.append(linkall[i].text)

# %%
nameList
# Out:
# [' 1. 빅데이터 분석개요 및 파이썬프로그래밍',
#  ' 2. 파이썬 자료형 및 파일 데이터 불러오기 ',
#  ' 3. 파이썬 자료형 복습 ',
#  ' 4. 파이썬 문법 및 데이터 불러오기 ',
#  ' 5. 파이썬 문법 응용 ',
#  ' 파이썬 코드리뷰 ',
#  ' 파이썬 스크랩관련 설문 ']

# %%
linkList
# Out:
# ['https://goo.gl/forms/BLiJDnHCC8MDoHr82',
#  'https://goo.gl/forms/bTvHsy0PY3am0BCq2',
#  'https://goo.gl/forms/ylZZiZUHfMxm7etJ3',
#  'https://goo.gl/forms/bGl0bgpmmqLKyEHI3',
#  'https://goo.gl/forms/TtbUdSHNSOmFdIUN2',
#  'https://forms.gle/SMgrtcifZLKr5JNZA',
#  'https://forms.gle/Ep3PTfsTmk3pkdhK7']

# %%
finalResult = pd.concat([pd.DataFrame(nameList), pd.DataFrame(linkList)], axis=1)
finalResult.columns=["title","link"]

# %%
# 데이터 프레임 변환
finalResult = pd.DataFrame(zip(nameList,linkList), columns=["title","link"])
# csv 파일로 저장
finalResult.to_csv("./link_scraping_result.csv",encoding="ms949", index=False)

# %%
# SMTP 프로토콜 로드
import smtplib

# 이메일을 간단하게 보낼수 있는 라이브러리 로드
from email.message import EmailMessage

# %%
# GMAIL 메일 설정
# 보안설정 허용되지 않은 앱 설정 YES -> https://myaccount.google.com/lesssecureapps)
smtp_gmail = smtplib.SMTP('smtp.gmail.com', 587)

# 서버 연결을 설정하는 단계
smtp_gmail.ehlo()
 
# 연결을 암호화 (tls 방식)
smtp_gmail.starttls()
 
#로그인
smtp_gmail.login('haiteamm@gmail.com','gyrhks1308')
# Out:
# (235, b'2.7.0 Accepted')

# %% [markdown]
# ### 수신자 목록 불러오기

# %%
# 저장된 csv 파일 불러오기
emaillist = pd.read_csv("./emailaddress.csv", encoding='ms949')
emaillist

# 이메일 주소정보 리스트 변환
to = emaillist['이메일'].tolist()
to
# Out:
# ['haiteam@kopo.ac.kr', 'haiteam@naver.com']

# %% [markdown]
# ### 메일전송

# %%
msg=EmailMessage()
 
# 제목 입력
msg['Subject']="퀴즈 정보"
 
# 내용 입력
msg.set_content("퀴즈정보")
 
# 보내는 사람
msg['From']='haiteamm@gmail.com'
 
# 받는 사람
msg['To'] = ",".join(to)
 
file='link_scraping_result.csv'
fp = open(file,'rb')
file_data=fp.read()
msg.add_attachment(file_data,maintype='text',
                   subtype='plain',filename='link_scraping_result.csv')

smtp_gmail.send_message(msg)
# Out:
# {}

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import os
from os.path import join, dirname

if os.name == 'nt':
    os_name = 'nt'
elif os.name == 'mac':
    os_name = 'mac'
else:
    os_name = 'linux'

if os_name == 'nt':
    dirver_loc = "d:/chromedriver/chromedriver.exe"
else:
    dirver_loc = "/home/download/chromedriver/chromedriver.exe"

# %% [markdown]
# ### 크롬 브라우저 설정

# %%
# 크롬 옵션 설정
options = webdriver.ChromeOptions()
# 헤드리스 설정 시 리눅스 같이 웹화면 없는경우에도 웹페이지 실행가능함
#options.add_argument('headless')
options.add_argument('window-size=1920x1080')
#options.add_argument("disable-gpu")
# 웹 드라이버 정의
driver = webdriver.Chrome(dirver_loc, options=options)

# %% [markdown]
# ### 키워드 등록

# %%
naver_login_url = 'https://nid.naver.com/nidlogin.login'
cafe_url = 'https://cafe.naver.com/smartpolytech'
keyword_list = [
    '스프링','웹'
]
result_dic = {}
for keyword in keyword_list:
    result_dic[keyword] = {
        'title' : [],
        'writer' : [],
        'href' : [],
        'date' : []
    }
exception_flag = 0
exception_title_keyword_list = ['하둡','빅데이터']
exception_writer_keyword_list = []

# %% [markdown]
# ### 로그인

# %%
# Login Page
driver.get(naver_login_url)
driver.find_element_by_name('id').send_keys('ID')
driver.find_element_by_name('pw').send_keys('PWD')
driver.find_element_by_css_selector('#frmNIDLogin > fieldset > input').click()

# %%
# Login Page
driver.get(naver_login_url)

id = "아이디"
pw = "비밀번호"
driver.execute_script("document.getElementsByName('id')[0].value=\'"+id+"\'")
driver.execute_script("document.getElementsByName('pw')[0].value=\'"+pw+"\'")
driver.find_element_by_css_selector('#frmNIDLogin > fieldset > input').click()

# %% [markdown]
# ### 카페 접속 및 검색어 크롤링

# %%
# 카페 접속 및 검색어 크롤링
driver.get(cafe_url)
driver.implicitly_wait(3)
# driver.get_screenshot_as_file('naver_main_headless.png')

# %%
search_input = driver.find_element_by_xpath('//*[@id="topLayerQueryInput"]')

# %%
search_input.send_keys(keyword)
search_button = driver.find_element_by_xpath('//*[@id="info-search"]/form/button')
search_button.click()
driver.implicitly_wait(3)
# driver.get_screenshot_as_file('naver_main_headless.png’)

iframe = driver.find_element_by_css_selector('iframe#cafe_main')
driver.switch_to.frame(iframe)

show_element = driver.find_element_by_xpath("""//*[@id="listSizeSelectDiv"]/a""")
show_element.click()
show_50_element = driver.find_element_by_xpath("""//*[@id="listSizeSelectDiv"]/ul/li[7]/a""")
show_50_element.click()

# %%
req = driver.page_source
html = BeautifulSoup(req, 'html.parser')

# %%
title_list = []
writer_list = []
href_list = []
date_list = []

# %%
# driver.get_screenshot_as_file('naver_main_headless.png')
for tag in html.select('div#content-area div#main-area table tbody tr'):
    if len(tag.select('div.inner_list > a.article')) < 1:
        continue

    title = tag.select('div.inner_list > a.article')[0].text.strip()
    number = tag.select('div.inner_number')[0].text.strip()
    writer = tag.select('td.p-nick > a.m-tcol-c')[0].text.strip()
    date = tag.select('td.td_date')[0].text.strip()
    if ':' in date:
        date = today

    # 제목 예외처리
    for exception_title_keyword in exception_title_keyword_list:
        if exception_title_keyword in title:
            exception_flag = 1
            break
    # 글쓴이 예외처리
    for exception_writer_keyword in exception_writer_keyword_list:
        if exception_writer_keyword == writer:
            exception_flag = 1
            break

    if exception_flag == 1:
        exception_flag = 0
        continue

    href = 'https://cafe.naver.com/joonggonara/'+number
    # print(title,"//",writer,"//",date)
    # print(href)

    if writer in writer_list:
        pass
    else:
        title_list.append(title)
        writer_list.append(writer)
        href_list.append(href)
        date_list.append(date)
driver.switch_to.default_content()
driver.quit()

# %%
finalResult = pd.DataFrame(zip(title_list,writer_list,href_list,date_list))

# %%
finalResult

# %%
https://www.coupang.com/np/categories/194810?page=1
https://www.coupang.com/np/categories/194810?page=2

# %%
import requests
from bs4 import BeautifulSoup

# %%
def getPageString(url):
    data = requests.get(url)
    bsHtml = BeautifulSoup(data.content, "html.parser")
    
    print(bsObj)
    return data.content

# %%
url = "https://www.coupang.com/np/categories/194810?page=1"

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import os
from os.path import join, dirname

if os.name == 'nt':
    os_name = 'nt'
elif os.name == 'mac':
    os_name = 'mac'
else:
    os_name = 'linux'

if os_name == 'nt':
    dirver_loc = "d:/chromedriver/chromedriver.exe"
else:
    dirver_loc = "/home/download/chromedriver/chromedriver.exe"

# %%
# 크롬 옵션 설정
options = webdriver.ChromeOptions()
# 헤드리스 설정 시 리눅스 같이 웹화면 없는경우에도 웹페이지 실행가능함
#options.add_argument('headless')
options.add_argument('window-size=1920x1080')
#options.add_argument("disable-gpu")
#웹 드라이버 정의
driver = webdriver.Chrome(dirver_loc, options=options)

# %%
url = "https://www.coupang.com"

driver.get(url)

# %%
searchBox =driver.find_element_by_xpath('//*[@id="headerSearchKeyword"]')

# %%
eggUrl = driver.current_url

# %%
searchBox.clear()

# %%
searchBox.send_keys("계란")

# %%
searchBox.send_keys(u'\ue007')

# %%
eggUrl = driver.current_url

# %%
eggUrl
# Out:
# 'https://www.coupang.com/np/search?component=&q=%EA%B3%84%EB%9E%80&channel=user'

# %%
eggSource = driver.page_source

# %%
bsSource = BeautifulSoup(eggSource,"html.parser")

# %% [markdown]
# ### 1. bs4 과제

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.coupang.com/np/categories/194810?page=1'

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36',}
data=requests.get(url,headers=headers)

# %%
bsObj = BeautifulSoup(data.text, "html.parser")

ul = bsObj.find("ul", {"id":"productList"})
lis = ul.findAll("li")

# %%
ul = bsObj.find("ul", {"id":"productList"})

# %%
lis = ul.findAll("li")

# %%
print(len(lis))
# Out:
# 60

# %%
nameList= []
priceList = []

# %%
for i in range(0,len(lis)):
    step1 = lis[i].find("dt",{"class":"image"}).find("img")
    nameList.append(step1.attrs["alt"])
    step2 = lis[i].find("em",{"class","sale"})
    priceList.append(step2.find("strong").text)

# %%
len(nameList)
# Out:
# 60

# %%
len(priceList)
# Out:
# 60

# %%
import pandas as pd
pd.DataFrame(zip(nameList,priceList))
# Out:
#                                                     0       1
# 0                       더마시나 무항생제 구운계란60구, 1개, 2,100g  10,300
# 1                    오복유통 HACCP인증 구운계란 2판60구, 60구, 2판  13,900
# 2                        참나무촌 무염훈제계란, 30개입, 1.2kg(한판)   6,200
# 3                     꾼란 맥반석 구운계란 30구 1판, 30개입, 1.2kg   7,900
# 4                            맛군 촉촉 쫄깃 구운 계란, 30알, 1박스   7,900
# 5                     감동란 간이베어 있는 촉촉한 반숙계란, 50g, 30개입  16,900
# 6               [ 계란사랑 ] 맥반석 구운계란 구운란 60구 (2판), 2700g  11,900
# 7                       진주햄 오마이 포켓 메추리알 5p, 25g, 10개입   9,440
# 8                      더마시나 영양간식 구운계란30구, 30구, 1,050g   4,200
# 9      맥반석 구운계란30 망있음 소금포함 훈제란바다종합유통 구운계란30구 훈제란, 30개   5,700
# 10               꾼란 맥반석 구운계란 30구+30구 총2판, 60개입, 1.2kg  11,900
# 11  에그에그 무항생제 맥반석 구운계란 1+1 대란 2판 총60구 훈제, 2개, 구운계란...  11,900
# 12   이엔에프푸드 반숙란 촉촉하게 간이배어 방금삶은것처럼 고소한 뉴반숙란 30개, 1500g  13,800
# 13  에그에그 무항생제 맥반석 구운계란 1+1 대란 2판 총60구 훈제, 1개, 구운란3...  14,900
# 14                     미스터유 참숯 구운란 훈제 맥반석구운계란 30구, 대란   4,900
# 15  농가정보서비스 [나린뜰] 맥반석 구운계란 1+1 [2판 무료배송], 1개, 990g...  10,300
# 16  [오아시스마켓] 10구 한시특가>자연이란-무항생제 동물복지유정란 행복한 닭의 유정란...   3,380
# 17  [데이타임특가] 참숯 구운계란 HACCP 구운란 30구 60구 간식 다이어트, 1b...   4,900
# 18                                 닭대리의 살균난백, 1kg, 2병  14,800
# 19                [호유란] 짜지않고 촉촉한 반숙계란 30개입, 1개, 1500g  15,660
# 20                  행복담기 참나무로 쫄깃하게 훈제 메추리알, 30개입, 15g  12,800
# 21                           오복유통 HACCP인증 구운계란 1판 30구   5,700
# 22                   [행복란] 촉촉하고 부드러운 반숙계란 행복란 30구, 단품  10,900
# 23                      [명품구운란] 구운계란 맥반석계란 구운란 대란 30구   6,500
# 24               푸른들농장 영월 동물복지 무항생제 유정란 청란 (청계란), 20개  12,900
# 25                           가농 금계란 1+등급 특란, 40개, 60g  12,900
# 26            행복담기 참나무로 쫄깃하게 훈제메추리알 15gx30개입, 1개, 15g   9,800
# 27                          계림농장 무항생제 반숙란 30구 1판, 1세트  11,900
# 28                             나린뜰 무항생제 맥반석 구운계란, 30구   4,500
# 29                            반찬단지 삶아서깐 메추리알, 1개, 1kg   5,900
# 30                      자연방사 유기농 야채먹고 자란 유정란 40구, 1박스  22,800
# 31       훈제 메추리알 15g*30입 2개 아침대용으로 간편한 야식으로 안성맞춤, 60입  23,500
# 32   전북김제 맥반석 구운계란 30구 60구 90구 120구, 1box, 김제안심구운란60구  12,900
# 33                           [나린뜰] 맥반석 구운계란(당일출고), 1개   6,900
# 34                               에그모닝 반숙계란, 1box, 20구   9,860
# 35                         영일 아라리 계란 30g(1통-50개), 1박스  23,200
# 36                           영일 아라리 계란 (훈제란) 30g, 50개  21,500
# 37  자연건조 구운계란 구운란 구운달걀 30구 60구 90구 120구, 1box, 구운란...   6,900
# 38         더마시나 구운계란 판매자 추천상품 모음(무배), 1개, 구운계란30구(1판)   4,200
# 39                       참나무촌 참맛훈제계란, 30개입, 1.2kg(한판)   7,200
# 40                 [명품구운란] 구운계란 맥반석계란 구운란 대란 60구 (2판)  15,300
# 41                                 닭대리의 살균난백, 1kg, 4병  26,100
# 42                    푸르젠 [동물복지 무항생제인증] 유정청란, 1개, 20구  14,900
# 43                                  중국식품 건두부 중국두부 1kg   8,000
# 44                      소원농장 무항생제 동물복지 유정란 계란 달걀, 20구  10,900
# 45                             훈민정과 꿀머금 무항생제 구운란, 30구   8,700
# 46                 자연애찬 반숙이, 반숙란 30개입 × 1개, 1개, 1350g  13,900
# 47                                     깐 메추리알 1kg, 1개   4,900
# 48                            중국식품 훠궈재료 두유피 중국두부 500g   5,940
# 49       [호유란] 짜지않고 촉촉한 반숙계란 10개 (2개입 X 5개), 1개, 500g   7,900
# 50  푸르젠 참숯돌에서 구운계란 (개당 45~50g 국산 구운소금증정), 30개, (개당...   7,900
# 51                      더마시나 무항생제 구운계란30구(1 050g), 1개   4,200
# 52                      에코팜 금에그 30팩 깐계란 구운달걀 구운계란 구운란  14,700
# 53                                  계림농장 아산맑은 반숙란, 1개  11,900
# 54                         행복담기 참나무로 쫄깃하게 훈제 메추리알, 단품  10,410
# 55                                     알나라깐메추리알1kg/새한   4,560
# 56                    참조은 구운계란 (망) 30구 x 2판, 60구, 45g  14,500
# 57  살림살이몰 HACCP 구운계란 3판 2판 1판 맥반석계란 구운란, 30구, 1구당 ...   8,000
# 58              아라리계란 30gX10개입개별포장구운계란염지란 바다종합유통, 10개   4,800
# 59                        중국식품 송화단(오리알) 중국계란 350g(6개)   3,500

# %%
step1 = lis[0].find("dt",{"class":"image"}).find("img")

# %%
step1
# Out:
# <img alt="더마시나 무항생제 구운계란60구, 1개, 2,100g" data-src="..." onerror='this.src="//t1a.coupangcdn.com/thumbnails/remote/600x600/image/coupang/common/no_img_1000_1000.png"' onload="window.logTime &amp;&amp; logTime(this);window.logImageLoadTime &amp;&amp; logImageLoadTime(this);" src="//thumbnail12.coupangcdn.com/thumbnails/remote/230x230ex/image/vendor_inventory/fc72/b761361f17c61ea3612182c6379d3904745edb2ae4b784821c44466b7e94.jpg" width="100%"/>

# %%
step1.attrs["alt"]
# Out:
# '더마시나 무항생제 구운계란60구, 1개, 2,100g'

# %%
step2 = lis[0].find("em",{"class","sale"})

# %%
step2.find("strong").text
# Out:
# '10,300'

# %%
url2 = 'https://www.coupang.com/np/categories/194810?page=1'

# %%
data=requests.get(url2)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     284             else:
# --> 285                 raise SocketError(str(e))
#     286         except OpenSSL.SSL.ZeroReturnError as e:
#
# OSError: (10060, 'WSAETIMEDOUT')
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     356             if read is False or not self._is_method_retryable(method):
# --> 357                 raise six.reraise(type(error), error, _stacktrace)
#     358             elif read is not None:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     284             else:
# --> 285                 raise SocketError(str(e))
#     286         except OpenSSL.SSL.ZeroReturnError as e:
#
# ProtocolError: ('Connection aborted.', OSError("(10060, 'WSAETIMEDOUT')"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-109-ce22aae67f2b> in <module>
# ----> 1 data=requests.get(url2)
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     488
#     489         except (ProtocolError, socket.error) as err:
# --> 490             raise ConnectionError(err, request=request)
#     491
#     492         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', OSError("(10060, 'WSAETIMEDOUT')"))

# %%
https://www.coupang.com/np/categories/194810

# %%
ㄹ개ㅡ ㅣㅑㅠㄴ.ㄴㅅ갸ㅜ

# %%
ㅇ
# Out:
# <html lang="ko-KR"><!--<![endif]--><head>
# <meta charset="utf-8"/>
# <meta content="zaNrGtrOLMjglkziY2IvmL8dOXyCWHGArDHqFazJQVI" name="google-site-verification"/>
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="//cart.coupang.com" rel="dns-prefetch"/>
# <link href="//assets.coupang.com" rel="dns-prefetch"/>
# <link href="//assets2.coupang.com" rel="dns-prefetch"/>
# <link href="//assets.coupangcdn.com" rel="dns-prefetch"/>
# <link href="//asset1.coupangcdn.com" rel="dns-prefetch"/>
# <link href="//private.coupang.com" rel="dns-prefetch"/>
# <link href="//triforce.coupang.com" rel="dns-prefetch"/>
# <link href="//img1a.coupangcdn.com" rel="dns-prefetch"/>
# <link href="//image1.coupangcdn.com" rel="dns-prefetch"/>
# <link href="//thumbnail1.coupangcdn.com" rel="dns-prefetch"/>
# <link href="//www.facebook.com" rel="dns-prefetch"/>
# <link href="//www.google.com" rel="dns-prefetch"/>
# <link href="//www.google.co.kr" rel="dns-prefetch"/>
# <link href="//stats.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="//connect.facebook.net" rel="dns-prefetch"/>
# <title>쿠팡! - 계란</title>
# <meta content="COUPANG" property="og:title"/>
# <meta content="//image15.coupangcdn.com/image/mobile/v3/img_fb_like.png" property="og:image"/>
# <meta content="https://www.coupang.com" property="og:url"/>
# <meta content="쿠팡은 로켓배송 - 계란에 대한 검색결과입니다. 우유, 두부, 계란 30구, 식빵, 라면, 샐러드, 바나나, 양파, 구운계란, " property="og:description"/>
# <meta content="쿠팡은 로켓배송 - 계란에 대한 검색결과입니다. 우유, 두부, 계란 30구, 식빵, 라면, 샐러드, 바나나, 양파, 구운계란, " name="description"/>
# <meta content="여성패션, 남성패션, 베이비패션 (0~3세), 여아패션 (3세 이상), 남아패션 (3세 이상), 스포츠패션, 신발, 가방/잡화, 명품패션, 뷰티, 출산/유아동, 식품, 주방용품, 생활용품, 홈인테리어, 가전디지털, 스포츠/레저, 자동차용품, 도서/음반/DVD, 완구/취미, 문구/오피스, 반려동물용품, 헬스/건강식품, " name="keywords"/>
# <meta content="website" property="og:type"/>
# <link href="//image14.coupangcdn.com/image/coupang/favicon/v2/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <!--[if lt IE 9]>
# <script src="/resources/20190709144817/np/js/lib/html5/html5.js" type="text/javascript"></script>
# <![endif]-->
# <!--[if lte IE 9]>
# <script src="//asset3.coupangcdn.com/cdnjs/json2/20150503/json2.js" type="text/javascript"></script>
# <![endif]-->
# <link href="/resources/20190709144817/np/css/common.min.css" rel="stylesheet" type="text/css"/>
# <link href="/resources/20190709144817/np/css/side.css" rel="stylesheet" type="text/css"/>
# <link href="/resources/20190709144817/np/css/search.min.css" rel="stylesheet" type="text/css"/>
# <style>#coupang-banner span.banner-bg{background:#e2faff;border-bottom:1px solid #cac6c3}
#         #coupang-banner span.banner-bg{float:left;width:100%;}
#         #coupang-banner .banner-middle{width:980px;margin:0 auto;}
#         #coupang-banner .banner-middle a{float:left;display: inline-block}</style>
# <script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="../modules/search/search" src="/resources/20190709144817/np/js/modules/../modules/search/search.js" type="text/javascript"></script><script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="../modules/search/utils/searchLogHelper-min" src="/resources/20190709144817/np/js/modules/../modules/search/utils/searchLogHelper-min.js" type="text/javascript"></script><script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="../modules/search/utils/searchWebLogHelper-min" src="/resources/20190709144817/np/js/modules/../modules/search/utils/searchWebLogHelper-min.js" type="text/javascript"></script><script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="../modules/common/template/search/SearchFocus" src="/resources/20190709144817/np/js/modules/../modules/common/template/search/SearchFocus.js" type="text/javascript"></script><script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="../modules/search/merchandisingWidget" src="/resources/20190709144817/np/js/modules/../modules/search/merchandisingWidget.js" type="text/javascript"></script><script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="../lib/jquery/plugin/stringify" src="/resources/20190709144817/np/js/modules/../lib/jquery/plugin/stringify.js" type="text/javascript"></script><script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="../page-controllers/common/controller" src="/resources/20190709144817/np/js/modules/../page-controllers/common/controller.js" type="text/javascript"></script><script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="triforce" src="//asset3.coupangcdn.com/customjs/triforce/0.0.23/triforce.min.js" type="text/javascript"></script><script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="handlebars" src="//asset3.coupangcdn.com/cdnjs/handlebars.js/1.3.0/handlebars.min.js" type="text/javascript"></script><script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="jquery" src="//asset3.coupangcdn.com/cdnjs/jquery/1.11.1/jquery.min.js" type="text/javascript"></script><script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="search/utils/searchCommon-min" src="/resources/20190709144817/np/js/modules/search/utils/searchCommon-min.js" type="text/javascript"></script><script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="search/searchWebLogSchemas" src="/resources/20190709144817/np/js/modules/search/searchWebLogSchemas.js" type="text/javascript"></script><script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="common/essentialData" src="/resources/20190709144817/np/js/modules/common/essentialData.js" type="text/javascript"></script><script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="search/utils/weblogUtils-min" src="/resources/20190709144817/np/js/modules/search/utils/weblogUtils-min.js" type="text/javascript"></script><script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="search/utils/searchWebLogHelper-min" src="/resources/20190709144817/np/js/modules/search/utils/searchWebLogHelper-min.js" type="text/javascript"></script><script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="common/utils/cookieUtils" src="/resources/20190709144817/np/js/modules/common/utils/cookieUtils.js" type="text/javascript"></script><script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="common/adsplatform/adsplatformLogger" src="/resources/20190709144817/np/js/modules/common/adsplatform/adsplatformLogger.js" type="text/javascript"></script><script async="" charset="utf-8" data-requirecontext="coupangWeb" data-requiremodule="common/gnbCashWidget" ...
# <body class="search renewal" data-coulog-config='{"initCustomURL":"", "initLogLabel":"", "preventDefaultLogging":"true"}' data-fodium-web-url="//reco.coupang.com" data-reference='{"controller":"search","isSubscribable":"","bundleid":"62","resourcedomain":"","abtestkey":[{"key":"2048","option":"B"},{"key":"2561","option":"A"},{"key":"1027","option":"C"},{"key":"1030","option":"C"},{"key":"4104","option":"A"},{"key":"1033","option":"C"},{"key":"3083","option":"B"},{"key":"2060","option":"A"},{"key":"1036","option":"C"},{"key":"3084","option":"A"},{"key":"3086","option":"B"},{"key":"1039","option":"C"},{"key":"3087","option":"B"},{"key":"2576","option":"A"},{"key":"1042","option":"C"},{"key":"2578","option":"B"},{"key":"3602","option":"A"},{"key":"5138","option":"A"},{"key":"3603","option":"A"},{"key":"3092","option":"B"},{"key":"1045","option":"C"},{"key":"2069","option":"B"},{"key":"3606","option":"B"},{"key":"1048","option":"C"},{"key":"3608","option":"C"},{"key":"3097","option":"E"},{"key":"2587","option":"A"},{"key":"4636","option":"B"},{"key":"4125","option":"B"},{"key":"2078","option":"B"},{"key":"2590","option":"B"},{"key":"3102","option":"B"},{"key":"4638","option":"B"},{"key":"3103","option":"C"},{"key":"3616","option":"A"},{"key":"2081","option":"B"},{"key":"1057","option":"C"},{"key":"3618","option":"A"},{"key":"1060","option":"C"},{"key":"1572","option":"A"},{"key":"3620","option":"A"},{"key":"3621","option":"A"},{"key":"3121","option":"B"},{"key":"3635","option":"B"},{"key":"3126","option":"A"},{"key":"3640","option":"B"},{"key":"3641","option":"B"},{"key":"4155","option":"B"},{"key":"2621","option":"B"},{"key":"1087","option":"A"},{"key":"3137","option":"B"},{"key":"68","option":"A"},{"key":"69","option":"A"},{"key":"581","option":"A"},{"key":"3141","option":"B"},{"key":"3143","option":"B"},{"key":"3655","option":"A"},{"key":"3657","option":"A"},{"key":"588","option":"A"},{"key":"3661","option":"A"},{"key":"3149","option":"A"},{"key":"2641","option":"B"},{"key":"3154","option":"A"},{"key":"2644","option":"B"},{"key":"2645","option":"B"},{"key":"1110","option":"A"},{"key":"3158","option":"A"},{"key":"3670","option":"B"},{"key":"2137","option":"B"},{"key":"3673","option":"A"},{"key":"3163","option":"B"},{"key":"3165","option":"B"},{"key":"5215","option":"A"},{"key":"2656","option":"B"},{"key":"2657","option":"B"},{"key":"3681","option":"B"},{"key":"2145","option":"A"},{"key":"1634","option":"B"},{"key":"2147","option":"A"},{"key":"3684","option":"A"},{"key":"3687","option":"A"},{"key":"1640","option":"B"},{"key":"3691","option":"A"},{"key":"2157","option":"A"},{"key":"3693","option":"A"},{"key":"1139","option":"A"},{"key":"3192","option":"B"},{"key":"2680","option":"B"},{"key":"3197","option":"B"},{"key":"4228","option":"B"},{"key":"3205","option":"B"},{"key":"4743","option":"B"},{"key":"3208","option":"B"},{"key":"3720","option":"B"},{"key":"3211","option":"B"},{"key":"3729","option":"B"},{"key":"2706","option":"A"},{"key":"3218","option":"A"},{"key":"2197","option":"B"},{"key":"150","option":"A"},{"key":"1686","option":"B"},{"key":"3735","option":"B"},{"key":"3224","option":"B"},{"key":"3738","option":"A"},{"key":"4250","option":"B"},{"key":"4251","option":"B"},{"key":"4252","option":"B"},{"key":"3233","option":"B"},{"key":"2723","option":"B"},{"key":"2724","option":"B"},{"key":"3239","option":"B"},{"key":"3240","option":"B"},{"key":"169","option":"B"},{"key":"1706","option":"B"},{"key":"2218","option":"B"},{"key":"3755","option":"A"},{"key":"2731","option":"A"},{"key":"3245","option":"B"},{"key":"2735","option":"A"},{"key":"2736","option":"A"},{"key":"3762","option":"B"},{"key":"2226","option":"A"},{"key":"692","option":"B"},{"key":"1204","option":"A"},{"key":"3253","option":"A"},{"key":"182","option":"B"},{"key":"695","option":"A"},{"key":"1719","option":"B"},{"key":"2743","option":"A"},{"key":"2232","option":"B"},{"key":"3257","option":"A"},{"key":"2748","option":"B"},{"key":"2238","option":"B"},{"key":"3262","o ...
#     "qctoken":"","collectionType":"Search", "webDomain":"", "isTargetOfDeliveryInformation":"false", "freeShippingOverAmount":"", "trCid":"", "trAid":"" }'>
# <!-- skip navigator -->
# <nav id="skip-navigation">
# <h2>스킵 네비게이션</h2>
# <a href="#login">#로그인 바로가기</a>
# <a href="#header">#메뉴 바로가기</a>
# <a href="#gnbAnalytics">#카테고리 바로가기</a>
# <a href="#contents">#본문 바로가기</a>
# </nav>
# <hr/>
# <div data-use-adzerk="true" id="coupang-banner"><span class="banner-bg"><div class="banner-middle"><a data-adsplatform='{"clickLogUri":"https://e-10116.adzerk.net/r?e=...&amp;s=C1KKhufAv8ZrssXjGPUtKU1TJMI", "impressionLogUri":"https://e-10116.adzerk.net/i.gif?e=...&amp;s=bh2eTYNffaeKWVIOpH6aoBOTgPA", "viewImpression":"https://e-10116.adzerk.net/e.gif?e=...&amp;s=Bn5GrMZh7l7pxo2d93q55QHZNJA"}' data-coulog='{"grp":"GNB","logType":"click","logCategory":"event","logLabel":"Topbanner_0"}' data-log-props='{ "id" : "top_banner", "param" : { "bannerLabel":"Topbanner_0"} }' href="https://www.coupang.com/np/promotion/43433"><img alt="" src="https://static.coupangcdn.com/pa/cmg_paperboy/image/1562658149483/0710_wowday_C0_1.jpg"/></a><a data-adsplatform='{"clickLogUri":"https://e-10116.adzerk.net/r?e=...&amp;s=XY2J28JI2v1ABZ9o12Xf_zObZoE", "impressionLogUri":"https://e-10116.adzerk.net/i.gif?e=...&amp;s=WDvmw1zJ523hzn4x5CVWt4IeXv0", "viewImpression":"https://e-10116.adzerk.net/e.gif?e=...&amp;s=CXTHCGLBkHBEG3RgjEqDjR9K2VI"}' data-coulog='{"grp":"GNB","logType":"click","logCategory":"event","logLabel":"Topbanner_1"}' data-log-props='{ "id" : "top_banner", "param" : { "bannerLabel":"Topbanner_1"} }' href="/np/promotion/43150"><img alt="" src="https://static.coupangcdn.com/qa/cmg_paperboy/image/1562222176882/NEW%26HOT_C0_02.jpg"/></a></div></span><a aria-label="Close" class="close" data-coulog='{"grp":"GNB","logType":"click","logCategory":"event","logLabel":"top_banner_close"}' data-log-props='{ "id" : "top_banner_close" }' role="button">배너 그만 보기</a></div>
# <!--[if lte IE 8]>
# <div id="browserSupportWrap">
#     <div class="bs-wrap">
#         <p class="bs-message">고객님의 브라우저에서는 쿠팡이 정상 동작하지 않습니다.<br />
#             인터넷 익스플로러 업데이트, 크롬 또는 파이어폭스 브라우저를 설치하세요.</p>
#         <ul class="bs-browser-download">
#             <li class="ie"><a href="http://windows.microsoft.com/ko-kr/internet-explorer/download-ie" target="_blank">인터넷 익스플로러<br /> <em>업데이트하기</em></a></li>
#             <li class="chrome"><a href="https://www.google.com/chrome/browser/desktop/index.html" target="_blank">크롬<br /> <em>설치하기</em></a></li>
#             <li class="firefox"><a href="https://www.mozilla.org/ko/firefox/new/" target="_blank">파이어폭스<br /> <em>설치하기</em></a></li>
#         </ul>
#     </div>
# </div>
# <![endif]-->
# <div class="renewal search srp-sync srp-sync-brand" id="container">
# <div class="renewal-header"><header id="header"><div class="sticky-wrapper" id="sticky-wrapper" style="height: 91px;"><section><div class="clearFix"><h1><a data-coulog='{"grp":"GNB","logType":"click","logCategory":"event","logLabel":"coupang_logo"}' data-log-props='{ "id": "coupang_logo" }' href="/" title="Coupang - 내가 잘사는 이유"><img alt="쿠팡로고" height="41" src="//image12.coupangcdn.com/image/coupang/common/logo_coupang_w350.png" width="174"/></a></h1><div class="search-form product-search clearFix"><form action="/np/search" data-actionurl="/np/search" id="headerSearchForm" method="get"><fieldset><legend>상품검색</legend><div class="header-searchForm"><div class="select--category"><a class="select--category--button" href="#"></a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> <a class="select--category__current" data-linkcode="" href="#" id="currentCategoryText">전체</a> </div><select class="search_category_ ...
# <span class="gnb-banner" style="background: #ffffff">
# <a class="category-banner-button" data-coulog='{"grp":"categoryMenu_rightBanner","logType":"click","logCategory":"event","logLabel":"womanclothe"}' data-log-props='{ "id":"category_menu_banner", "param":{"categoryLabel":"womanclothe"} }' href="/np/search?q=%EB%A6%B0%EB%84%A8%EC%9B%90%ED%94%BC%EC%8A%A4&amp;component=224931" title="여성패션">여성패션</a>
# <img alt="여성패션" class="category-banner-image" data-banner-src="//image11.coupangcdn.com/image/displayitem/displayitem_1572ac68-6111-414f-a4d5-3d4dfe1104bb.jpg"/>
# </span>
# </div></div></li> <li class="beauty"><a class="first-depth" data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"beauty"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"beauty"} }' href="/np/categories/176522">뷰티<i class="select-icon"></i></a><div class="depth"><div class="depth-list banner third"><ul> <li class="second-depth-list"><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"beauty"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"beauty"} }' href="/np/campaigns/248">명품화장품 <i class="depth-select-icon"></i></a><div class="third-depth-list"><ul> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"beauty"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"beauty"} }' href="/np/categories/176860">스킨케어</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"beauty"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"beauty"} }' href="/np/categories/176875">메이크업</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"beauty"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"beauty"} }' href="/np/categories/176901">향수</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"beauty"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"beauty"} }' href="/np/categories/176904">헤어케어</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"beauty"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"beauty"} }' href="/np/categories/176911">바디케어</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"beauty"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"beauty"} }' href="/np/categories/176917">남성화장품</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"beauty"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"beauty"} }' href="/np/categories/176925">뷰티소품</a></li> </ul></div></li> <li class="second-depth-list"><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"beauty"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"beauty"} }' href="/np/categories/176530">스킨케어 <i class="depth-select-icon"></i></a><div class="third-depth-list"><ul> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"beauty"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"beauty"} }' href="/np/categories/176531">기초화장품</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"beauty"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"beauty"} }' href="/np/categories/176542">클렌징/필링</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"beauty"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"beauty"} }' href="/np/categories/176554">마스크/팩</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"beauty"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"beauty"} }' href="/np/categories/176563">선케어/태닝</a></li> </ul></div></li> <li class="second-depth-list"><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"beauty"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"beauty"} }' href="/np/categories/176573">메이크업 <i class="depth-select-icon"></i></a><div class="third-depth-list"><ul> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"beauty"}' data-log-props='{ "id ...
# <span class="gnb-banner" style="background: #ffffff">
# <a class="category-banner-button" data-coulog='{"grp":"categoryMenu_rightBanner","logType":"click","logCategory":"event","logLabel":"beauty"}' data-log-props='{ "id":"category_menu_banner", "param":{"categoryLabel":"beauty"} }' href="/np/search?q=%EB%84%A4%EC%9D%BC%ED%8C%81&amp;component=427210" title="뷰티">뷰티</a>
# <img alt="뷰티" class="category-banner-image" data-banner-src="//image14.coupangcdn.com/image/displayitem/displayitem_0280ccae-5c76-48c6-a6aa-c1fe6da75c01.jpg"/>
# </span>
# </div></div></li> <li class="child-birth"><a class="first-depth" data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"baby"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"baby"} }' href="/np/categories/221934">출산/유아동<i class="select-icon"></i></a><div class="depth"><div class="depth-list banner third"><ul> <li class="second-depth-list"><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"baby"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"baby"} }' href="/np/categories/227021">유기농/친환경 전문관 <i class="depth-select-icon"></i></a><div class="third-depth-list"><ul> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"baby"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"baby"} }' href="/np/categories/227022">분유/어린이식품</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"baby"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"baby"} }' href="/np/categories/227027">기저귀</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"baby"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"baby"} }' href="/np/categories/227071">위생/건강/세제</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"baby"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"baby"} }' href="/np/categories/227097">수유/이유용품</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"baby"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"baby"} }' href="/np/categories/227130">유아동패션</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"baby"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"baby"} }' href="/np/categories/227228">유아가구/데코</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"baby"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"baby"} }' href="/np/categories/227234">유아동침구</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"baby"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"baby"} }' href="/np/categories/227241">외출용품</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"baby"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"baby"} }' href="/np/categories/227246">매트/안전용품</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"baby"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"baby"} }' href="/np/categories/227251">완구/교구</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"baby"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"baby"} }' href="/np/categories/227371">임부/출산선물세트</a></li> </ul></div></li> <li class="second-depth-list"><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"baby"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"baby"} }' href="/np/categories/223843">베이비패션 <i class="depth-select-icon"></i></a><div class="third-depth-list"><ul> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"baby"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"baby"} }' href="/np/categories/223845">베이비 여아</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"baby"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"baby"} }' href="/np/categories/223846">베이비 남아</a></li> <li><a data-coulog='{"grp": ...
# <span class="gnb-banner" style="background: #ffffff">
# <a class="category-banner-button" data-coulog='{"grp":"categoryMenu_rightBanner","logType":"click","logCategory":"event","logLabel":"baby"}' data-log-props='{ "id":"category_menu_banner", "param":{"categoryLabel":"baby"} }' href="/np/promotion/29759" title="출산/유아동">출산/유아동</a>
# <img alt="출산/유아동" class="category-banner-image" data-banner-src="//image15.coupangcdn.com/image/displayitem/displayitem_e191242e-b3a4-42de-85e4-63f5285c8ba5.jpg"/>
# </span>
# </div></div></li> <li class="food"><a class="first-depth" data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"food"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"food"} }' href="/np/categories/194276">식품<i class="select-icon"></i></a><div class="depth"><div class="depth-list banner third"><ul> <li class="second-depth-list"><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"food"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"food"} }' href="/np/categories/203052">유기농/친환경 전문관 <i class="depth-select-icon"></i></a><div class="third-depth-list"><ul> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"food"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"food"} }' href="/np/categories/203054">과일</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"food"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"food"} }' href="/np/categories/203066">견과/건과</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"food"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"food"} }' href="/np/categories/203073">채소</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"food"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"food"} }' href="/np/categories/203087">쌀/잡곡</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"food"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"food"} }' href="/np/categories/203096">축산/계란</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"food"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"food"} }' href="/np/categories/203103">수산물/건어물</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"food"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"food"} }' href="/np/categories/203112">음료</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"food"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"food"} }' href="/np/categories/203117">유제품/두유</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"food"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"food"} }' href="/np/categories/203123">커피/원두/차</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"food"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"food"} }' href="/np/categories/203128">과자/시리얼</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"food"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"food"} }' href="/np/categories/203134">면/통조림/가공식품</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"food"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"food"} }' href="/np/categories/203139">가루/조미료/오일</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"food"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"food"} }' href="/np/categories/203144">장/소스/드레싱/식초</a></li> <li class="more-category"><a href="/np/categories/203052">더보기</a></li> </ul></div></li> <li class="second-depth-list"><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"food"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"food"} }' href="/np/categories/194282">과일 <i class="depth-select-icon"></i></a><div clas ...
# <span class="gnb-banner" style="background: #FFF">
# <a class="category-banner-button" data-coulog='{"grp":"categoryMenu_rightBanner","logType":"click","logCategory":"event","logLabel":"food"}' data-log-props='{ "id":"category_menu_banner", "param":{"categoryLabel":"food"} }' href="/np/campaigns/1884" title="수입식품관 / 나라별음식">식품</a>
# <img alt="수입식품관 / 나라별음식" class="category-banner-image" data-banner-src="//image12.coupangcdn.com/image/displayitem/displayitem_5bde3a69-d8aa-4ede-bd98-63cbbdcde591.jpg"/>
# </span>
# </div></div></li> <li class="kitchen"><a class="first-depth" data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"kitchen"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"kitchen"} }' href="/np/categories/185669">주방용품<i class="select-icon"></i></a><div class="depth"><div class="depth-list banner third"><ul> <li class="second-depth-list"><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"kitchen"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"kitchen"} }' href="/np/categories/186504">주방가전 <i class="depth-select-icon"></i></a><div class="third-depth-list"><ul> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"kitchen"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"kitchen"} }' href="/np/categories/186506">전기밥솥</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"kitchen"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"kitchen"} }' href="/np/categories/186520">전자레인지/오븐</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"kitchen"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"kitchen"} }' href="/np/categories/384889">가스레인지</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"kitchen"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"kitchen"} }' href="/np/categories/384890">전기레인지</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"kitchen"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"kitchen"} }' href="/np/categories/186585">식기세척/건조기</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"kitchen"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"kitchen"} }' href="/np/categories/186543">믹서기/블렌더</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"kitchen"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"kitchen"} }' href="/np/categories/186533">커피메이커/머신</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"kitchen"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"kitchen"} }' href="/np/categories/427583">빙수기/제빙기</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"kitchen"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"kitchen"} }' href="/np/categories/384907">전기포트</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"kitchen"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"kitchen"} }' href="/np/categories/384921">에어프라이어/튀김기</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"kitchen"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"kitchen"} }' href="/np/categories/384913">토스터/간식메이커</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"kitchen"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"kitchen"} }' href="/np/categories/186570">전기그릴/전기쿠커</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"kitchen"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"kitchen"} }' href="/np/categories/186526">정수기/냉온수기</a></li> <li class="more-category"><a href="/np/categories/186504">더보기</a></li> </ul></div></li> <li class="second-depth-list"><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"kitchen"}' data-log-props='{ "id":"category_menu", "param" ...
# <span class="gnb-banner" style="background: #FFF">
# <a class="category-banner-button" data-coulog='{"grp":"categoryMenu_rightBanner","logType":"click","logCategory":"event","logLabel":"kitchen"}' data-log-props='{ "id":"category_menu_banner", "param":{"categoryLabel":"kitchen"} }' href="/np/search?q=%EB%B9%99%EC%88%98%EA%B8%B0&amp;component=186404" title="주방용품">주방용품</a>
# <img alt="주방용품" class="category-banner-image" data-banner-src="//image14.coupangcdn.com/image/displayitem/displayitem_3a1d374a-c68d-402a-a8d0-a0a3314c54d2.jpg"/>
# </span>
# </div></div></li> <li class="life"><a class="first-depth" data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"living"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"living"} }' href="/np/categories/115673">생활용품<i class="select-icon"></i></a><div class="depth"><div class="depth-list banner third"><ul> <li class="second-depth-list"><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"living"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"living"} }' href="/np/categories/228303">유기농/친환경 전문관 <i class="depth-select-icon"></i></a><div class="third-depth-list"><ul> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"living"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"living"} }' href="/np/categories/228304">세제</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"living"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"living"} }' href="/np/categories/228332">생리대</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"living"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"living"} }' href="/np/categories/276476">샤워타올/수건</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"living"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"living"} }' href="/np/categories/228396">구강/면도</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"living"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"living"} }' href="/np/categories/228406">청소용품</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"living"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"living"} }' href="/np/categories/228416">방향/탈취/제습</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"living"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"living"} }' href="/np/categories/228421">살균/방충제</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"living"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"living"} }' href="/np/categories/228428">페인트</a></li> </ul></div></li> <li class="second-depth-list"><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"living"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"living"} }' href="/np/categories/399742">세탁세제 <i class="depth-select-icon"></i></a><div class="third-depth-list"><ul> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"living"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"living"} }' href="/np/categories/399743">일반/겸용세제</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"living"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"living"} }' href="/np/categories/399744">드럼전용세제</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"living"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"living"} }' href="/np/categories/399745">캡슐/시트세제</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"living"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"living"} }' href="/np/categories/399746">섬유유연제</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"living"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"living"} }' href="/np/categories/399747"> ...
# <span class="gnb-banner" style="background: #ffffff">
# <a class="category-banner-button" data-coulog='{"grp":"categoryMenu_rightBanner","logType":"click","logCategory":"event","logLabel":"living"}' data-log-props='{ "id":"category_menu_banner", "param":{"categoryLabel":"living"} }' href="/np/search?q=%EB%8D%B0%EC%98%A4%EB%93%9C%EB%9E%80%ED%8A%B8&amp;component=123011" title="0701">생활용품</a>
# <img alt="0701" class="category-banner-image" data-banner-src="//image11.coupangcdn.com/image/displayitem/displayitem_61da0554-17d8-4ab3-8be8-c56fbc24c3b0.jpg"/>
# </span>
# </div></div></li> <li class="home_decoration"><a class="first-depth" data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"home_decoration"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"home_decoration"} }' href="/np/categories/184555">홈인테리어<i class="select-icon"></i></a><div class="depth"><div class="depth-list banner third"><ul> <li class="second-depth-list"><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"home_decoration"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"home_decoration"} }' href="/np/categories/388647">여름 침구샵 <i class="depth-select-icon"></i></a><div class="third-depth-list"><ul> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"home_decoration"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"home_decoration"} }' href="/np/categories/388648">이불</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"home_decoration"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"home_decoration"} }' href="/np/categories/388653">쿨매트/패드</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"home_decoration"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"home_decoration"} }' href="/np/categories/388657">침구커버류</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"home_decoration"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"home_decoration"} }' href="/np/categories/388661">침구세트</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"home_decoration"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"home_decoration"} }' href="/np/categories/388664">베개</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"home_decoration"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"home_decoration"} }' href="/np/categories/388670">유아동침구</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"home_decoration"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"home_decoration"} }' href="/np/categories/388682">방석/쿠션</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"home_decoration"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"home_decoration"} }' href="/np/categories/388688">모기장/안전망</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"home_decoration"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"home_decoration"} }' href="/np/categories/388698">대자리/러그/거실화</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"home_decoration"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"home_decoration"} }' href="/np/categories/388702">문발</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"home_decoration"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"home_decoration"} }' href="/np/categories/388707">커튼</a></li> <li><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"home_decoration"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"home_decoration"} }' href="/np/categories/388712">블라인드/쉐이드</a></li> </ul></div></li> <li class="second-depth-list"><a data-coulog='{"grp":"categoryLeftMenu","logType":"click","logCategory":"event","logLabel":"home_decoration"}' data-log-props='{ "id":"category_menu", "param":{"categoryLabel":"home_decoration"} }' href="/np/categories/413976">싱글하우스 <i class="dept ...
# <span class="gnb-banner" style="background: #ffffff">
# <a class="category-banner-button" data-coulog='{"grp":"categoryMenu_rightBanner","logType":"click","logCategory":"event","logLabel":"home_decoration"}' data-log-props='{ "id":"category_menu_banner", "param":{"categoryLabel":"home_decoration"} }' href="/np/categories/388647" title="홈인테리어">홈인테리어</a>
# <img alt="홈인테리어" class="category-banner-image" data-banner-src="//image12.coupangcdn.com/image/displayitem/displayitem_b9b5861a-7f15-4581-91a0-3fb8548213e3.jpg"/>
# </span>
# ...
#                  "eventAction" : "click"
#                }' href="//www.coupang.com/vp/products/112293047?vendorItemId=3704127327&amp;eventLabel=recommendation_widget_pc_srp_001&amp;platform=web&amp;rmdABTestInfo=5140:A&amp;rmdValue=p52672142:vt-1.0.0:p112293047" title="푸르젠 참숯돌에서 구운계란 (개당 45~50g 국산 구운소금증정), 30개, (개당 45~50g)">
# <img alt="푸르젠 참숯돌에서 구운계란 (개당 45~50g 국산 구운소금증정), 30개, (개당 45~50g)" class="recommend-widget__item__image" onerror="this.src='//t1a.coupangcdn.com/thumbnails/remote/300x300/image/coupang/common/no_img_1000_1000.png'" src="//thumbnail14.coupangcdn.com/thumbnails/remote/292x292ex/image/vendor_inventory/images/2018/07/23/17/7/d1c723c5-7923-4045-aba4-3497e24add6c.jpg"/>
# <strong class="recommend-widget__item__title">푸르젠 참숯돌에서 구운계란 (개당 45~50g 국산 구운소금증정), 30개, (개당 45~50g)</strong>
# <div class="recommend-widget__item__price-wrap">
# <span class="recommend-widget__item__price"><em>7,900</em>원</span>
# </div>
# <div class="recommend-widget__item__review">
# <span class="recommend-widget__srp-asset-split-bg recommend-widget__item__review-score-bg">
# <span class="recommend-widget__srp-asset-split-bg recommend-widget__item__review-score" style="width:90%;">
# <em>90%</em>
# </span>
# </span>
# <span class="recommend-widget__item__review-count">(137)</span>
# </div>
# </a>
# </li>
# <li class="recommend-widget__item">
# <a data-wiselog='{
#                  "trackingTag" : "eventLabel=recommendation_widget_pc_srp_001&amp;platform=web&amp;rmdABTestInfo=5140:A&amp;rmdValue=p52672142:vt-1.0.0:p83707462",
#                  "eventAction" : "click"
#                }' href="//www.coupang.com/vp/products/83707462?vendorItemId=3643767955&amp;eventLabel=recommendation_widget_pc_srp_001&amp;platform=web&amp;rmdABTestInfo=5140:A&amp;rmdValue=p52672142:vt-1.0.0:p83707462" title="머거본 꾸이랑 나쵸, 290g, 1개">
# <img alt="머거본 꾸이랑 나쵸, 290g, 1개" class="recommend-widget__item__image" onerror="this.src='//t1a.coupangcdn.com/thumbnails/remote/300x300/image/coupang/common/no_img_1000_1000.png'" src="//thumbnail11.coupangcdn.com/thumbnails/remote/292x292ex/image/product/image/vendoritem/2018/10/05/3643767955/5656f53b-92fb-4e34-a321-9fce69cab29c.jpg"/>
# <strong class="recommend-widget__item__title">머거본 꾸이랑 나쵸, 290g, 1개</strong>
# <div class="recommend-widget__item__price-wrap">
# <span class="recommend-widget__item__price"><em>6,090</em>원</span>
# <span class="recommend-widget__item__unit-price">(10g당 210원)</span>
# </div>
# <div class="recommend-widget__item__badge-wrap">
# <img alt="" class="recommend-widget__item__badge-wrap__badge type-ROCKET" src="//image15.coupangcdn.com/image/badges/rocket/rocket_logo.png"/>
# </div>
# <div class="recommend-widget__item__review">
# <span class="recommend-widget__srp-asset-split-bg recommend-widget__item__review-score-bg">
# <span class="recommend-widget__srp-asset-split-bg recommend-widget__item__review-score" style="width:90%;">
# <em>90%</em>
# </span>
# </span>
# <span class="recommend-widget__item__review-count">(2,650)</span>
# </div>
# </a>
# </li>
# <li class="recommend-widget__item">
# <a data-wiselog='{
#                  "trackingTag" : "eventLabel=recommendation_widget_pc_srp_001&amp;platform=web&amp;rmdABTestInfo=5140:A&amp;rmdValue=p157491778:vt-1.0.0:p167732590",
#                  "eventAction" : "click"
#                }' href="//www.coupang.com/vp/products/167732590?vendorItemId=4040086162&amp;eventLabel=recommendation_widget_pc_srp_001&amp;platform=web&amp;rmdABTestInfo=5140:A&amp;rmdValue=p157491778:vt-1.0.0:p167732590" title="[명품구운란] 구운계란 맥반석계란 구운란 대란 30구">
# <img alt="[명품구운란] 구운계란 맥반석계란 구운란 대란 30구" class="recommend-widget__item__image" onerror="this.src='//t1a.coupangcdn.com/thumbnails/remote/300x300/image/coupang/common/no_img_1000_1000.png'" src="//thumbnail12.coupangcdn.com/thumbnails/remote/292x292ex/image/vendor_inventory/images/2018/11/23/17/4/21100510-d12b-4670-b08a-6da54ab40d3c.jpg"/>
# <strong class="recommend-widget__item__title">[명품구운란] 구운계란 맥반석계란 구운란 대란 30구</strong>
# <div class="recommend-widget__item__price-wrap">
# <span class="recommend-widget__item__price"><em>6,500</em>원</span>
# <span class="recommend-widget__item__unit-price">(1개당 217원)</span>
# </div>
# <div class="recommend-widget__item__review">
# <span class="recommend-widget__srp-asset-split-bg recommend-widget__item__review-score-bg">
# <span class="recommend-widget__srp-asset-split-bg recommend-widget__item__review-score" style="width:90%;">
# <em>90%</em>
# </span>
# </span>
# <span class="recommend-widget__item__review-count">(249)</span>
# </div>
# </a>
# </li>
# <li class="recommend-widget__item">
# <a data-wiselog='{
#                  "trackingTag" : "eventLabel=recommendation_widget_pc_srp_001&amp;platform=web&amp;rmdABTestInfo=5140:A&amp;rmdValue=p52672142:vt-1.0.0:p36762090",
#                  "eventAction" : "click"
#                }' href="//www.coupang.com/vp/products/36762090?vendorItemId=3288985724&amp;eventLabel=recommendation_widget_pc_srp_001&amp;platform=web&amp;rmdABTestInfo=5140:A&amp;rmdValue=p52672142:vt-1.0.0:p36762090" title="구운란 흑란세트(30ea 구운계란15ea+참숯흑란15ea), 1개, 30구">
# <img alt="구운란 흑란세트(30ea 구운계란15ea+참숯흑란15ea), 1개, 30구" class="recommend-widget__item__image" onerror="this.src='//t1a.coupangcdn.com/thumbnails/remote/300x300/image/coupang/common/no_img_1000_1000.png'" src="//thumbnail15.coupangcdn.com/thumbnails/remote/292x292ex/image/vendor_inventory/images/2017/09/14/11/4/cd14bcb6-4d05-46e3-a77a-4f5914bbef8e.jpg"/>
# <strong class="recommend-widget__item__title">구운란 흑란세트(30ea 구운계란15ea+참숯흑란15ea), 1개, 30구</strong>
# <div class="recommend-widget__item__price-wrap">
# <span class="recommend-widget__item__price"><em>14,800</em>원</span>
# <span class="recommend-widget__item__unit-price">(1개당 493원)</span>
# </div>
# <div class="recommend-widget__item__review">
# <span class="recommend-widget__srp-asset-split-bg recommend-widget__item__review-score-bg">
# <span class="recommend-widget__srp-asset-split-bg recommend-widget__item__review-score" style="width:70%;">
# <em>70%</em>
# </span>
# </span>
# <span class="recommend-widget__item__review-count">(9)</span>
# </div>
# </a>
# </li>
# </ul>
# </div>
# <a class="recommend-widget__srp-asset-split-bg recommend-widget__arrow-button prev dimmed" href="javascript:;" style="display: none;" title="이전 상품 보기">이전 상품 보기</a>
# <a class="recommend-widget__srp-asset-split-bg recommend-widget__arrow-button next" href="javascript:;" title="다음 상품 보기">다음 상품 보기</a>
# </div>
# </div>
# </div></div>
# <!-- coupang footer -->
# <footer class="footer_new" id="footer">
# <div class="footer-layer1">
# <a href="https://www.coupang.com/np/jobs" target="_blank">인재채용</a>
# <a href="https://wing.coupang.com/vendor/joining/welcome?inflow=WEB_FOOTER_B">입점 / 제휴문의</a>
# <a href="https://csmessenger.coupang.com/cs-center/notice/main">공지사항</a>
# <a href="https://csmessenger.coupang.com/cs-center/voc/main">고객의 소리</a>
# <a href="/np/policies/terms">이용약관</a>
# <a href="/np/policies/privacy"><b>개인정보 처리방침</b></a>
# <a href="/np/safety">신뢰관리센터</a>
# <a href="https://partners.coupang.com/" target="_blank">제휴마케팅</a>
# <a href="/np/policies/commercial">광고정책</a>
# </div>
# <div class="footer-layer2">
# <h1><a href="/" title="COUPANG">COUPANG</a></h1>
# <div class="footer-content">
# <address>
#                     쿠팡(주) | 대표이사 : 김범석,고명주,정보람<br/>
#                     서울시 송파구 송파대로 570 <br/>
#                     사업자 등록번호 : 120-88-00767 <br/>
#                     통신판매업신고 : 2017-서울송파-0680<br/>
# <a class="licensee" href="http://www.ftc.go.kr/info/bizinfo/communicationViewPopup.jsp?wrkr_no=1208800767" target="_blank" title="사업자정보 확인">사업자정보 확인 &gt;</a>
# </address>
# <div class="contact-info">
# <a class="call-center" href="http://cs.coupang.com/customerCenter/home" title="365 고객센터">
# <strong>365고객센터</strong> | 전자금융거래분쟁처리담당<br/>
# <em>1577-7011</em>
#                         서울특별시 금천구 두산로 70 B, 24층<br/>
# <span class="contact-fax">Fax : 02-3441-7011 | email : help@coupang.com</span>
# </a>
# </div>
# <p class="safe-service">
# <strong>우리은행 채무지급보증 안내</strong><br/>
# <span>
#                 당사는 고객님이 현금 결제한 금액에 대해<br/>우리은행과 채무지급보증 계약을 체결하여<br/>안전거래를 보장하고 있습니다.<br/>
# </span>
# <a class="service-check" href="javascript:;" id="serviceCheck" title="서비스 가입사실 확인">서비스 가입사실 확인 &gt;</a>
# </p>
# </div>
# </div>
# <div class="footer-layer3 slide-unit">
# <div class="slide-area">
# <ul class="award-list">
# <li><a class="award-link3" href="https://csmessenger.coupang.com/cs-center/notice/main?id=2345" title="정보보호 관리체계 ISMS 인증획득">정보보호 관리체계 ISMS 인증획득</a></li>
# <li><a class="award-link4" href="https://csmessenger.coupang.com/cs-center/notice/main?id=2344" title="개인정보보호 관리체계 PIMS 인증획득">개인정보보호 관리체계 PIMS 인증획득</a></li>
# <li><a class="award-link5" href="https://csmessenger.coupang.com/cs-center/notice/main?id=2473" title="정보보안 국제표준 ISO27001 인증획득">정보보안 국제표준 ISO27001 인증획득</a></li>
# <li><a class="award-link13" href="https://www.eprivacy.or.kr:40018/seal/mark.jsp?mark=e&amp;code=2019-R034" target="_blank" title="개인정보우수사이트 ePRIVACY인증획득">개인정보우수사이트 ePRIVACY인증획득</a></li>
# </ul>
# </div>
# </div>
# <div class="footer-layer4">
# <div class="coupang-copyright">
# <p class="info">개별 판매자가 등록한 마켓플레이스(오픈마켓) 상품에 대한 광고, 상품주문, 배송 및 환불의 의무와 책임은 각 판매자가 부담하고,<br/> 이에 대하여 쿠팡은 통신판매중개자로서 통신판매의 당사자가 아니므로 일체 책임을 지지 않습니다. <br/> 쿠팡은 소비자 보호와 안전거래를 위해 신뢰관리센터(CM112@coupang.com)를 운영하고 있습니다.</p>
# <ul class="sns-link">
# <li><a class="facebook" href="https://www.facebook.com/Coupang.korea" target="_blank" title="쿠팡 페이스북">쿠팡 페이스북</a></li>
# <li><a class="blog" href="http://blog.coupang.com" target="_blank" title="쿠팡 블로그">쿠팡 블로그</a></li>
# <li><a class="instagram" href="https://www.instagram.com/coupang" target="_blank" title="쿠팡 인스타그램">쿠팡 인스타그램</a></li>
# </ul>
# </div>
# </div>
# </footer>
# </div>
# <script src="/resources/20190709144817/np/js/lib/jslog/jslog.js" type="text/javascript"></script>
# <script type="text/javascript">
# 			new JsLog('coupang_web', '','','https://jslog.coupang.com').enableTrap();
# 		</script>
# <script>
#
#     window.logRequireTime = function(){};
#
#     try {
#         if (window.performance && window.performance.now) {
#             window.redwoodTimeLog = {
#                 requirejs: {
#                     start: window.performance.now()
#                 }
#             };
#             window.logRequireTime = function () {
#                 window.redwoodTimeLog.requirejs.end = window.performance.now();
#                 window.redwoodTimeLog.requirejs.time = window.redwoodTimeLog.requirejs.end - window.redwoodTimeLog.requirejs.start;
#             }
#         }
#     } catch(e) {}
#
#
#
# </script>
# <script onload="logRequireTime()" src="/resources/20190709144817/np/js/lib/requirejs/require-2.1.14.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#
#
#       define('page/search/include/searchAlsoViewedProducts.hbs', ['handlebars'], function(Handlebars) {
#   var template = Handlebars.template(function (Handlebars,depth0,helpers,partials,data) {
#   this.compilerInfo = [4,'>= 1.0.0'];
# helpers = this.merge(helpers, Handlebars.helpers); data = data || {};
#   var buffer = "", stack1, helper, functionType="function", escapeExpression=this.escapeExpression;
#
#
#   buffer += "<div data-fodium-widget=\"desktop/widgets/srp/AlsoViewedProducts\" data-fodium-widget-params='{\n         \"productIds\": ";
#   if (helper = helpers.productIndexes) { stack1 = helper.call(depth0, {hash:{},data:data}); }
#   else { helper = (depth0 && depth0.productIndexes); stack1 = typeof helper === functionType ? helper.call(depth0, {hash:{},data:data}) : helper; }
#   buffer += escapeExpression(stack1)
#     + ",\n         \"widgetId\": \"WIDGET_PC_SRP_001\",\n         \"minCount\": 5,\n         \"maxCount\": 15\n     }'></div>";
#   return buffer;
#   });
#   var templates = Handlebars.templates = Handlebars.templates || {};
#   templates['page/search/include/searchAlsoViewedProducts.hbs'] = template;
#   var partials = Handlebars.partials = Handlebars.partials || {};
#   partials['page/search/include/searchAlsoViewedProducts.hbs'] = template;
#   return template;
# });
#
#
#
#
#
#     var coupangWebRequire = require.config({
#         baseUrl: '/resources/20190709144817/np/js/modules',
#         context : 'coupangWeb',
#         paths: {
#             jquery: '//asset3.coupangcdn.com/cdnjs/jquery/1.11.1/jquery.min',
#             hashchange: '../lib/jquery/jquery.ba-hashchange-1.3-browser-patch',
#             handlebars: '//asset3.coupangcdn.com/cdnjs/handlebars.js/1.3.0/handlebars.min',
#             text: '//asset3.coupangcdn.com/cdnjs/require-text/2.0.12/text.min',
#             moment: '//asset3.coupangcdn.com/cdnjs/moment.js/2.10.2/moment.min',
#             momentLocale: '//asset3.coupangcdn.com/cdnjs/moment.js/2.10.2/locales.min',
#             lodash: '//asset3.coupangcdn.com/cdnjs/lodash.js/3.10.1/lodash.min',
#             template: '/resources/20190709144817/np/html/template',
# 			facebook: '//connect.facebook.net/ko_KR/sdk',
#             triforce: '//asset3.coupangcdn.com/customjs/triforce/0.0.23/triforce.min',
#             couLog: '//asset3.coupangcdn.com/customjs/cou-log/1.0.17/cou-log.min',
#             speedChecker: '//asset3.coupangcdn.com/customjs/speed-checker/0.7.2/speed-checker.min',
#             ezPlus: '//asset3.coupangcdn.com/customjs/jquery-elevatezoom-plus/1.1.11/jquery.ez-plus.min',
#             fodiumWidgetLoader: '//asset3.coupangcdn.com/customjs/fodium-widget-loader/1.0.1/fodiumWidgetLoader.min',
#             videojs: '//asset3.coupangcdn.com/cdnjs/video.js/5.16.0/video.min',
#             videohls: '//asset3.coupangcdn.com/cdnjs/videojs-contrib-hls/5.1.1/videojs-contrib-hls',
#             weblog: '//asset3.coupangcdn.com/customjs/coupang-web-log/1.0.0/web-log.umd.min',
#             incorrectInfoBundle: 'sdp/incorrectInfoReport/webpack/incorrectInfoBundle'
#         },
#         shim: {
#             handlebars: {
#                 exports: 'Handlebars'
#             },
#             hashchange: {
#             	deps: ['jquery'],
#             	exports: 'Hashchange'
#         	},
# 			facebook : {
# 				exports: 'FB'
# 			},
# 			couLog: {
# 				deps: ['jquery'],
# 				exports: 'couLog'
# 			},
#             speedChecker: {
#                 deps: ['jquery','couLog'],
#                 exports: 'speedChecker'
#             }
#         }
#     });
#
#
#     coupangWebRequire([
#     '../modules/search/search',
#     '../modules/search/utils/searchLogHelper-min',
#     '../modules/search/utils/searchWebLogHelper-min',
#     '../modules/common/template/search/SearchFocus',
#     '../modules/search/merchandisingWidget'
# ], function(search, logHelper, webLogHelper, searchFocus, merchandisingWidget) {
#     logHelper.initialize();
#     webLogHelper.initialize();
#
#     new searchFocus('#headerSearchKeyword');
#     merchandisingWidget.initialize();
#
#     coupangWebRequire(['searchFilter', 'searchContents', 'searchCustomizedCheckbox'], function (searchFilter, searchContents, searchCustomizedCheckbox) {
#         searchFilter.initialize();
#         searchContents.initialize();
#         searchCustomizedCheckbox.initialize($("#searchOptionForm"));
#     });
# });
#
# coupangWebRequire([
#     'handlebars',
#     'hashchange',
#     '../lib/jquery/plugin/stringify',
#     '../page-controllers/common/controller',
#     'couLog',
#     'triforce'
# ]);
#
#
#
#
#
#
#
# </script>
# <!-- Facebook Pixel Code -->
# <script>
#     !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#         n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#         t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#             document,'script','https://connect.facebook.net/en_US/fbevents.js');
#     fbq('init', '652323801535981');
#     fbq('track', 'PageView');
#
# </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=652323801535981&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <script async="true" src="//static.criteo.net/js/ld/ld.js" type="text/javascript"></script>
# <div class="ad-badge-tooltip" style="letter-spacing: -1.5px;">
# <span>쿠팡으로부터 광고 서비스를</span>
# <span>구매한 제휴업체의 판매상품으로,</span>
# <span>일반 상품보다 우선 정렬됩니다.</span>
# </div>
# <div id="criteo-tags-div" style="display: none;"></div></body></html>

# %%
driver.find_element_by_xpath('//*[@id="sticky-wrapper"]/section/div[1]/h1/a/img').click()

# %%
//*[@id="gnbAnalytics"]/ul[1]/li[4]/div/div/ul/li[6]/div/ul/li[6]/a

# %%
driver.current_url
# Out:
# 'https://www.coupang.com/np/search?component=&q=%EA%B3%84%EB%9E%80&channel=user'

# %%
eggUrl = driver.page_source

# %%
eggUrl
# Out:
# '<html lang="ko-KR"><!--<![endif]--><head>\n    <meta charset="utf-8">\n    <meta name="google-site-verification" content="zaNrGtrOLMjglkziY2IvmL8dOXyCWHGArDHqFazJQVI">\n    <meta http-equiv="x-dns-prefetch-control" content="on">\n    <link rel="dns-prefetch" href="//cart.coupang.com">\n    <link rel="dns-prefetch" href="//assets.coupang.com">\n    <link rel="dns-prefetch" href="//assets2.coupang.com">\n    <link rel="dns-prefetch" href="//assets.coupangcdn.com">\n    <link rel="dns-prefetch" href="//asset1.coupangcdn.com">\n    <link rel="dns-prefetch" href="//private.coupang.com">\n    <link rel="dns-prefetch" href="//triforce.coupang.com">\n    <link rel="dns-prefetch" href="//img1a.coupangcdn.com">\n    <link rel="dns-prefetch" href="//image1.coupangcdn.com">\n    <link rel="dns-prefetch" href="//thumbnail1.coupangcdn.com">\n    <link rel="dns-prefetch" href="//www.facebook.com">\n    <link rel="dns-prefetch" href="//www.google.com">\n    <link rel="dns-prefetch" href="//www.google.co.kr">\n    <link rel="dns-prefetch" href="//stats.g.doubleclick.net">\n    <link rel="dns-prefetch" href="//connect.facebook.net">\n\n    <title>쿠팡! - 계란</title>\n    \n    \n\n    \n    \n        \n        \n        \n            <meta property="og:title" content="COUPANG">\n            <meta property="og:image" content="//image15.coupangcdn.com/image/mobile/v3/img_fb_like.png">\n            <meta property="og:url" content="https://www.coupang.com">\n        \n        \n        \n            <meta property="og:description" content="쿠팡은 로켓배송 - 계란에 대한 검색결과입니다. 우유, 두부, 계란 30구, 식빵, 라면, 샐러드, 바나나, 양파, 구운계란, ">\n            <meta name="description" content="쿠팡은 로켓배송 - 계란에 대한 검색결과입니다. 우유, 두부, 계란 30구, 식빵, 라면, 샐러드, 바나나, 양파, 구운계란, ">\n            <meta name="keywords" content="여성패션, 남성패션, 베이비패션 (0~3세), 여아패션 (3세 이상), 남아패션 (3세 이상), 스포츠패션, 신발, 가방/잡화, 명품패션, 뷰티, 출산/유아동, 식품, 주방용품, 생활용품, 홈인테리어, 가전디지털, 스포츠/레저, 자동차용품, 도서/음반/DVD, 완구/취미, 문구/오피스, 반려동물용품, 헬스/건강식품, ">\n        \n\n        \n    \n\n<meta property="og:type" content="website">\n\n\n    <link rel="shortcut icon" href="//image14.coupangcdn.com/image/coupang/favicon/v2/favicon.ico" type="image/x-icon">\n    \n    \n        <!--[if lt IE 9]>\n<script src="/resources/20190709144817/np/js/lib/html5/html5.js" type="text/javascript"></script>\n<![endif]-->\n<!--[if lte IE 9]>\n<script src="//asset3.coupangcdn.com/cdnjs/json2/20150503/json2.js" type="text/javascript"></script>\n<![endif]-->\n\n    \n        <link rel="stylesheet" href="/resources/20190709144817/np/css/common.min.css" type="text/css">\n        <link rel="stylesheet" href="/resources/20190709144817/np/css/side.css" type="text/css">\n        \n    \n\n\n    \n    \n    \n    <link rel="stylesheet" href="/resources/20190709144817/np/css/search.min.css" type="text/css">\n\n\n     <style>#coupang-banner span.banner-bg{background:#e2faff;border-bottom:1px solid #cac6c3}\n        #coupang-banner span.banner-bg{float:left;width:100%;}\n        #coupang-banner .banner-middle{width:980px;margin:0 auto;}\n        #coupang-banner .banner-middle a{float:left;display: inline-block}</style>\n\n<script type="text/javascript" charset="utf-8" async="" data-requirecontext="coupangWeb" data-requiremodule="../modules/search/search" src="/resources/20190709144817/np/js/modules/../modules/search/search.js"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="coupangWeb" data-requiremodule="../modules/search/utils/searchLogHelper-min" src="/resources/20190709144817/np/js/modules/../modules/search/utils/searchLogHelper-min.js"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="coupangWeb" data-requiremodule="../modules/search/utils/searchWebLogHelper-min" src="/resources/20190709144817/np/js/modules/../modules/search/utils/searchWebLogHelper-min.js"></script><script type="text/javascript" charset="utf-8" async="" data-requirecontext="coupangWeb" data-requiremodule="../modules/common/template/search/Sear ...

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import os
from os.path import join, dirname

if os.name == 'nt':
    os_name = 'nt'
elif os.name == 'mac':
    os_name = 'mac'
else:
    os_name = 'linux'

if os_name == 'nt':
    dirver_loc = "d:/chromedriver/chromedriver.exe"
else:
    dirver_loc = "/home/download/chromedriver/chromedriver.exe"

# %%
# 크롬 옵션 설정
options = webdriver.ChromeOptions()
# 헤드리스 설정 시 리눅스 같이 웹화면 없는경우에도 웹페이지 실행가능함
#options.add_argument('headless')
options.add_argument('window-size=1920x1080')
#options.add_argument("disable-gpu")
#웹 드라이버 정의
driver = webdriver.Chrome(dirver_loc, options=options)

# %%
searchBoxurl = "https://www.coupang.com"

driver.get(url).

# %%
searchButton =driver.find_element_by_xpath('//*[@id="header"]/section/div/div/div[2]').click().implicitlyWait(10, TimeUnit.SECONDS);
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-47-5f35d364dafa> in <module>
# ----> 1 searchButton =driver.find_element_by_xpath('//*[@id="header"]/section/div/div/div[2]').click().implicitlyWait(10, TimeUnit.SECONDS);
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=75.0.3770.100)

# %%
searchButton.click()
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-45-6a9cf9ab0419> in <module>
# ----> 1 searchButton.click()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=75.0.3770.100)

# %%
#headerSearchBtn

# %%
categorybtn = driver.find_element_by_xpath('//*[@id="gnbAnalytics"]/ul[1]/li[4]/div/div/ul/li[6]/div/ul/li[6]/a')

# %%
categorybtn.click
# Out:
# <bound method WebElement.click of <selenium.webdriver.remote.webelement.WebElement (session="ff32b89f8dbaa18f33df71e4ca510768", element="bfdce68e-d274-446e-9b8c-af7a33815d64")>>

# %%
data

# %%
data = requests.get(url)
data
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     284             else:
# --> 285                 raise SocketError(str(e))
#     286         except OpenSSL.SSL.ZeroReturnError as e:
#
# OSError: (10060, 'WSAETIMEDOUT')
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     356             if read is False or not self._is_method_retryable(method):
# --> 357                 raise six.reraise(type(error), error, _stacktrace)
#     358             elif read is not None:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     284             else:
# --> 285                 raise SocketError(str(e))
#     286         except OpenSSL.SSL.ZeroReturnError as e:
#
# ProtocolError: ('Connection aborted.', OSError("(10060, 'WSAETIMEDOUT')"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-14-f5d472bd1c0c> in <module>
# ----> 1 data = requests.get(url)
#       2 data
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     488
#     489         except (ProtocolError, socket.error) as err:
# --> 490             raise ConnectionError(err, request=request)
#     491
#     492         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', OSError("(10060, 'WSAETIMEDOUT')"))

# %%
getPageString(url)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     284             else:
# --> 285                 raise SocketError(str(e))
#     286         except OpenSSL.SSL.ZeroReturnError as e:
#
# OSError: (10060, 'WSAETIMEDOUT')
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     356             if read is False or not self._is_method_retryable(method):
# --> 357                 raise six.reraise(type(error), error, _stacktrace)
#     358             elif read is not None:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     284             else:
# --> 285                 raise SocketError(str(e))
#     286         except OpenSSL.SSL.ZeroReturnError as e:
#
# ProtocolError: ('Connection aborted.', OSError("(10060, 'WSAETIMEDOUT')"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-13-ee3ea1838bf1> in <module>
# ----> 1 getPageString(url)
#
# <ipython-input-11-7c097acde3ad> in getPageString(url)
#       1 def getPageString(url):
# ----> 2     data = requests.get(url)
#       3     bsHtml = BeautifulSoup(data.content, "html.parser")
#       4
#       5     print(bsObj)
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     488
#     489         except (ProtocolError, socket.error) as err:
# --> 490             raise ConnectionError(err, request=request)
#     491
#     492         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', OSError("(10060, 'WSAETIMEDOUT')"))

# %%
finalResult
# Out:
#                                              0        1  \
# 0                           [스프링부트] Session 처리    황원용교수
# 1           자바 개발환경설정 (Java_home) 설정 및 시험문제 힌트    김효관교수
# 2                                성한빈 면접후기 입니다.  2018성한빈
# 3                               05.15 웹UI 강의자료      조준형
# 4  웹서버 실행 중 200, 403 호출이 동시에 응답할때(파비콘 요청)_업데이트  2018정효재
#
#                                         2            3
# 0  https://cafe.naver.com/joonggonara/413  2019.06.28.
# 1  https://cafe.naver.com/joonggonara/332  2019.04.16.
# 2  https://cafe.naver.com/joonggonara/222  2018.09.17.
# 3  https://cafe.naver.com/joonggonara/146  2018.05.15.
# 4  https://cafe.naver.com/joonggonara/141  2018.05.09.
