# %% [markdown]
# ### 리스트로 데이터프레임 만들기

# %%
import pandas as pd

# %%
## make dataframe from dictionary
from itertools import repeat
a = ["A01","A02","A03","A04","A05"]
b = list(range(201501,201506,1))
c = list(repeat(100,5))
df1 = pd.DataFrame(zip(a,b,c))

# %%
oneRow = ["A05","201506","100"]

# %%
appendPd = pd.DataFrame([oneRow])

# %%
df1.append(appendPd)
# Out:
#      0       1    2
# 0  A01  201501  100
# 1  A02  201502  100
# 2  A03  201503  100
# 3  A04  201504  100
# 4  A05  201505  100
# 0  A05  201506  100

# %% [markdown]
# ### 딕셔너리로 데이터프레임 만들기

# %%
from collections import OrderedDict

# %%
## make dataframe from dictionary
from itertools import repeat
a = ["A01","A02","A03","A04","A05"]
b = list(range(201501,201506,1))
c = list(repeat(100,5))
my_dict = {"b":a, "c":b, "a":c}
orderedDict = OrderedDict(my_dict)
testdf = pd.DataFrame(orderedDict)
testdf
# Out:
#      b       c    a
# 0  A01  201501  100
# 1  A02  201502  100
# 2  A03  201503  100
# 3  A04  201504  100
# 4  A05  201505  100

# %% [markdown]
# # 데이터 준비 (customerdata.csv)

# %%
import pandas as pd

# %%
customerData = pd.read_csv("../dataset/customerdata.csv")
customerData.head(1)
# Out:
#    CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566        4273.9    3          6.4    1.679181  Big-Screen-lover

# %% [markdown]
# # A. 데이터 조작하기

# %% [markdown]
# ### 1. 원하는 행 조회하기

# %%
customerData.dtypes
# Out:
# CUSTID           object
# AVERAGEPRICE    float64
# EMI               int64
# DEVICECOUNT     float64
# PRODUCTAGE      float64
# CUSTTYPE         object
# dtype: object

# %%
import pandas as pd
from sqlalchemy import create_engine 
 
# CSV 파일을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_csv("../dataset/customerdata.csv")

# 컬럼해더 재정의
customerData.columns = ['CUSTID','AVGPRICE','EMI','DEVICECOUNT','PRODUCTAGE','CUSTTYPE']
#customerData.columns = [x.upper() for x in customerData.columns]
# 데이터 VIEW
customerData.head()

## 조건 설정
emiCondition=3
deviceCondition=5
inplaceVariable = customerData[ (customerData.EMI.astype(str) == "3") & (customerData.DEVICECOUNT>5) ]
#customerData.query('EMI == @emiCondition & DEVICECOUNT > @deviceCondition')
inplaceVariable.head()
# Out:
#     CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0   A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 27  F17131  3179.708359    3          6.5    1.100000        Early-bird
# 33  G16437  3787.328898    3          6.7    1.000000        Early-bird
# 36  G18402  3402.199381    3          6.5    1.000000        Early-bird
# 40  H16326  3988.935304    3          6.5    0.900000        Early-bird

# %%
import pandas as pd
from sqlalchemy import create_engine 
 
# CSV 파일을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_csv("../dataset/customerdata.csv")

# 컬럼해더 재정의
customerData.columns = ['CUSTID','AVGPRICE','EMI','DEVICECOUNT','PRODUCTAGE','CUSTTYPE']
#customerData.columns = [x.upper() for x in customerData.columns]
# 데이터 VIEW
customerData.head()

## 조건 설정
emiCondition="3"
deviceCondition=5
inplaceVariable = customerData[ (customerData.EMI.astype(str) == emiCondition) & 
                                (customerData.DEVICECOUNT>deviceCondition) ]
#customerData.query('EMI == @emiCondition & DEVICECOUNT > @deviceCondition')
inplaceVariable.head()
# Out:
#     CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0   A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 27  F17131  3179.708359    3          6.5    1.100000        Early-bird
# 33  G16437  3787.328898    3          6.7    1.000000        Early-bird
# 36  G18402  3402.199381    3          6.5    1.000000        Early-bird
# 40  H16326  3988.935304    3          6.5    0.900000        Early-bird

# %%
import pandas as pd 
 
# CSV 파일을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_csv("../dataset/customerdata.csv")

# 컬럼해더 재정의
customerData.columns = ['CUSTID','AVGPRICE','EMI','DEVICECOUNT','PRODUCTAGE','CUSTTYPE']
# 데이터 VIEW
customerData.head()

## 조건 설정
emiCondition= ["2","3"]
deviceCondition=5
isinVariable = customerData[ ~customerData.EMI.isin(emiCondition)  ]
isinVariable.head()
# Out:
#     CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 11  C18622  3246.000000    1          5.0    1.891624  Big-Screen-lover
# 46  I14835  3374.091339    1          4.0    2.749678      Sleeping-dog
# 47  I17056  2963.370122    1          3.3    2.139196      Sleeping-dog
# 56  K10712  3419.462596    1          4.4    2.825790      Sleeping-dog
# 57  K13300  3159.839204    1          3.7    1.960833      Sleeping-dog

# %% [markdown]
# ### [추가] 데이터프레임 타입변환

# %%
customerData.dtypes
### int, str, float
customerData["DEVICECOUNT"] = customerData["DEVICECOUNT"].astype(float)
customerData.dtypes
customerData.head()
# Out:
#    CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219  3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312  3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605  3713.211107    2          6.6    0.900000        Early-bird
# 4  B10634  3391.074215    2          4.2    2.453656      Sleeping-dog

# %% [markdown]
# ### [프로젝트 실습]

# %% [markdown]
# [데이터타입 통합]
# kopo_channel_seasonality_new.csv 파일을 불러온 후
# selloutData 변수에 담으세요 이후
# QTY컬럼→실수(float), 이외컬럼→문자(str)로 변경하세요

# %% [markdown]
# ### 2. 원하는 컬럼 조회하기

# %%
import pandas as pd
from sqlalchemy import create_engine 
# CSV 파일을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_csv("../dataset/customerData.csv")
customerData.head()
# Out:
#    CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4  B10634   3391.074215    2          4.2    2.453656      Sleeping-dog

# %%
# 컬럼해더 재정의
customerDataC = customerData[['CUSTID','EMI']]

# 데이터 VIEW
customerDataC.head()
# Out:
#    CUSTID  EMI
# 0  A13566    3
# 1  A14219    2
# 2  A15312    2
# 3  A16605    2
# 4  B10634    2

# %%
# 특정컬럼 값 확인
customerDataD = customerData[['EMI']].drop_duplicates()

# %%
# customerDataD.EMI.values[0]

# %% [markdown]
# ### [추가] 인덱스로 행/열 선택하기

# %%
customerData

df1 = customerData.iloc[0:1,:]
df1
# Out:
#    CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566        4273.9    3          6.4    1.679181  Big-Screen-lover

# %%
df2 = customerData.loc[0:3][["AVERAGEPRICE","EMI"]]
df2.head()
# Out:
#    AVERAGEPRICE  EMI
# 0   4273.900000    3
# 1   3642.441950    2
# 2   3653.884565    2
# 3   3713.211107    2

# %%
import pandas as pd
from sqlalchemy import create_engine 
 
# CSV 파일을 읽어 Data Frame 변수에 저장하기
kopo_customerData = pd.read_csv("../dataset/kopo_customerdata.csv")
kopo_customerData.head(2)

### 데이터불러오기

kopo_customerData.columns

### 컬럼번호 인덱싱

stnameNo = kopo_customerData.columns.get_loc("STATENAME")
genderNo = kopo_customerData.columns.get_loc("GENDER")

kopo_customerData.iloc[0:5,[stnameNo,genderNo]]
# Out:
#   STATENAME  GENDER
# 0    State2    Male
# 1    State2    Male
# 2    State2  Female
# 3    State2    Male
# 4    State2    Male

# %% [markdown]
# ### 4. 이상 데이터 정제하기

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine 
 
# CSV 파일을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_csv("../dataset/customerdata.csv")

# %%
customerData.head(2)
# Out:
#    CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566    4273.90000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219    3642.44195    2          4.0    2.682023      Sleeping-dog

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine 
 
# CSV 파일을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_csv("../dataset/customerdata.csv")

customerData.columns = ["CUSTID","AVGPRICE","EMI","DEVICECOUNT","PRODUCTAGE","CUSTTYPE"]
#customerData.columns = [x.upper() for x in customerData.columns]

# 데이터 VIEW
customerData.head()


customerData["PRODUCTAGE"]= np.\
where(customerData["PRODUCTAGE"] < 1, 1,
customerData["PRODUCTAGE"])

customerData.head()
# Out:
#    CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219  3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312  3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605  3713.211107    2          6.6    1.000000        Early-bird
# 4  B10634  3391.074215    2          4.2    2.453656      Sleeping-dog

# %% [markdown]
# ### [추가] 데이터 컬럼간 연산하기

# %%
customerData["NEW_COLUMN"] = customerData.CUSTID.str[1:]+"_"+customerData.EMI.astype(str)
customerData.head()
# Out:
#    CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0  A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219  3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312  3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605  3713.211107    2          6.6    1.000000        Early-bird
# 4  B10634  3391.074215    2          4.2    2.453656      Sleeping-dog
#
#   NEW_COLUMN
# 0    13566_3
# 1    14219_2
# 2    15312_2
# 3    16605_2
# 4    10634_2

# %% [markdown]
# ### 실습문제

# %% [markdown]
# productage가 1보다작으면 1, 2보다작으면2, 3보다작으면3
# 이외는 5라고 새로운 컬럼 product_age_new를 생성하세요

# %% [markdown]
# ### [프로젝트 실습]

# %% [markdown]
# [불량 데이터 처리]
# kopo_channel_seasonality_new.csv 자료를 담은
# selloutData 변수에서
# QTY컬럼 음수(반품)인 경우 0, 양수인 경우 기존 QTY 값유지하는 로직을 적용하여 QTY_NEW 컬럼을 추가하세요

# %% [markdown]
# [데이터 통합]
# selloutData 자료에서
# YEAR, WEEK 컬럼을 생성하고 WEEK 가 52 이하인
# 데이터만 조회한 후 refinedSelloutData 변수에 담으세요

# %% [markdown]
# ### 5. 데이터 정렬하기

# %%
import pandas as pd
 
# CSV 파일을 읽어 Data Frame 변수에 저장하기
kopo_customerData = pd.read_csv("../dataset/customerdata.csv")

# %%
kopo_customerData.head()
# Out:
#    CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4  B10634   3391.074215    2          4.2    2.453656      Sleeping-dog

# %%
sortKey = ["EMI","AVERAGEPRICE"]

# %%
kopo_customerData.sort_values(sortKey, ascending=[False,True], inplace=True)
kopo_customerData.head()
# Out:
#      CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE    CUSTTYPE
# 52   J15083   2811.265932    3          6.0         0.9  Early-bird
# 135  X13390   2947.543982    3          6.3         1.1  Early-bird
# 45   I12899   3018.895637    3          6.4         0.9  Early-bird
# 53   J16445   3041.848186    3          6.4         0.8  Early-bird
# 27   F17131   3179.708359    3          6.5         1.1  Early-bird

# %% [markdown]
# ### 6. 데이터 요약분석 하기

# %%
groupKey = ['CUSTTYPE','EMI']

# %%
# 평균 구하기 # mean, std, sum
meanValue = customerData.\
groupby(groupKey, as_index=False).\
mean()
meanValue
#meanValue.reset_index(inplace=True)
# Out:
#            CUSTTYPE  EMI     AVGPRICE  DEVICECOUNT  PRODUCTAGE  \
# 0  Big-Screen-lover    1  3246.000000     5.000000    1.891624
# 1  Big-Screen-lover    2  3535.317391     5.508696    2.223247
# 2  Big-Screen-lover    3  4111.600000     6.400000    1.838520
# 3        Early-bird    1  2390.083736     6.300000    1.000000
# 4        Early-bird    2  3232.445885     6.460606    1.021212
# 5        Early-bird    3  3455.966035     6.475000    1.031250
# 6      Sleeping-dog    1  3185.918464     3.833333    2.357587
# 7      Sleeping-dog    2  3504.298670     4.353659    2.724274
#
#    PRODUCTAGE_NEW      TEST
# 0        2.000000  2.000000
# 1        2.804348  2.804348
# 2        2.333333  2.333333
# 3        2.000000  2.000000
# 4        2.000000  2.000000
# 5        2.000000  2.000000
# 6        2.777778  2.777778
# 7        3.463415  3.463415

# %%
# 평균 구하기 # mean, std, sum
meanValue = customerData.\
groupby(groupKey, as_index=False)[["AVGPRICE"]].\
mean()
meanValue
#meanValue.reset_index(inplace=True)
# Out:
#            CUSTTYPE  EMI     AVGPRICE
# 0  Big-Screen-lover    1  3246.000000
# 1  Big-Screen-lover    2  3535.317391
# 2  Big-Screen-lover    3  4111.600000
# 3        Early-bird    1  2390.083736
# 4        Early-bird    2  3232.445885
# 5        Early-bird    3  3455.966035
# 6      Sleeping-dog    1  3185.918464
# 7      Sleeping-dog    2  3504.298670

# %%
# 평균 및 표준편차 구하기
groupData = customerData.groupby(groupKey).agg(["mean","std"])["AVGPRICE"]
groupData
# Out:
#                              mean         std
# CUSTTYPE         EMI
# Big-Screen-lover 1    3246.000000         NaN
#                  2    3535.317391  322.633901
#                  3    4111.600000  195.060324
# Early-bird       1    2390.083736         NaN
#                  2    3232.445885  345.810935
#                  3    3455.966035  412.696326
# Sleeping-dog     1    3185.918464  199.545685
#                  2    3504.298670  317.495859

# %% [markdown]
# ### 실습

# %% [markdown]
# EMI 별 MAX 값을 구하세요

# %% [markdown]
# ### [프로젝트 실습]

# %% [markdown]
# refinedData 에서 →
# 지역, 상품, 연주차 단위로 정렬하여
# sortedData 변수에 담으세요

# %% [markdown]
# [지역, 상품, 연도별 집계]
# sortedData 에서 지역, 상품 단위
# 판매량(QTY_NEW) 의 평균 연산 후
# groupData 변수에 담으세요
#
# 이후 컬럼명을 QTY_MEAN로 변경하세요

# %% [markdown]
# ### # 기본통계치 구하기

# %%
# 기본통계치 구하기
meanPriceValue = customerData.\
groupby(['EMI']).AVGPRICE.\
describe()
meanPriceValue
# Out:
#      count         mean         std          min          25%          50%  \
# EMI
# 1     11.0  3119.031810  301.047916  2390.083736  2978.220215  3159.839204
# 2    120.0  3441.429664  349.691674  2411.008838  3231.429242  3418.480121
# 3     19.0  3559.487188  454.411870  2811.265932  3219.363531  3592.353540
#
#              75%          max
# EMI
# 1    3363.814315  3419.462596
# 2    3656.799297  4166.533130
# 3    3867.447366  4296.873743

# %%
meanPriceGroup = meanPriceValue.reset_index()
meanPriceGroup
# Out:
#    EMI  count         mean         std          min          25%          50%  \
# 0    1   11.0  3119.031810  301.047916  2390.083736  2978.220215  3159.839204
# 1    2  120.0  3441.429664  349.691674  2411.008838  3231.429242  3418.480121
# 2    3   19.0  3559.487188  454.411870  2811.265932  3219.363531  3592.353540
#
#            75%          max
# 0  3363.814315  3419.462596
# 1  3656.799297  4166.533130
# 2  3867.447366  4296.873743

# %% [markdown]
# ### 7. 데이터 연산하기 (심화 - 고급), 이동평균법

# %%
# 이동평균 구간 정의
order = 5
import math
suborder = math.floor(order/2)
suborder

# 연산
customerData["TEST"] = customerData["PRODUCTAGE"].rolling(window = 5, center = True,
                                                         min_periods=1).mean()
customerData.head(10)
# Out:
#    CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0  A13566  4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219  3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312  3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605  3713.211107    2          6.6    1.000000        Early-bird
# 4  B10634  3391.074215    2          4.2    2.453656      Sleeping-dog
# 5  B16849  3755.263391    2          4.7    2.786665      Sleeping-dog
# 6  B18816  3213.911446    2          6.4    1.000000        Early-bird
# 7  C10639  3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8  C12717  3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9  C15050  4020.173425    2          4.9    3.013440      Sleeping-dog
#
#   NEW_COLUMN  PRODUCTAGE_NEW      TEST
# 0    13566_3               2  2.523135
# 1    14219_2               3  2.142351
# 2    15312_2               5  2.204612
# ...

# %% [markdown]
# # B. 데이터 합치기

# %%
import pandas as pd
from sqlalchemy import create_engine 
 
# CSV 파일을 읽어 Data Frame 변수에 저장하기
joinSellout = pd.read_csv("../dataset/join_kopo_product_volume.csv")
print(joinSellout.head())

# CSV 파일을 읽어 Data Frame 변수에 저장하기
joinMaster = pd.read_csv("../dataset/join_region_master.csv", encoding = "ms949") 

print(joinMaster.head())
# Out:
#   REGIONID PRODUCT  YEARWEEK   QTY
# 0      A01  ST0001    201901  3000
# 1      A01  ST0001    201902  3500
# 2      A02  ST0002    201901  4000
# 3      A02  ST0003    201902  7000
#   REGIONID REGIONNAME
# 0      A01         한국
# 1      A02         미국
# 2      A03        프랑스
# 3      A04         독일

# %%
joinSellout
# Out:
#   REGIONID PRODUCT  YEARWEEK   QTY
# 0      A01  ST0001    201901  3000
# 1      A01  ST0001    201902  3500
# 2      A02  ST0002    201901  4000
# 3      A02  ST0003    201902  7000

# %%
joinMaster
# Out:
#   REGIONID REGIONNAME
# 0      A01         한국
# 1      A02         미국
# 2      A03        프랑스
# 3      A04         독일

# %%
mergeResult = pd.merge(joinSellout, joinMaster,\
        left_on="REGIONID", right_on = "REGIONID", how="inner")\
[["REGIONID","REGIONNAME","PRODUCT","YEARWEEK","QTY"]]
mergeResult.head()
# Out:
#   REGIONID REGIONNAME PRODUCT  YEARWEEK   QTY
# 0      A01         한국  ST0001    201901  3000
# 1      A01         한국  ST0001    201902  3500
# 2      A02         미국  ST0002    201901  4000
# 3      A02         미국  ST0003    201902  7000

# %% [markdown]
# ### [프로젝트 실습]

# %% [markdown]
# refinedSelloutData와 groupData를
# [REGIONID, PRODUCT, YEAR] 키로 조인하여
# mergedData 변수에 아래와 같이 담으세요

# %% [markdown]
# 계절성 지수는
# QTY_NEW / QTY_MEAN
# 으로 산출하여 SEASONALITY 컬럼을 생성한다.

# %% [markdown]
# 마지막으로 [지역, 상품, 주차] 별
# 계절성 지수, 판매량  평균 값을
# 조별 산출하세요.

# %%
# A01 데이터 정제
a01data = joinSellout[(joinSellout['REGIONID']=='A01')]
print(len(a01data))

# A02 데이터 정제
a02data = joinSellout[(joinSellout['REGIONID']=='A02')]
print(len(a02data))

# 데이터 결과 값 MERGE
mergedata = pd.concat([a01data, a02data], axis=0)
print(len(mergedata))
# Out:
# 2
# 2
# 4
