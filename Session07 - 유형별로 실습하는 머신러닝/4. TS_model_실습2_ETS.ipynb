# %%
import statsmodels.tsa.holtwinters

# %%
from statsmodels.tsa.api import ExponentialSmoothing , SimpleExpSmoothing 
from statsmodels.tsa.arima_model import ARIMA
import scipy
from scipy.optimize import minimize 
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.tsa import api 
from statsmodels.tsa.api import ExponentialSmoothing , SimpleExpSmoothing 
from statsmodels.tsa.arima_model import ARIMA
import scipy
from scipy.optimize import minimize 
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ### 1. 데이터 불러오기

# %%
#CSV 파일 불러오기
selloutData = pd.read_csv('../dataset/sample_kopo.csv')
# 컬럼해더 재정의
selloutData.columns = selloutData.columns.str.upper()
# 데이터 VIEW
selloutData.head()
# Out:
#    YEAR MONTH  REGION   SUBSIDIARY   PRODUCT   BRAND      MODEL MODEL_GROUP  \
# 0  2015   JAN  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0895  MODELG0876
# 1  2015   FEB  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0895  MODELG0876
# 2  2015   MAR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0895  MODELG0876
# 3  2015   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0895  MODELG0876
# 4  2015   MAY  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0895  MODELG0876
#
#   CAPA   FEATURE  SALES_QTY  SALES_PRICE  MON
# 0    -  FEATURE1        103        97084    1
# 1    -  FEATURE1         60        52861    2
# 2    -  FEATURE1        172       150478    3
# 3    -  FEATURE1        145       121392    4
# 4    -  FEATURE1         71        61763    5

# %% [markdown]
# ### 2. 데이터 필터 및 정렬

# %%
sortKey = ["SUBSIDIARY","PRODUCT","MODEL","YEAR","MON"]
groupKey = ["SUBSIDIARY","PRODUCT","MODEL"]

# %%
# 오름차순정렬
sortedData = selloutData.sort_values(sortKey)
sortedData.reset_index(drop=True,inplace=True)
sortedData.head()
# Out:
#    YEAR MONTH  REGION   SUBSIDIARY   PRODUCT   BRAND      MODEL MODEL_GROUP  \
# 0  2017   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND2  MODEL0001  MODELG0001
# 1  2017   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND2  MODEL0002  MODELG0002
# 2  2017   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND2  MODEL0005  MODELG0005
# 3  2017   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND2  MODEL0008  MODELG0008
# 4  2014   JAN  Europe  SUBSIDIARY1  PRODUCT1  BRAND2  MODEL0013  MODELG0013
#
#   CAPA   FEATURE  SALES_QTY  SALES_PRICE  MON
# 0  267  FEATURE2          1         1271    4
# 1  268  FEATURE2         10         8498    4
# 2  266  FEATURE2          2         2023    4
# 3  264  FEATURE2          1         1311    4
# 4  348  FEATURE1          1          690    1

# %%
def groupCountDf(eachGroup):

    #eachGroup = groupData.get_group(list(groupData.groups)[5])

    eachGroup["KNOB"] = eachGroup["SALES_QTY"].count()

    return eachGroup

# %%
groupResult = sortedData.groupby(groupKey).apply(groupCountDf)

# %%
maxKnob = groupResult["KNOB"].max()
maxKnob
# Out:
# 40

# %% [markdown]
# ### 최대 maxKnob 존재 데이터만 필터링

# %%
refinedData = groupResult[groupResult.KNOB >= maxKnob]

# %%
refinedData["YEARMON"] = refinedData["YEAR"].astype(str) +  refinedData["MON"].astype(str).str.zfill(2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
refinedData
# Out:
#        YEAR MONTH  REGION   SUBSIDIARY   PRODUCT   BRAND      MODEL  \
# 208    2014   JAN  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 209    2014   FEB  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 210    2014   MAR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 211    2014   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 212    2014   MAY  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 213    2014   JUN  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 214    2014   JUL  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 215    2014   AUG  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 216    2014   SEP  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 217    2014   OCT  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 218    2014   NOV  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 219    2014   DEC  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 220    2015   JAN  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 221    2015   FEB  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 222    2015   MAR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 223    2015   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 224    2015   MAY  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 225    2015   JUN  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 226    2015   JUL  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 227    2015   AUG  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 228    2015   SEP  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 229    2015   OCT  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 230    2015   NOV  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 231    2015   DEC  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 232    2016   JAN  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 233    2016   FEB  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 234    2016   MAR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 235    2016   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 236    2016   MAY  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 237    2016   JUN  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# ...     ...   ...     ...          ...       ...     ...        ...
# 15404  2014   NOV  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15405  2014   DEC  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15406  2015   JAN  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15407  2015   FEB  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15408  2015   MAR  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15409  2015   APR  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15410  2015   MAY  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15411  2015   JUN  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15412  2015   JUL  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15413  2015   AUG  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15414  2015   SEP  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15415  2015   OCT  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15416  2015   NOV  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15417  2015   DEC  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15418  2016   JAN  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15419  2016   FEB  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15420  2016   MAR  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15421  2016   APR  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15422  2016   MAY  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15423  2016   JUN  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15424  2016   JUL  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15425  2016   AUG  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15426  2016   SEP  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15427  2016   OCT  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15428  2016   NOV  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15429  2016   DEC  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15430  2017   JAN  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15431  2017   FEB  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15432  2017   MAR  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 15433  2017   APR  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
#
#       MODEL_GROUP CAPA   FEATURE  SALES_QTY  SALES_PRICE  MON  KNOB YEARMON
# 208    MODELG0037  264  FEATURE4         78        66839    1    40  201401
# 209    MODELG0037  264  FEATURE4         71        62273    2    40  201402
# 210    MODELG0037  264  FEATURE4         77        69258    3    40  201403
# 211    MODELG0037  264  FEATURE4         62        55437    4    40  201404
# 212    MODELG0037  264  FEATURE4         76        68938    5    40  201405
# 213    MODELG0037  264  FEATURE4         78        69120    6    40  201406
# 214    MODELG0037  264  FEATURE4         97        84177    7    40  201407
# 215    MODELG0037  264  FEATURE4         54        46278    8    40  201408
# 216    MODELG0037  264  FEATURE4         58        49769    9    40  201409
# 217    MODELG0037  264  FEATURE4         41        34219   10    40  201410
# 218    MODELG0037  264  FEATURE4         38        31706   11    40  201411
# 219    MODELG0037  264  FEATURE4         67        55096   12    40  201412
# 220    MODELG0037  264  FEATURE4        442       271868    1    40  201501
# 221    MODELG0037  264  FEATURE4        138        75750    2    40  201502
# 222    MODELG0037  264  FEATURE4         35        19270    3    40  201503
# 223    MODELG0037  264  FEATURE4         52        28128    4    40  201504
# 224    MODELG0037  264  FEATURE4         61        34311    5    40  201505
# 225    MODELG0037  264  FEATURE4         10         5391    6    40  201506
# 226    MODELG0037  264  FEATURE4         12         5629    7    40  201507
# 227    MODELG0037  264  FEATURE4          7         3941    8    40  201508
# 228    MODELG0037  264  FEATURE4          6         3562    9    40  201509
# 229    MODELG0037  264  FEATURE4         40        26718   10    40  201510
# 230    MODELG0037  264  FEATURE4         79        51839   11    40  201511
# 231    MODELG0037  264  FEATURE4          7         4371   12    40  201512
# 232    MODELG0037  264  FEATURE4          2         1130    1    40  201601
# 233    MODELG0037  264  FEATURE4          4         2529    2    40  201602
# 234    MODELG0037  264  FEATURE4          1          650    3    40  201603
# 235    MODELG0037  264  FEATURE4         12         8108    4    40  201604
# 236    MODELG0037  264  FEATURE4         10         7363    5    40  201605
# 237    MODELG0037  264  FEATURE4         28        19694    6    40  201606
# ...           ...  ...       ...        ...          ...  ...   ...     ...
# 15404  MODELG0791  494  FEATURE6        767      1020659   11    40  201411
# 15405  MODELG0791  494  FEATURE6        957      1296861   12    40  201412
# 15406  MODELG0791  494  FEATURE6        916      1137428    1    40  201501
# 15407  MODELG0791  494  FEATURE6        633       753034    2    40  201502
# 15408  MODELG0791  494  FEATURE6        587       671211    3    40  201503
# 15409  MODELG0791  494  FEATURE6        536       614624    4    40  201504
# 15410  MODELG0791  494  FEATURE6        670       789353    5    40  201505
# 15411  MODELG0791  494  FEATURE6        702       805871    6    40  201506
# 15412  MODELG0791  494  FEATURE6        755       851973    7    40  201507
# 15413  MODELG0791  494  FEATURE6        692       803218    8    40  201508
# 15414  MODELG0791  494  FEATURE6        721       881275    9    40  201509
# 15415  MODELG0791  494  FEATURE6        804      1001088   10    40  201510
# 15416  MODELG0791  494  FEATURE6        838      1042781   11    40  201511
# 15417  MODELG0791  494  FEATURE6        940      1108444   12    40  201512
# 15418  MODELG0791  494  FEATURE6        751       870115    1    40  201601
# 15419  MODELG0791  494  FEATURE6        523       594271    2    40  201602
# 15420  MODELG0791  494  FEATURE6        439       513308    3    40  201603
# 15421  MODELG0791  494  FEATURE6        508       639444    4    40  201604
# 15422  MODELG0791  494  FEATURE6        554       676879    5    40  201605
# 15423  MODELG0791  494  FEATURE6        558       657790    6    40  201606
# 15424  MODELG0791  494  FEATURE6        601       682502    7    40  201607
# 15425  MODELG0791  494  FEATURE6        545       651051    8    40  201608
# 15426  MODELG0791  494  FEATURE6        409       428111    9    40  201609
# 15427  MODELG0791  494  FEATURE6        303       312733   10    40  201610
# 15428  MODELG0791  494  FEATURE6        224       276179   11    40  201611
# 15429  MODELG0791  494  FEATURE6        216       248188   12    40  201612
# 15430  MODELG0791  494  FEATURE6         19        19136    1    40  201701
# 15431  MODELG0791  494  FEATURE6          8         8710    2    40  201702
# 15432  MODELG0791  494  FEATURE6          5         5272    3    40  201703
# 15433  MODELG0791  494  FEATURE6          7         7225    4    40  201704
#
# [3320 rows x 15 columns]

# %% [markdown]
# ### 3. ets 머신러닝 사용

# %%
# pip install --upgrade --no-deps statsmodels stats모델 업데이트
# mul: 데이터 흐름이 비선형형태. 곱셉 방식의 증가 
# add: 데이터 흐름이 선형형태. 덧셈 방식의 증가
# 계절성 옵션이라 추즉했던 seasonal_periods는 52주로 정함
# 지수평활화의 함수에선 시계열의 흐름과 특징이 맞지 않으면 자동으로 인덱스 오류가 발생한다

# %%
YEARMON_STD = 201604

# %%
holtwinters()

# %%
def sub_function(data):
   #그룹바이 다음에 바로 apply(sub_function)이 들어갈거기때문에 맨첫줄에 reset_index 
    data.reset_index(inplace=True,drop=True)
    ########################################2017년기준으로 train ,test 데이터 분리##
    trainData = data[data["YEARMON"].astype(int)<YEARMON_STD].reset_index(drop = True)
    testData = data[data["YEARMON"].astype(int)>=YEARMON_STD].reset_index(drop = True)
    trainCount = len(trainData)
    testCount = len(testData)
    y =  trainData[['SALES_QTY']]
    M = 'multiplicative'
    #######################################모델적용############################################
    ##ets_model = ExponentialSmoothing(y.values,  trend=None, seasonal=M,  seasonal_periods=12 )
    ##ets_fit = ets_model.fit(optimized='True')
    hw_fit = ExponentialSmoothing(y.values, seasonal_periods=12, trend='add', seasonal='add').fit(use_boxcox=True)
    ##ets_model = ARIMA(y.values, order=(0,1,1))
    ##ets_fit = ets_model.fit(trend='c',full_output=True, disp=1)
    yhPredict = hw_fit.predict(start=trainCount+1,end=trainCount+testCount)
    ###############예측데이터 데이터프레임화 후 testData에 밀어넣음##############################
    yh = pd.DataFrame(data = yhPredict,columns = ["predict"])
    testData["PREDICT"] = yh
    
    #input값으로 들어온 데이터 수랑 return으로 보내는 testData는 수가 다른데 리턴값에 따라 데이터프레임 변형되도 상관없는듯.
    return testData

# %%
forecastData = refinedData.groupby(groupKey).apply(sub_function).reset_index(drop=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\morestats.py:901: RuntimeWarning: divide by zero encountered in log
#   llf -= N / 2.0 * np.log(np.sum((y - y_mean)**2. / N, axis=0))
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\optimize.py:2189: RuntimeWarning: invalid value encountered in double_scalars
#   w = xb - ((xb - xc) * tmp2 - (xb - xa) * tmp1) / denom
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\optimize.py:1849: RuntimeWarning: invalid value encountered in double_scalars
#   tmp1 = (x - w) * (fx - fv)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\optimize.py:1850: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\optimize.py:1851: RuntimeWarning: invalid value encountered in double_scalars
#   p = (x - v) * tmp2 - (x - w) * tmp1
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\optimize.py:1852: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = 2.0 * (tmp2 - tmp1)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:726: RuntimeWarning: invalid value encountered in subtract
#   season = (fitted - inv_boxcox(trend, lamda))[:i]

# %%
forecastData
# Out:
#       YEAR MONTH  REGION   SUBSIDIARY   PRODUCT   BRAND      MODEL  \
# 0     2016   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 1     2016   MAY  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 2     2016   JUN  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 3     2016   JUL  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 4     2016   AUG  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 5     2016   SEP  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 6     2016   OCT  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 7     2016   NOV  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 8     2016   DEC  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 9     2017   JAN  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 10    2017   FEB  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 11    2017   MAR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 12    2017   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0037
# 13    2016   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 14    2016   MAY  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 15    2016   JUN  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 16    2016   JUL  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 17    2016   AUG  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 18    2016   SEP  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 19    2016   OCT  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 20    2016   NOV  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 21    2016   DEC  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 22    2017   JAN  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 23    2017   FEB  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 24    2017   MAR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 25    2017   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0038
# 26    2016   APR  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0041
# 27    2016   MAY  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0041
# 28    2016   JUN  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0041
# 29    2016   JUL  Europe  SUBSIDIARY1  PRODUCT1  BRAND1  MODEL0041
# ...    ...   ...     ...          ...       ...     ...        ...
# 1049  2017   JAN  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0729
# 1050  2017   FEB  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0729
# 1051  2017   MAR  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0729
# 1052  2017   APR  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0729
# 1053  2016   APR  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1054  2016   MAY  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1055  2016   JUN  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1056  2016   JUL  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1057  2016   AUG  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1058  2016   SEP  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1059  2016   OCT  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1060  2016   NOV  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1061  2016   DEC  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1062  2017   JAN  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1063  2017   FEB  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1064  2017   MAR  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1065  2017   APR  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0751
# 1066  2016   APR  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1067  2016   MAY  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1068  2016   JUN  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1069  2016   JUL  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1070  2016   AUG  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1071  2016   SEP  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1072  2016   OCT  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1073  2016   NOV  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1074  2016   DEC  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1075  2017   JAN  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1076  2017   FEB  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1077  2017   MAR  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
# 1078  2017   APR  Europe  SUBSIDIARY2  PRODUCT1  BRAND2  MODEL0807
#
#      MODEL_GROUP CAPA   FEATURE  SALES_QTY  SALES_PRICE  MON  KNOB YEARMON  \
# 0     MODELG0037  264  FEATURE4         12         8108    4    40  201604
# 1     MODELG0037  264  FEATURE4         10         7363    5    40  201605
# 2     MODELG0037  264  FEATURE4         28        19694    6    40  201606
# 3     MODELG0037  264  FEATURE4         29        20460    7    40  201607
# 4     MODELG0037  264  FEATURE4         38        23425    8    40  201608
# 5     MODELG0037  264  FEATURE4         49        29044    9    40  201609
# 6     MODELG0037  264  FEATURE4         52        30669   10    40  201610
# 7     MODELG0037  264  FEATURE4         27        15849   11    40  201611
# 8     MODELG0037  264  FEATURE4         16         9183   12    40  201612
# 9     MODELG0037  264  FEATURE4         29        15906    1    40  201701
# 10    MODELG0037  264  FEATURE4         22        11127    2    40  201702
# 11    MODELG0037  264  FEATURE4         10         4867    3    40  201703
# 12    MODELG0037  264  FEATURE4          7         3938    4    40  201704
# 13    MODELG0038  264  FEATURE4         77        40440    4    40  201604
# 14    MODELG0038  264  FEATURE4         79        41012    5    40  201605
# 15    MODELG0038  264  FEATURE4         96        48530    6    40  201606
# 16    MODELG0038  264  FEATURE4        102        51580    7    40  201607
# 17    MODELG0038  264  FEATURE4         81        41511    8    40  201608
# 18    MODELG0038  264  FEATURE4        135        71870    9    40  201609
# 19    MODELG0038  264  FEATURE4         64        32618   10    40  201610
# 20    MODELG0038  264  FEATURE4         70        35334   11    40  201611
# 21    MODELG0038  264  FEATURE4         60        28922   12    40  201612
# 22    MODELG0038  264  FEATURE4         81        38378    1    40  201701
# 23    MODELG0038  264  FEATURE4         67        32920    2    40  201702
# 24    MODELG0038  264  FEATURE4         61        29118    3    40  201703
# 25    MODELG0038  264  FEATURE4         48        23266    4    40  201704
# 26    MODELG0041  293  FEATURE4         13        13036    4    40  201604
# 27    MODELG0041  293  FEATURE4         16        16233    5    40  201605
# 28    MODELG0041  293  FEATURE4         13        12791    6    40  201606
# 29    MODELG0041  293  FEATURE4         23        22054    7    40  201607
# ...          ...  ...       ...        ...          ...  ...   ...     ...
# 1049  MODELG0716  572  FEATURE6         91        70012    1    40  201701
# 1050  MODELG0716  572  FEATURE6         89        72604    2    40  201702
# 1051  MODELG0716  572  FEATURE6         67        52700    3    40  201703
# 1052  MODELG0716  572  FEATURE6         81        65878    4    40  201704
# 1053  MODELG0737  545  FEATURE6         99       126991    4    40  201604
# 1054  MODELG0737  545  FEATURE6        115       143518    5    40  201605
# 1055  MODELG0737  545  FEATURE6        118       142305    6    40  201606
# 1056  MODELG0737  545  FEATURE6        170       181073    7    40  201607
# 1057  MODELG0737  545  FEATURE6        125       135962    8    40  201608
# 1058  MODELG0737  545  FEATURE6        129       136641    9    40  201609
# 1059  MODELG0737  545  FEATURE6        153       163008   10    40  201610
# 1060  MODELG0737  545  FEATURE6        139       148578   11    40  201611
# 1061  MODELG0737  545  FEATURE6        162       160766   12    40  201612
# 1062  MODELG0737  545  FEATURE6        131       128574    1    40  201701
# 1063  MODELG0737  545  FEATURE6         83        88193    2    40  201702
# 1064  MODELG0737  545  FEATURE6         77        80264    3    40  201703
# 1065  MODELG0737  545  FEATURE6         28        32239    4    40  201704
# 1066  MODELG0791  494  FEATURE6        508       639444    4    40  201604
# 1067  MODELG0791  494  FEATURE6        554       676879    5    40  201605
# 1068  MODELG0791  494  FEATURE6        558       657790    6    40  201606
# 1069  MODELG0791  494  FEATURE6        601       682502    7    40  201607
# 1070  MODELG0791  494  FEATURE6        545       651051    8    40  201608
# 1071  MODELG0791  494  FEATURE6        409       428111    9    40  201609
# 1072  MODELG0791  494  FEATURE6        303       312733   10    40  201610
# 1073  MODELG0791  494  FEATURE6        224       276179   11    40  201611
# 1074  MODELG0791  494  FEATURE6        216       248188   12    40  201612
# 1075  MODELG0791  494  FEATURE6         19        19136    1    40  201701
# 1076  MODELG0791  494  FEATURE6          8         8710    2    40  201702
# 1077  MODELG0791  494  FEATURE6          5         5272    3    40  201703
# 1078  MODELG0791  494  FEATURE6          7         7225    4    40  201704
#
#          PREDICT
# 0       2.564799
# 1       0.530662
# 2       1.069938
# 3       0.345972
# 4       0.429469
# 5       2.070454
# 6       4.379561
# 7       1.149107
# 8       7.429157
# 9       3.726691
# 10      1.000000
# 11      1.444459
# 12      2.564798
# 13    122.688025
# 14     60.385726
# 15    134.967447
# 16    118.313377
# 17     91.793392
# 18    138.158514
# 19     99.725170
# 20    102.167815
# 21    116.104217
# 22    107.558479
# 23     59.201854
# 24     70.217292
# 25    109.554701
# 26     22.000730
# 27     29.960862
# 28     32.420388
# 29     28.743445
# ...          ...
# 1049  142.435494
# 1050  182.769045
# 1051  153.334805
# 1052  215.818182
# 1053  121.303299
# 1054  169.391204
# 1055  229.130636
# 1056  238.079167
# 1057  241.312166
# 1058  279.258964
# 1059  294.834822
# 1060  339.378070
# 1061  272.305325
# 1062  172.114032
# 1063  142.775078
# 1064  119.977581
# 1065  141.905400
# 1066  544.502583
# 1067  577.494879
# 1068  665.359030
# 1069  687.042955
# 1070  732.420288
# 1071  773.241686
# 1072  820.482365
# 1073  948.009345
# 1074  797.708809
# 1075  578.028613
# 1076  567.924566
# 1077  542.237645
# 1078  635.002308
#
# [1079 rows x 16 columns]

# %% [markdown]
# ### 4. 그룹바이 디버깅 시각화

# %%
groupNewcustomerData = forecastData.groupby(groupKey)

# %%
len(groupNewcustomerData)
# Out:
# 83

# %%
#14개의 그룹중 첫번째 그룹을 가져옴
eachGroup = groupNewcustomerData.get_group(list(groupNewcustomerData.groups)[0])

# %%
#치솟는 값이 있어서 시각화가힘들어져 걸러냄
eachGroup1 =eachGroup[eachGroup['PREDICT']<2000]

# %%
#실제값과 예측값 시각화 비교
plt.plot(eachGroup1['YEARMON'],eachGroup1['SALES_QTY'])
plt.plot(eachGroup1['YEARMON'],eachGroup1['PREDICT'])
plt.show()

# %% [markdown]
# ### 5. 정확도 측정

# %%
mean_squared_error(forecastData['SALES_QTY'], forecastData['PREDICT'])
# Out:
# 80908.24523633248

# %%
mean_absolute_error(forecastData['SALES_QTY'], forecastData['PREDICT'])
# Out:
# 143.62598457080233

# %% [markdown]
# ### 6. csv로 내보내기

# %%
#forecastData.to_csv('ets.csv',index = False)
