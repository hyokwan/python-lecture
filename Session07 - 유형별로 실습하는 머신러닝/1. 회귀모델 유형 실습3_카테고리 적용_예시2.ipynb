# %%
import pandas as pd
import numpy as np
import warnings

from sklearn.preprocessing import LabelEncoder
from sklearn import tree, linear_model, ensemble, svm
from sklearn.metrics import mean_absolute_error

import matplotlib.pyplot as plt

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 1. 데이터 불러오기

# %%
featuresData = pd.read_csv("../dataset/kopo_decision_tree_all_new.csv")
print(type(featuresData), featuresData.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'> (32415, 12)

# %%
len(featuresData.ITEM.unique())
# Out:
# 491

# %%
groupKey = ["REGIONID", "ITEM"]

# %%
groupData = featuresData.groupby(groupKey)[["QTY"]].agg("size").reset_index()
groupData.head()
# Out:
#   REGIONID     ITEM  0
# 0      A01  ITEM001  3
# 1      A01  ITEM002  2
# 2      A01  ITEM003  1
# 3      A01  ITEM004  7
# 4      A01  ITEM005  8

# %%
groupData.rename(columns={0:"KNOB"}, inplace=True)

# %%
mergedData = pd.merge(left=featuresData,
        right=groupData,
        on=groupKey,
        how="left")
mergedData.head(6)
# Out:
#   REGIONID PRODUCTGROUP PRODUCT     ITEM  YEARWEEK  YEAR  WEEK  QTY HOLIDAY  \
# 0      A01         PG01     P01  ITEM001    201538  2015    38    1       N
# 1      A01         PG01     P01  ITEM001    201548  2015    48    1       Y
# 2      A01         PG01     P01  ITEM001    201549  2015    49    2       Y
# 3      A01         PG01     P01  ITEM002    201526  2015    26    1       Y
# 4      A01         PG01     P01  ITEM002    201532  2015    32    1       N
# 5      A01         PG01     P01  ITEM003    201553  2015    53    2       Y
#
#    HCLUS PROMOTION  PRO_PERCENT  KNOB
# 0      4         N          0.0     3
# 1      0         N          0.0     3
# 2      0         N          0.0     3
# 3      1         N          0.0     2
# 4      4         N          0.0     2
# 5      1         N          0.0     1

# %% [markdown]
# ### 2. 데이터 전처리 (MAX 실적 보유자료만 활용)

# %%
maxHistory = mergedData.KNOB.max()

# %%
cleansedData = mergedData[mergedData.KNOB >= maxHistory]

# %%
le_pro = LabelEncoder()

# %%
cleansedData["N_PRODUCTGROUP"] = le_pro.fit_transform(cleansedData.PRODUCTGROUP)
cleansedData["N_PRODUCT"] = le_pro.fit_transform(cleansedData.PRODUCT)

# %%
ynMap = {"Y":1, "N":0}
cleansedData["HOLI_YN"] = cleansedData.HOLIDAY.map(ynMap)
cleansedData["PROM_YN"] = cleansedData.PROMOTION.map(ynMap)
cleansedData.head(3)
# Out:
#      REGIONID PRODUCTGROUP PRODUCT     ITEM  YEARWEEK  YEAR  WEEK  QTY  \
# 2352      A01         PG02     P03  ITEM043    201501  2015     1   87
# 2353      A01         PG02     P03  ITEM043    201502  2015     2   60
# 2354      A01         PG02     P03  ITEM043    201503  2015     3   51
#
#      HOLIDAY  HCLUS PROMOTION  PRO_PERCENT  KNOB  N_PRODUCTGROUP  N_PRODUCT  \
# 2352       Y      1         Y      0.19759   146               0          0
# 2353       N      4         Y      0.19759   146               0          0
# 2354       N      4         N      0.00000   146               0          0
#
#       HOLI_YN  PROM_YN
# 2352        1        1
# 2353        0        1
# 2354        0        0

# %%
len(cleansedData.ITEM.unique())
# Out:
# 52

# %% [markdown]
# ### 3. 전체 그룹 최적 MAE 검색

# %%
def predict_ml(onegroup):
    eachGroup = onegroup.reset_index(drop=True)

    ### 3-1. 특성선정

    corrdf = eachGroup.corr(numeric_only=True)
    corrStd = 0.6
    features = list(corrdf[(abs(corrdf.QTY) > corrStd) & (corrdf.QTY < 1)].index)
    label = ['QTY']
    
    if len(features) < 1:
        while (True) :
            corrStd -= 0.05
            features = list(corrdf[(abs(corrdf.QTY) > corrStd) & (corrdf.QTY < 1)].index)
            
            if len(features) > 0:
                break
    
    ## 만약 feature가 없는 경우 예측값 = 0 [과연 0?]
    ## 만약 feature가 있는 경우 예측 [3가지 방법으로 예측]
    ## 검증 [mae] 최소인 모델 > bestmodel 선정

    ### 3-2. 데이터 분리

    yearweekStd = 201701

    trainData_features = eachGroup[eachGroup.YEARWEEK < yearweekStd][features]
    trainData_label = eachGroup[eachGroup.YEARWEEK < yearweekStd][label]
    testData_features = eachGroup[eachGroup.YEARWEEK >= yearweekStd][features]
    testData_label = eachGroup[eachGroup.YEARWEEK >= yearweekStd][label]
    testData_all = eachGroup[eachGroup.YEARWEEK >= yearweekStd]

    ### 3-3. 모델 선언
    model_method_tr = tree.DecisionTreeRegressor(random_state=1)
    model_method_rf = ensemble.RandomForestRegressor(random_state=1)
    model_method_lr = linear_model.LinearRegression()
    model_method_svm = svm.SVR(gamma='scale', C=1.0, epsilon=0.2)

    ### 3-4. 훈련
    model_tr = model_method_tr.fit(trainData_features, trainData_label)
    model_rf = model_method_rf.fit(trainData_features, trainData_label)
    model_lr = model_method_lr.fit(trainData_features, trainData_label)
    model_svm = model_method_svm.fit(trainData_features, trainData_label)

    ### 3-5. 예측
    predict_tr = model_tr.predict(testData_features)
    predict_rf = model_rf.predict(testData_features)
    predict_lr = model_lr.predict(testData_features)
    predict_svm = model_svm.predict(testData_features)
    
    testData_all["TR_PREDICT"] = predict_tr
    testData_all["RF_PREDICT"] = predict_rf
    testData_all["LR_PREDICT"] = predict_lr
    testData_all["SVM_PREDICT"] = predict_svm

    mae_tr = mean_absolute_error(testData_all.QTY, testData_all.TR_PREDICT)
    mae_rf = mean_absolute_error(testData_all.QTY, testData_all.RF_PREDICT)
    mae_lr = mean_absolute_error(testData_all.QTY, testData_all.LR_PREDICT)
    mae_svm = mean_absolute_error(testData_all.QTY, testData_all.SVM_PREDICT)
    
    maeList = [mae_tr, mae_rf, mae_lr, mae_svm]
    maeDic = {mae_tr:"DecisionTreeRegressor", mae_rf:"RandomForestRegressor", mae_lr:"LinearRegression", mae_svm:"SVM"}
    model_name = np.array([maeDic[np.min(maeList)]]*len(testData_all))
    testData_all["MODEL"] = model_name
    corr_std = np.array([round(corrStd,2)]*len(testData_all))
    testData_all["COR_STD"] = corr_std
    maxMae = np.array([round(np.min(maeList),2)]*len(testData_all))
    testData_all["MIN_MAE"] = maxMae
    featureList = np.array([", ".join(features)]*len(testData_all))
    testData_all["FEATURES"] = featureList

#     print("ITEM:", testData_all.ITEM.unique(), ", MAE:", round(np.max(maeList),2), ", BestFit:", maeDic[np.max(maeList)], ", CORR:", round(corrStd,2), ", Feature", features)
    return testData_all

# %%
def final_summary(onedata):
    # groupedData2 = predictResult.groupby(groupKey)
    # onedata = groupedData2.get_group(list(groupedData2.groups)[0])

    targetColumns = ['ITEM', 'MIN_MAE', 'MODEL', 'COR_STD', 'FEATURES']

    outResult = onedata.head(1)[targetColumns]

    return outResult

# %%
predictResult = cleansedData.groupby(groupKey).apply(predict_ml, ).reset_index(drop=True)

# %%
predictResult.groupby(groupKey).apply(final_summary).reset_index(drop=True)
# Out:
#        ITEM  MIN_MAE                  MODEL  COR_STD  \
# 0   ITEM043   134.33  DecisionTreeRegressor     0.60
# 1   ITEM044     4.06  DecisionTreeRegressor     0.60
# 2   ITEM051     7.00  RandomForestRegressor     0.50
# 3   ITEM053   127.27  DecisionTreeRegressor     0.55
# 4   ITEM054     7.64       LinearRegression     0.55
# 5   ITEM056    26.51       LinearRegression     0.55
# 6   ITEM084    26.01                    SVM     0.50
# 7   ITEM085     9.53                    SVM     0.45
# 8   ITEM141    12.95  RandomForestRegressor     0.60
# 9   ITEM142   244.81  RandomForestRegressor     0.55
# 10  ITEM143    15.57  DecisionTreeRegressor     0.60
# 11  ITEM144     3.60       LinearRegression     0.60
# 12  ITEM145   162.76  RandomForestRegressor     0.60
# 13  ITEM146     4.65                    SVM     0.40
# 14  ITEM147    64.97  RandomForestRegressor     0.60
# 15  ITEM176    12.66  DecisionTreeRegressor     0.60
# 16  ITEM178   142.78  DecisionTreeRegressor     0.60
# 17  ITEM180    19.83  DecisionTreeRegressor     0.60
# 18  ITEM192   100.34       LinearRegression     0.55
# 19  ITEM205     4.86       LinearRegression     0.60
# 20  ITEM206    34.45  RandomForestRegressor     0.60
# 21  ITEM207     5.95       LinearRegression     0.60
# 22  ITEM209    17.55  DecisionTreeRegressor     0.60
# 23  ITEM220    26.10  RandomForestRegressor     0.60
# 24  ITEM224    24.01                    SVM     0.60
# 25  ITEM229   154.65       LinearRegression     0.55
# 26  ITEM230    33.01       LinearRegression     0.55
# 27  ITEM234    35.35       LinearRegression     0.60
# 28  ITEM236     8.33  RandomForestRegressor     0.60
# 29  ITEM239    60.39  RandomForestRegressor     0.60
# 30  ITEM240     7.45       LinearRegression     0.60
# 31  ITEM249    44.65  RandomForestRegressor     0.55
# 32  ITEM254    71.50  DecisionTreeRegressor     0.60
# 33  ITEM256    11.84       LinearRegression     0.60
# 34  ITEM257   125.18                    SVM     0.60
# 35  ITEM258     8.83       LinearRegression     0.60
# 36  ITEM287    15.79                    SVM     0.45
# 37  ITEM293     3.54                    SVM     0.50
# 38  ITEM294     2.76       LinearRegression     0.30
# 39  ITEM295    10.33       LinearRegression     0.50
# 40  ITEM302     6.20  RandomForestRegressor     0.45
# 41  ITEM326   256.81  DecisionTreeRegressor     0.60
# 42  ITEM327   227.44       LinearRegression     0.60
# 43  ITEM328   115.30       LinearRegression     0.50
# 44  ITEM359   169.31       LinearRegression     0.60
# 45  ITEM360    49.06  RandomForestRegressor     0.60
# 46  ITEM361   173.07       LinearRegression     0.60
# 47  ITEM362    93.67  RandomForestRegressor     0.50
# 48  ITEM363    57.83       LinearRegression     0.60
# 49  ITEM364    26.70       LinearRegression     0.50
# 50  ITEM374   238.98                    SVM     0.45
# 51  ITEM376    66.81       LinearRegression     0.45
#
#                        FEATURES
# 0                   PRO_PERCENT
# 1          PRO_PERCENT, PROM_YN
# 2                         HCLUS
# 3                         HCLUS
# 4                         HCLUS
# 5                   PRO_PERCENT
# 6                         HCLUS
# 7                         HCLUS
# 8                   PRO_PERCENT
# 9            HCLUS, PRO_PERCENT
# 10                  PRO_PERCENT
# 11                  PRO_PERCENT
# 12                        HCLUS
# 13                  PRO_PERCENT
# 14                  PRO_PERCENT
# 15                  PRO_PERCENT
# 16                  PRO_PERCENT
# 17                  PRO_PERCENT
# 18                  PRO_PERCENT
# 19           HCLUS, PRO_PERCENT
# 20                  PRO_PERCENT
# 21           HCLUS, PRO_PERCENT
# 22                  PRO_PERCENT
# 23                  PRO_PERCENT
# 24           HCLUS, PRO_PERCENT
# 25                  PRO_PERCENT
# 26                  PRO_PERCENT
# 27                  PRO_PERCENT
# 28                  PRO_PERCENT
# 29           HCLUS, PRO_PERCENT
# 30           HCLUS, PRO_PERCENT
# 31           HCLUS, PRO_PERCENT
# 32           HCLUS, PRO_PERCENT
# 33           HCLUS, PRO_PERCENT
# 34           HCLUS, PRO_PERCENT
# 35  HCLUS, PRO_PERCENT, HOLI_YN
# 36                        HCLUS
# 37                        HCLUS
# 38  HCLUS, PRO_PERCENT, HOLI_YN
# 39           HCLUS, PRO_PERCENT
# 40                     YEARWEEK
# 41         PRO_PERCENT, PROM_YN
# 42                  PRO_PERCENT
# 43           HCLUS, PRO_PERCENT
# 44                  PRO_PERCENT
# 45                  PRO_PERCENT
# 46                  PRO_PERCENT
# 47                        HCLUS
# 48                  PRO_PERCENT
# 49           HCLUS, PRO_PERCENT
# 50                  PRO_PERCENT
# 51  HCLUS, PRO_PERCENT, HOLI_YN

# %%
itemIdx = 0 # 그래프 확인이 필요한 ITEM INDEX

# %%
predictGroup = predictResult.groupby(groupKey)

# %%
itemData = predictGroup.get_group(list(predictGroup.groups)[itemIdx])
yearVal = itemData["YEARWEEK"]
yearVal = yearVal - 201700
realVal = itemData["QTY"]
trVal = itemData["TR_PREDICT"]
svmVal = itemData["SVM_PREDICT"]
rfVal = itemData["RF_PREDICT"]
lrVal = itemData["LR_PREDICT"]

# %%
plt.plot(yearVal, realVal, yearVal, trVal, yearVal, rfVal, yearVal, svmVal, yearVal, lrVal)
plt.show()
